# %% [markdown]
# ## Natural Language Processing of a Book

# %% [markdown]
# **Team Name:** ASH
# **Team Members:**  <br>Ayush Gupta(17ucs042),<br>
# Harshit Garg(17ucs064),<br> Shubhi Rustagi(17ucs158)

# %% [markdown]
# ## Book Details
#
# ### Book 1
#
# <b>Book Title</b> - Off Sandy Hook, and other stories<br>
# <b>Author's Name</b> - Richard Dehan<br>
# <b>Subjects</b> - Fiction, Short stories<br>
# <b>Number of Sentences</b> - 11202<br>
# <b>Number of Words</b> - 98822<br>
# <b>Character set encoding</b> - UTF-8<br>
#
# ### Book 2
#
# <b>Book Title</b> - A Book<br>
# <b>Author's Name</b> - Djuna Barnes<br>
# <b>Subjects</b> - Fiction<br>
# <b>Number of Sentences</b> - 1967<br>
# <b>Number of Words</b> - 43897<br>
# <b>Character set encoding</b> - UTF-8<br>

# %% [markdown]
# This is part of NLP-Projects Phase-1.
# In this project, we have used the following libraries and toolkits:
# * **nltk** - A leading platform in Python designed to provide easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along with a suite of text processing libraries. These libraries are used for classification, tokenisation, lemmatisation etc.
# * **string** - This module consists of basic operations that can be performed on string.
# * **WordNetLemmatizer** - It is a package for lemmatization. Lemmatization is the process of grouping together the words having similar meaning to a particular word.
# * **stopwords** - Set of commonly used words that are mostly ignored in text processing.
# * **matplotlib** - Library used for data visualisation. In other words, it is used for plotting the relationship among different components.
# * **re** - Library used for operations on regular expressions.
# * **wordcloud** - Library is used to plot the relative frequency of the words in text.

# %% [markdown]
# #### To begin, we import all the necssary libraries.

# %%
import nltk
import string
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.corpus import brown
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import numpy as np
import re

# %% [markdown]
# # PART 1

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Book 1

# %% [markdown]
# Now, open the book and read it in a variable *file*. Further, we read the contents of the book in another variable *T*.
# We declare a variable *T2* equal to *T* in case we require the original text later in the process as *T* will undergo text processing.

# %%
#Reading Book
file = open("Sandy_Hook_NLP.txt",encoding="utf8")

# variable T
T = file.read()

# variable T2
T2=T

# Printing the contents of the book stored in T
print(T[:1000])
# Out:
# ﻿Project Gutenberg's Off Sandy Hook and other stories, by Richard Dehan
#
# This eBook is for the use of anyone anywhere in the United States and most
# other parts of the world at no cost and with almost no restrictions
# whatsoever.  You may copy it, give it away or re-use it under the terms of
# the Project Gutenberg License included with this eBook or online at
# www.gutenberg.org.  If you are not located in the United States, you'll have
# to check the laws of the country where you are located before using this ebook.
#
# Title: Off Sandy Hook and other stories
#
# Author: Richard Dehan
#
# Release Date: October 8, 2019 [EBook #60452]
#
# Language: English
#
# Character set encoding: UTF-8
#
# *** START OF THIS PROJECT GUTENBERG EBOOK OFF SANDY HOOK AND OTHER STORIES ***
#
#
#
#
# Produced by Richard Tonsing and the Online Distributed
# Proofreading Team at http://www.pgdp.net (This file was
# produced from images generously made available by The
# Internet Archive)
#
#
#
#
#
#
#
#
#
#                              OFF SANDY HOOK

# %% [markdown]
# Further, punctuation marks are removed using ***maketrans()*** function and ***translate()*** function.
# First, *maketrans()* maps the string.punctuation to None and creates a mapping table. Then, using *translate()*, all the punctuations in *T* are replaced by None according to the mapping table. This is done in order to obtain the meaningful words.

# %%
translator = str.maketrans("","",string.punctuation)
T=T.translate(translator)
print(T[:1000])
# Out:
# ﻿Project Gutenbergs Off Sandy Hook and other stories by Richard Dehan
#
# This eBook is for the use of anyone anywhere in the United States and most
# other parts of the world at no cost and with almost no restrictions
# whatsoever  You may copy it give it away or reuse it under the terms of
# the Project Gutenberg License included with this eBook or online at
# wwwgutenbergorg  If you are not located in the United States youll have
# to check the laws of the country where you are located before using this ebook
#
# Title Off Sandy Hook and other stories
#
# Author Richard Dehan
#
# Release Date October 8 2019 EBook 60452
#
# Language English
#
# Character set encoding UTF8
#
#  START OF THIS PROJECT GUTENBERG EBOOK OFF SANDY HOOK AND OTHER STORIES
#
#
#
#
# Produced by Richard Tonsing and the Online Distributed
# Proofreading Team at httpwwwpgdpnet This file was
# produced from images generously made available by The
# Internet Archive
#
#
#
#
#
#
#
#
#
#                              OFF SANDY HOOK
#
#                            AND OTHER

# %% [markdown]
# Removal of the acknowledgement section and transcriber's note is done by using the substitution function and regular expressions.

# %%
# Removing acknowledgement
T = re.sub("Project[\s\S]*CONTENTS","",T)
T = re.sub("TRANSCRIBER[\s\S]*","",T)
print(T[:1000])
# Out:
# ﻿
#
#
#                                                 PAGE
#                    OFF SANDY HOOK                  1
#
#                    GEMINI                         15
#
#                    A DISH OF MACARONI             31
#
#                    “FREDDY  CIE”              44
#
#                    UNDER THE ELECTRICS            60
#
#                    “VALCOURT’S GRIN”              68
#
#                    THE EVOLUTION OF THE FAIREST   81
#
#                    THE REVOLT OF RUSTLETON        95
#
#                    A DYSPEPTIC’S TRAGEDY         107
#
#                    RENOVATION                    119
#
#                    THE BREAKING PLACE            133
#
#                    A LANCASHIRE DAISY            143
#
#                    A PITCHED BATTLE              154
#
#                    THE TUG OF WAR                164
#
#                    GAS                          180
#
#                    AIR                           193
#
#                    SIDE                         205
#
#                    A SPIRIT ELO

# %% [markdown]
# Similarly as above, we remove the chapter names from the index of the book.

# %%
# Removing Chapter Names
T=re.sub("[A-Z]{2,}","",T)
print(T[:1000])
# Out:
# ﻿
#
#
#
#                                        1
#
#                                             15
#
#                    A                31
#
#                    “  ”              44
#
#                                  60
#
#                    “’S ”              68
#
#                           81
#
#                               95
#
#                    A ’S          107
#
#                                        119
#
#                                  133
#
#                    A              143
#
#                    A                154
#
#                                       164
#
#                                              180
#
#                                               193
#
#                                             205
#
#                    A              219
#
#                     ’S               230
#
#                               241
#
#                     ’S          264
#
#                     ’S          276
#
#                                          287

# %% [markdown]
# Now, we remove the Chapter Numbers using the substitution function and regular expression.

# %%
# Removing Chapter Numbers
T=re.sub("[0-9]+","",T)
print(T[:1000])
# Out:
# ﻿
#
#
#
#
#
#
#
#                    A
#
#                    “  ”
#
#
#
#                    “’S ”
#
#
#
#
#
#                    A ’S
#
#
#
#
#
#                    A
#
#                    A
#
#
#
#
#
#
#
#
#
#                    A
#
#                     ’S
#
#
#
#                     ’S
#
#                     ’S
#
#
#
#                    A
#
#                    “—  —”

# %% [markdown]
# Conversion of the text to lower case for the ease of analysis.

# %%
# Converting text to lowercase
T = T.lower()
print(T[:1000])
# Out:
# ﻿
#
#
#
#
#
#
#
#                    a
#
#                    “  ”
#
#
#
#                    “’s ”
#
#
#
#
#
#                    a ’s
#
#
#
#
#
#                    a
#
#                    a
#
#
#
#
#
#
#
#
#
#                    a
#
#                     ’s
#
#
#
#                     ’s
#
#                     ’s
#
#
#
#                    a
#
#                    “—  —”

# %%
# splitting the lines and joining them into one.
T = " ".join(T.split())
wordcloudT=T
T2=T
print(T[:1000])
# Out:
# ﻿ a “ ” “’s ” a ’s a a a ’s ’s ’s a “— —” on board the rampatina liner eleven days and a half out from liverpool the usual terrific sensation created by the appearance of the pilotyacht prevailed necks were craned and toes were trodden on as the steamer slackened speed and a line dexterously thrown by a bluejerseyed deckhand was caught by somebody aboard the yacht the pilot not insensible to the fact of his being a personage of note carefully divested his bearded countenance of all expression as he saluted the captain and taking from the decksteward’s obsequiously proffered salver a glass containing fourfingers of neat bourbon whisky concealed its contents about his person without perceptible emotion and went up with the first officer upon the upper bridge as the relieved skipper plunged below the telegraphs clicked their message—the leviathan hulk of the liner quivered and began to forge slowly ahead and an intelligentlooking thinlipped badlyshaved young man in a bowler tweeds and str

# %% [markdown]
# Tokenisation is splitting a string into words, thus, forming a list of words known as tokens.
# For tokenisation, we use a library from *nltk* known as *tokenise*. The library consists of function *word_tokenize()* which takes the string, here *T* as the parameter and returns the list as shown in the output.

# %%
# Tokenisation
from nltk.tokenize import word_tokenize

T = word_tokenize(T)
print(T[:1000])
# Out:
# ['\ufeff', 'a', '“', '”', '“', '’', 's', '”', 'a', '’', 's', 'a', 'a', 'a', '’', 's', '’', 's', '’', 's', 'a', '“', '—', '—', '”', 'on', 'board', 'the', 'rampatina', 'liner', 'eleven', 'days', 'and', 'a', 'half', 'out', 'from', 'liverpool', 'the', 'usual', 'terrific', 'sensation', 'created', 'by', 'the', 'appearance', 'of', 'the', 'pilotyacht', 'prevailed', 'necks', 'were', 'craned', 'and', 'toes', 'were', 'trodden', 'on', 'as', 'the', 'steamer', 'slackened', 'speed', 'and', 'a', 'line', 'dexterously', 'thrown', 'by', 'a', 'bluejerseyed', 'deckhand', 'was', 'caught', 'by', 'somebody', 'aboard', 'the', 'yacht', 'the', 'pilot', 'not', 'insensible', 'to', 'the', 'fact', 'of', 'his', 'being', 'a', 'personage', 'of', 'note', 'carefully', 'divested', 'his', 'bearded', 'countenance', 'of', 'all', 'expression', 'as', 'he', 'saluted', 'the', 'captain', 'and', 'taking', 'from', 'the', 'decksteward', '’', 's', 'obsequiously', 'proffered', 'salver', 'a', 'glass', 'containing', 'fourfingers', 'of', 'neat', 'bourbon', 'whisky', 'concealed', 'its', 'contents', 'about', 'his', 'person', 'without', 'perceptible', 'emotion', 'and', 'went', 'up', 'with', 'the', 'first', 'officer', 'upon', 'the', 'upper', 'bridge', 'as', 'the', 'relieved', 'skipper', 'plunged', 'below', 'the', 'telegraphs', 'clicked', 'their', 'message—the', 'leviathan', 'hulk', 'of', 'the', 'liner', 'quivered', 'and', 'began', 'to', 'forge', 'slowly', 'ahead', 'and', 'an', 'intelligentlooking', 'thinlipped', 'badlyshaved', 'young', 'man', 'in', 'a', 'bowler', 'tweeds', 'and', 'striped', 'necktie', 'introduced', 'himself', 'to', 'the', 'second', 'officer', 'as', 'an', 'emissary', 'of', 'the', 'press', '“', 'mr', 'cyrus', 'k', 'pillson', 'new', 'york', 'yeller', 'pleased', 'to', 'know', 'you', 'sir', '”', 'said', 'the', 'second', 'officer', '“', 'step', 'into', 'the', 'smokeroom', 'this', 'way', 'barsteward', 'a', 'brandy', 'cocktail', 'for', 'me', 'and', 'you', 'sir', 'order', 'whatever', 'you', 'are', 'most', 'in', 'the', 'habit', 'of', 'hoisting', 'whisky', 'straight', 'now', 'sir', 'happy', 'to', 'afford', 'you', 'what', 'information', 'i', 'can', '”', '“', 'i', 'presume', '”', 'observed', 'the', 'young', 'gentleman', 'of', 'the', 'press', 'settling', 'himself', 'on', 'the', 'springy', 'morocco', 'cushions', 'and', 'accepting', 'the', 'second', 'officer', '’', 's', 'polite', 'offer', 'of', 'a', 'green', 'havana', 'of', 'the', 'strongest', 'kind', '“', 'that', 'you', 'have', 'had', 'a', 'smooth', 'passage', 'considerin', '’', 'the', 'time', 'of', 'year', '”', '“', 'smooth', '”', 'the', 'second', 'officer', 'carefully', 'reversed', 'in', 'his', 'reply', 'the', 'pressman', '’', 's', 'remark', '“', 'well', 'yes', 'the', 'time', 'of', 'year', 'considered', 'a', 'smooth', 'passage', 'i', 'take', 'it', 'we', 'have', 'had', '”', '“', 'no', 'fogs', '”', 'interrogated', 'the', 'young', 'gentleman', 'clicking', 'the', 'elastic', 'band', 'of', 'a', 'notebook', 'which', 'projected', 'from', 'his', 'breastpocket', '“', 'fogs', 'no', '”', 'said', 'the', 'second', 'officer', '“', 'you', 'didn', '’', 't', 'chance', '”', 'pursued', 'the', 'young', 'gentleman', 'of', 'the', 'press', 'taking', 'his', 'short', 'drink', 'from', 'the', 'steward', '’', 's', 'salver', 'and', 'throwing', 'it', 'contemptuously', 'down', 'his', 'throat', '“', 'to', 'fall', 'in', 'with', 'a', 'berg', 'off', 'the', 'bank', 'did', 'you', '”', '“', 'not', 'a', 'smell', 'of', 'one', '”', 'replied', 'the', 'second', 'officer', 'with', 'decision', '“', 'ran', 'into', 'a', 'derelict', 'hencoop', 'perhaps', '”', 'persisted', 'the', 'young', 'gentleman', 'concealing', 'the', 'worn', 'sole', 'of', 'a', 'wearied', 'boot', 'from', 'the', 'searching', 'glare', 'of', 'the', 'electric', 'light', 'by', 'tucking', 'it', 'underneath', 'him', '“', 'or', 'an', 'old', 'lady', '’', 's', 'bonnetbox', 'or', 'a', 'rubber', 'doll', 'some', 'woman', '’', 's', 'baby', 'had', 'lost', 'overboard', 'no', '”', 'he', 'echoed', 'as', 'the', 'second', 'off ...

# %% [markdown]
# Lemmatization is grouping together of the different forms of a word having similar meaning that is reducing the inflected forms and sometimes derivationally related forms of a word to a common base form to ease the analysis of the document.

# %%
# Lemmatisation
lemmatizer = WordNetLemmatizer()

# forming a set of stopwords from english language
stop_words = set(stopwords.words('english'))

# creating an empty list
lemmatized_T=[]

# traversing all the words
for word in T:
    # if the word has a length greater than or equal to 2 and is not a stopword
    if len(word) >= 2 and word not in stop_words:
        # then we append the word into the list lemmatized_T after performing lemmatization 
        # using the lemmatize() function
        lemmatized_T.append(lemmatizer.lemmatize(word))
        
# printing the list of lemmatized words
print(lemmatized_T[:1000])
# Out:
# ['board', 'rampatina', 'liner', 'eleven', 'day', 'half', 'liverpool', 'usual', 'terrific', 'sensation', 'created', 'appearance', 'pilotyacht', 'prevailed', 'neck', 'craned', 'toe', 'trodden', 'steamer', 'slackened', 'speed', 'line', 'dexterously', 'thrown', 'bluejerseyed', 'deckhand', 'caught', 'somebody', 'aboard', 'yacht', 'pilot', 'insensible', 'fact', 'personage', 'note', 'carefully', 'divested', 'bearded', 'countenance', 'expression', 'saluted', 'captain', 'taking', 'decksteward', 'obsequiously', 'proffered', 'salver', 'glass', 'containing', 'fourfingers', 'neat', 'bourbon', 'whisky', 'concealed', 'content', 'person', 'without', 'perceptible', 'emotion', 'went', 'first', 'officer', 'upon', 'upper', 'bridge', 'relieved', 'skipper', 'plunged', 'telegraph', 'clicked', 'message—the', 'leviathan', 'hulk', 'liner', 'quivered', 'began', 'forge', 'slowly', 'ahead', 'intelligentlooking', 'thinlipped', 'badlyshaved', 'young', 'man', 'bowler', 'tweed', 'striped', 'necktie', 'introduced', 'second', 'officer', 'emissary', 'press', 'mr', 'cyrus', 'pillson', 'new', 'york', 'yeller', 'pleased', 'know', 'sir', 'said', 'second', 'officer', 'step', 'smokeroom', 'way', 'barsteward', 'brandy', 'cocktail', 'sir', 'order', 'whatever', 'habit', 'hoisting', 'whisky', 'straight', 'sir', 'happy', 'afford', 'information', 'presume', 'observed', 'young', 'gentleman', 'press', 'settling', 'springy', 'morocco', 'cushion', 'accepting', 'second', 'officer', 'polite', 'offer', 'green', 'havana', 'strongest', 'kind', 'smooth', 'passage', 'considerin', 'time', 'year', 'smooth', 'second', 'officer', 'carefully', 'reversed', 'reply', 'pressman', 'remark', 'well', 'yes', 'time', 'year', 'considered', 'smooth', 'passage', 'take', 'fog', 'interrogated', 'young', 'gentleman', 'clicking', 'elastic', 'band', 'notebook', 'projected', 'breastpocket', 'fog', 'said', 'second', 'officer', 'chance', 'pursued', 'young', 'gentleman', 'press', 'taking', 'short', 'drink', 'steward', 'salver', 'throwing', 'contemptuously', 'throat', 'fall', 'berg', 'bank', 'smell', 'one', 'replied', 'second', 'officer', 'decision', 'ran', 'derelict', 'hencoop', 'perhaps', 'persisted', 'young', 'gentleman', 'concealing', 'worn', 'sole', 'wearied', 'boot', 'searching', 'glare', 'electric', 'light', 'tucking', 'underneath', 'old', 'lady', 'bonnetbox', 'rubber', 'doll', 'woman', 'baby', 'lost', 'overboard', 'echoed', 'second', 'officer', 'shook', 'head', 'thunder', 'manage', 'lose', 'twenty', 'foot', 'portrail', 'carried', 'away', 'said', 'second', 'officer', 'offering', 'young', 'press', 'gentleman', 'light', 'thanks', 'always', 'eat', 'mine', 'said', 'young', 'press', 'gentleman', 'gracefully', 'matter', 'taste', 'observed', 'second', 'officer', 'blowing', 'blue', 'ring', 'guess', 'taste', 'knowing', 'came', 'said', 'young', 'pressman', 'part', 'twenty', 'foot', 'rail', 'carried', 'away', 'said', 'second', 'officer', 'kin', 'see', 'retorted', 'visitor', 'carried', 'away', 'said', 'second', 'officer', 'elephant', 'pet', 'running', 'aboard', 'queried', 'pressman', 'imperturbable', 'coolness', 'passenger', 'returned', 'second', 'officer', 'equal', 'calm', 'snap', 'pressman', 'notebook', 'open', 'knee', 'pencil', 'vibrated', 'virgin', 'page', 'curious', 'utterance', 'wail', 'cough', 'roar', 'made', 'hand', 'held', 'start', 'yarrrr', 'ohowgh', 'yarr', 'melancholy', 'sound', 'came', 'without', 'borne', 'cool', 'breeze', 'late', 'afternoon', 'march', 'open', 'ventilator', 'might', 'queried', 'young', 'gentleman', 'press', 'expression', 'opinion', 'part', 'elephant', 'lord', 'love', 'said', 'second', 'officer', 'leopard', 'added', 'second', 'pause', 'puma', 'happen', 'menagerie', 'aboard', 'inquired', 'pressman', 'making', 'note', 'shorthand', 'sir', 'beasts—elephants', 'leopard', 'box', 'cobras—are', 'invoiced', 'london', 'dock', 'wealthy', 'amateur', 'new', 'york', 'state', 'iron', 'king', 'corn', 'king', 'cotton', 'king', 'pickle', 'king', 'kerosene', 'king', 'said', 'second', 'officer', 'steady', ' ...

# %%
from nltk.corpus import wordnet as wn
nouns = []
verbs = []
for word in lemmatized_T:
    for synset in wn.synsets(word):
        if "noun" in synset.lexname() and word not in nouns:
            nouns.append(word)
            
        elif "verb" in synset.lexname() and word not in verbs:
            verbs.append(word)

# %%
print(nouns)
# Out:
# ['board', 'liner', 'eleven', 'day', 'half', 'liverpool', 'sensation', 'appearance', 'neck', 'toe', 'steamer', 'speed', 'line', 'deckhand', 'somebody', 'yacht', 'pilot', 'fact', 'personage', 'note', 'countenance', 'expression', 'captain', 'taking', 'salver', 'glass', 'bourbon', 'whisky', 'content', 'person', 'emotion', 'first', 'officer', 'upper', 'bridge', 'skipper', 'telegraph', 'leviathan', 'hulk', 'forge', 'young', 'man', 'bowler', 'tweed', 'necktie', 'second', 'emissary', 'press', 'mr', 'cyrus', 'york', 'yeller', 'know', 'sir', 'step', 'way', 'brandy', 'cocktail', 'order', 'habit', 'straight', 'information', 'gentleman', 'settling', 'morocco', 'cushion', 'offer', 'green', 'havana', 'kind', 'smooth', 'passage', 'time', 'year', 'reply', 'pressman', 'remark', 'well', 'yes', 'take', 'fog', 'elastic', 'band', 'notebook', 'chance', 'pursued', 'short', 'drink', 'steward', 'throat', 'fall', 'berg', 'bank', 'smell', 'one', 'decision', 'derelict', 'hencoop', 'concealing', 'sole', 'boot', 'glare', 'electric', 'light', 'old', 'lady', 'rubber', 'doll', 'woman', 'baby', 'lost', 'shook', 'head', 'thunder', 'twenty', 'foot', 'offering', 'thanks', 'mine', 'matter', 'taste', 'blowing', 'blue', 'ring', 'guess', 'knowing', 'part', 'rail', 'kin', 'see', 'visitor', 'elephant', 'pet', 'running', 'coolness', 'passenger', 'equal', 'calm', 'snap', 'open', 'knee', 'pencil', 'virgin', 'page', 'utterance', 'wail', 'cough', 'roar', 'hand', 'start', 'melancholy', 'sound', 'cool', 'breeze', 'afternoon', 'march', 'ventilator', 'might', 'opinion', 'lord', 'love', 'leopard', 'pause', 'puma', 'menagerie', 'making', 'shorthand', 'box', 'london', 'dock', 'amateur', 'state', 'iron', 'king', 'corn', 'cotton', 'pickle', 'kerosene', 'steady', 'lip', 'mean', 'mother', 'cousin', 'chew', 'gum', 'school', 'recess', 'little', 'guessing', 'shad', 'soar', 'wing', 'article', 'realm', 'plutocracy', 'name', 'mention', 'right', 'beast', 'present', 'purchaser', 'infant', 'daughter', 'fifth', 'birthday', 'coughing', 'chorus', 'hail', 'columbia', 'rose', 'promenade', 'deck', 'ready', 'wave', 'silk', 'exchange', 'sentiment', 'glimpse', 'land', 'call', 'voice', 'slight', 'shiver', 'child', 'queer', 'spot', 'bingo', 'dead', 'passing', 'palm', 'brown', 'rapid', 'particular', 'deathbed', 'scene', 'interest', 'welcome', 'em', 'white', 'licking', 'die', 'seasickness', 'thing', 'worth', 'professional', 'attendance', 'stem', 'stern', 'print', 'gown', 'apron', 'ward', 'shoe', 'lack', 'corner', 'divan', 'shirtfront', 'fed', 'girl', 'mackintosh', 'holdall', 'black', 'bag', 'sort', 'plump', 'bow', 'air', 'get', 'full', 'money', 'fare', 'tariff', 'score', 'special', 'derrick', 'sling', 'cage', 'capital', 'indian', 'teak', 'cost', 'mint', 'lot', 'sweat', 'swearing', 'funnel', 'wire', 'hawser', 'top', 'fast', 'port', 'starboard', 'davit', 'rigging', 'double', 'tarpaulin', 'keep', 'dry', 'lee', 'forward', 'cabin', 'skylight', 'job', 'quiet', 'elbow', 'say', 'regard', 'patient', 'wish', 'purser', 'mistake', 'hospital', 'nurse', 'bedroom', 'far', 'night', 'kink', 'hair', 'forehead', 'want', 'move', 'floor', 'madam', 'grin', 'enough', 'bungle', 'make', 'sea', 'flying', 'turning', 'cigar', 'teeth', 'come', 'side', 'may', 'number', 'eye', 'flash', 'sleep', 'great', 'morgan', 'extreme', 'rapidity', 'drop', 'perspiration', 'sallow', 'glory', 'thought', 'run', 'tackle', 'tub', 'cap', 'keeping', 'surprise', 'felt', 'smile', 'nursing', 'association', 'american', 'looking', 'animal', 'voyage', 'principal', 'condition', 'pay', 'attention', 'pressure', 'point', 'outside', 'nigger', 'three', 'fair', 'wind', 'nothing', 'like', 'feeding', 'apple', 'nut', 'biscuit', 'saloon', 'table', 'must', 'appetite', 'trunk', 'round', 'wild', 'put', 'hogshead', 'good', 'addition', 'allowance', 'hay', 'bread', 'beetroot', 'grain', 'cabbage', 'ca', 'temper', 'milk', 'breathing', 'snoring', 'people', 'washing', 'soap', 'circular', 'expense', 'case', 'toilet', 'complexion', 'living', 'standing', 'morning', 'water', 'swabbing',  ...

# %%
print(verbs)
# Out:
# ['board', 'created', 'prevailed', 'neck', 'craned', 'toe', 'trodden', 'steamer', 'slackened', 'speed', 'line', 'thrown', 'caught', 'yacht', 'pilot', 'note', 'divested', 'bearded', 'countenance', 'saluted', 'captain', 'taking', 'proffered', 'glass', 'containing', 'concealed', 'content', 'went', 'officer', 'bridge', 'relieved', 'skipper', 'plunged', 'telegraph', 'clicked', 'hulk', 'quivered', 'began', 'forge', 'man', 'striped', 'introduced', 'second', 'press', 'pleased', 'know', 'said', 'step', 'order', 'habit', 'hoisting', 'afford', 'presume', 'observed', 'settling', 'cushion', 'accepting', 'offer', 'green', 'smooth', 'time', 'reversed', 'reply', 'remark', 'well', 'considered', 'take', 'fog', 'interrogated', 'clicking', 'band', 'projected', 'chance', 'pursued', 'short', 'drink', 'throwing', 'fall', 'bank', 'smell', 'replied', 'ran', 'persisted', 'concealing', 'worn', 'sole', 'wearied', 'boot', 'searching', 'glare', 'light', 'tucking', 'rubber', 'baby', 'lost', 'echoed', 'shook', 'head', 'thunder', 'manage', 'lose', 'foot', 'carried', 'offering', 'thanks', 'eat', 'mine', 'matter', 'taste', 'blowing', 'blue', 'ring', 'guess', 'knowing', 'came', 'part', 'rail', 'see', 'retorted', 'pet', 'running', 'queried', 'returned', 'equal', 'calm', 'snap', 'open', 'pencil', 'vibrated', 'page', 'wail', 'cough', 'roar', 'made', 'hand', 'held', 'start', 'sound', 'borne', 'cool', 'breeze', 'march', 'lord', 'love', 'added', 'pause', 'happen', 'inquired', 'making', 'box', 'invoiced', 'dock', 'state', 'iron', 'corn', 'cotton', 'pickle', 'steady', 'mean', 'mother', 'used', 'chew', 'gum', 'school', 'recess', 'guessing', 'soar', 'wing', 'article', 'gilded', 'imagine', 'name', 'mention', 'right', 'commit', 'shipped', 'intended', 'present', 'coughing', 'chorus', 'hail', 'rose', 'promenade', 'deck', 'assembled', 'ready', 'wave', 'starred', 'exchange', 'glimpse', 'land', 'call', 'voice', 'controlling', 'slight', 'shiver', 'queer', 'spot', 'passing', 'palm', 'brown', 'interest', 'welcome', 'white', 'licking', 'die', 'seen', 'complete', 'stem', 'print', 'gown', 'ward', 'shoe', 'grunted', 'lack', 'doubled', 'corner', 'balanced', 'bulging', 'waited', 'seemed', 'fed', 'black', 'bag', 'noticed', 'sort', 'plump', 'bow', 'air', 'meant', 'get', 'full', 'fare', 'tariff', 'filled', 'long', 'score', 'attend', 'rigged', 'sling', 'cage', 'strengthened', 'cost', 'mint', 'stowed', 'lot', 'sweat', 'swearing', 'funnel', 'bolting', 'screwed', 'wire', 'top', 'fast', 'port', 'starboard', 'rigging', 'double', 'keep', 'warm', 'dry', 'forward', 'cabin', 'got', 'job', 'quiet', 'elbow', 'say', 'please', 'regard', 'wish', 'ask', 'worried', 'asked', 'determined', 'referred', 'mistake', 'nurse', 'allotted', 'hear', 'played', 'kink', 'framed', 'want', 'move', 'floor', 'smoothing', 'grin', 'bungle', 'make', 'flying', 'stopped', 'looked', 'turning', 'shortened', 'come', 'occupy', 'side', 'number', 'smiled', 'eye', 'flash', 'sleep', 'ejaculated', 'became', 'plied', 'drop', 'broke', 'sallow', 'glory', 'cried', 'thought', 'run', 'tackle', 'wallowing', 'touched', 'cap', 'keeping', 'surprise', 'felt', 'understand', 'nodded', 'smile', 'told', 'nursing', 'engaged', 'bought', 'prompted', 'looking', 'voyage', 'understood', 'condition', 'permitted', 'pay', 'appreciating', 'pressure', 'point', 'coughed', 'suggested', 'heard', 'fair', 'wind', 'delighted', 'like', 'feeding', 'nut', 'table', 'sharpened', 'suppose', 'round', 'put', 'allowance', 'hay', 'bread', 'grain', 'cabbage', 'temper', 'milk', 'breathed', 'breathing', 'complain', 'snoring', 'people', 'allow', 'happened', 'hinted', 'took', 'washing', 'scented', 'soap', 'expense', 'case', 'complexion', 'living', 'harry', 'standing', 'water', 'swabbing', 'soaped', 'squirting', 'rinse', 'believed', 'sight', 'drew', 'pantomime', 'given', 'weather', 'bit', 'bugle', 'blew', 'turned', 'mound', 'disgust', 'bucket', 'oblige', 'cheer', 'brisk', 'considering', 'sighed', 'tear', 'trickled', 'swayed', 'better', 'charge', 'face', 'streaked', 'lay', 'glued', 'devo ...

# %%
noun_dic = {}
lt = []
for noun in nouns:
    l = []
    for synset in wn.synsets(noun):
        if "noun" in synset.lexname():
            if synset.lexname()[5:] not in l:
                l.append(synset.lexname()[5:])
                lt.append(synset.lexname()[5:])
                
    noun_dic[noun] = l

# %%
for i in noun_dic:
    print(i,":", noun_dic[i])
# Out:
# board : ['group', 'substance', 'artifact', 'food']
# liner : ['act', 'artifact']
# eleven : ['quantity', 'group']
# day : ['time', 'state', 'person']
# half : ['quantity', 'time']
# liverpool : ['location']
# sensation : ['cognition', 'person', 'feeling', 'state']
# appearance : ['attribute', 'event', 'act', 'cognition']
# neck : ['body', 'object', 'food', 'artifact']
# toe : ['body', 'artifact']
# steamer : ['food', 'artifact', 'animal']
# speed : ['time', 'attribute', 'act', 'relation', 'artifact']
# line : ['group', 'communication', 'shape', 'phenomenon', 'location', 'cognition', 'artifact', 'act', 'quantity', 'possession']
# deckhand : ['person']
# somebody : ['Tops']
# yacht : ['artifact']
# pilot : ['person', 'communication', 'cognition', 'artifact']
# fact : ['cognition', 'communication', 'state']
# personage : ['person']
# note : ['communication', 'attribute', 'possession', 'state']
# countenance : ['attribute', 'communication', 'body']
# expression : ['attribute', 'communication', 'process', 'act']
# captain : ['person']
# taking : ['act']
# salver : ['artifact']
# glass : ['substance', 'artifact', 'quantity']
# bourbon : ['person', 'food', 'group']
# whisky : ['food']
# content : ['group', 'communication', 'relation', 'quantity', 'cognition', 'state', 'artifact']
# person : ['Tops', 'body', 'communication']
# emotion : ['feeling']
# first : ['relation', 'quantity', 'time', 'act', 'communication', 'artifact']
# officer : ['person']
# upper : ['artifact']
# bridge : ['artifact', 'relation', 'body', 'act']
# skipper : ['person']
# telegraph : ['artifact']
# leviathan : ['person']
# hulk : ['person', 'artifact']
# forge : ['artifact']
# young : ['animal', 'person', 'group']
# man : ['person', 'animal', 'location', 'artifact']
# bowler : ['person', 'artifact']
# tweed : ['artifact']
# necktie : ['artifact']
# second : ['time', 'act', 'relation', 'quantity', 'person', 'communication', 'artifact']
# emissary : ['person']
# press : ['state', 'communication', 'artifact', 'group', 'act']
# mr : ['communication']
# cyrus : ['person']
# york : ['group']
# yeller : ['person']
# know : ['cognition']
# sir : ['person']
# step : ['act', 'quantity', 'artifact', 'state', 'event', 'communication']
# way : ['attribute', 'act', 'location', 'state', 'artifact', 'quantity', 'cognition', 'possession']
# brandy : ['food']
# cocktail : ['food']
# order : ['communication', 'attribute', 'state', 'group', 'act']
# habit : ['cognition', 'act', 'artifact', 'process']
# straight : ['person', 'group', 'artifact']
# information : ['communication', 'cognition', 'group', 'attribute']
# gentleman : ['person']
# settling : ['event']
# morocco : ['location', 'substance']
# cushion : ['artifact']
# offer : ['communication', 'act']
# green : ['attribute', 'location', 'person', 'object', 'food', 'artifact']
# havana : ['location']
# kind : ['cognition']
# smooth : ['act']
# passage : ['act', 'communication', 'artifact', 'body', 'event']
# time : ['event', 'time', 'Tops', 'attribute']
# year : ['time', 'group']
# reply : ['communication']
# pressman : ['person']
# remark : ['communication', 'cognition']
# well : ['artifact', 'communication']
# yes : ['communication']
# take : ['possession', 'act']
# fog : ['phenomenon', 'state', 'cognition']
# elastic : ['artifact']
# band : ['group', 'attribute', 'artifact', 'communication', 'body']
# notebook : ['communication', 'artifact']
# chance : ['state', 'phenomenon', 'act', 'attribute']
# pursued : ['person']
# short : ['artifact', 'act']
# drink : ['food', 'act', 'object']
# steward : ['person']
# throat : ['body', 'artifact', 'animal']
# fall : ['time', 'act', 'event', 'object', 'attribute']
# berg : ['object', 'person']
# bank : ['object', 'group', 'possession', 'artifact', 'act']
# smell : ['cognition', 'attribute', 'state', 'act']
# one : ['quantity', 'cognition']
# decision : ['act', 'cognition', 'event', 'attribute']
# derelict : ['person', 'artifact']
# hencoop : ['artifact']
# concealing : ['act']
# sole : ['artifact', 'food', 'body', 'animal']
# boot : ['artifact', 'feeling', 'act']
# glare : ['attribute', 'act', 'state']
# electric : ['artifact']
# light : ['phenomenon', 'artifact', 'cognition', 'attribute', 'location', 'state', 'person', 'motive', 'communication']
# old : ['time']
# lady : ['person']
# rubber : ['substance', 'artifact']
# doll : ['artifact', 'person']
# woman : ['person', 'group']
# baby : ['person', 'animal', 'act']
# lost : ['group']
# shook : ['artifact']
# head : ['body', 'animal', 'cognition', 'person', 'group', 'phenomenon', 'location', 'communication', 'state', 'quantity', 'plant', 'object', 'event', 'artifact', 'act']
# thunder : ['event', 'artifact']
# twenty : ['quantity', 'possession']
# foot : ['body', 'quantity', 'location', 'animal', 'artifact', 'act', 'person', 'group', 'communication']
# offering : ['communication', 'possession', 'act']
# thanks : ['communication', 'act']
# mine : ['artifact']
# matter : ['cognition', 'Tops', 'attribute', 'communication']
# taste : ['cognition', 'feeling', 'event', 'food', 'act']
# blowing : ['process']
# blue : ['attribute', 'artifact', 'group', 'object', 'substance', 'animal']
# ring : ['attribute', 'shape', 'artifact', 'object', 'group', 'event']
# guess : ['communication', 'cognition']
# knowing : ['cognition']
# part : ['relation', 'artifact', 'object', 'cognition', 'location', 'act', 'possession', 'body', 'communication']
# rail : ['artifact', 'animal']
# kin : ['person', 'group']
# see : ['location']
# visitor : ['person']
# elephant : ['animal', 'communication']
# pet : ['animal', 'person', 'feeling', 'act']
# running : ['act', 'state']
# coolness : ['feeling', 'attribute']
# passenger : ['person']
# equal : ['person']
# calm : ['attribute', 'phenomenon']
# snap : ['act', 'time', 'food', 'event', 'attribute', 'artifact']
# open : ['location', 'event', 'cognition']
# knee : ['body', 'animal', 'artifact']
# pencil : ['artifact', 'substance', 'shape']
# virgin : ['person', 'location']
# page : ['communication', 'person']
# utterance : ['communication']
# wail : ['communication']
# cough : ['state']
# roar : ['event', 'communication']
# hand : ['body', 'person', 'communication', 'cognition', 'location', 'group', 'artifact', 'quantity', 'animal', 'act']
# start : ['event', 'time', 'act', 'location', 'communication', 'attribute']
# melancholy : ['feeling', 'state', 'body']
# sound : ['attribute', 'cognition', 'phenomenon', 'event', 'communication', 'object']
# cool : ['attribute']
# breeze : ['phenomenon', 'act']
# afternoon : ['time', 'communication']
# march : ['time', 'act', 'group', 'location', 'communication']
# ventilator : ['artifact']
# might : ['attribute']
# opinion : ['cognition', 'communication', 'act']
# lord : ['person']
# love : ['feeling', 'cognition', 'person', 'quantity', 'act']
# leopard : ['substance', 'animal']
# pause : ['time', 'act']
# puma : ['animal']
# menagerie : ['group', 'artifact']
# making : ['act', 'attribute', 'artifact']
# shorthand : ['communication']
# box : ['artifact', 'quantity', 'state', 'shape', 'plant', 'act']
# london : ['location', 'person']
# dock : ['artifact', 'plant', 'animal']
# amateur : ['person']
# state : ['location', 'Tops', 'group', 'state']
# iron : ['substance', 'artifact']
# king : ['person', 'state', 'artifact']
# corn : ['plant', 'food', 'state', 'attribute']
# cotton : ['substance', 'artifact', 'plant']
# pickle : ['food', 'state']
# kerosene : ['substance']
# steady : ['person']
# lip : ['body', 'plant', 'communication', 'artifact', 'animal']
# mean : ['cognition']
# mother : ['person', 'substance', 'cognition']
# cousin : ['person']
# chew : ['food', 'act']
# gum : ['food', 'body', 'substance', 'plant']
# school : ['group', 'artifact', 'cognition', 'time']
# recess : ['state', 'shape', 'object', 'artifact', 'act']
# little : ['quantity']
# guessing : ['cognition']
# shad : ['food', 'animal']
# soar : ['act']
# wing : ['animal', 'artifact', 'group', 'person', 'location', 'food']
# article : ['communication', 'Tops']
# realm : ['state', 'location', 'cognition']
# plutocracy : ['group']
# name : ['communication', 'state', 'group', 'person', 'act']
# mention : ['communication']
# right : ['attribute', 'location', 'artifact', 'group', 'body', 'act', 'possession']
# beast : ['Tops', 'person']
# present : ['time', 'possession', 'communication']
# purchaser : ['person']
# infant : ['person']
# daughter : ['person']
# fifth : ['quantity', 'relation', 'communication']
# birthday : ['time']
# coughing : ['state']
# chorus : ['event', 'group', 'communication']
# hail : ['phenomenon', 'object', 'communication']
# columbia : ['object', 'location', 'artifact']
# rose : ['plant', 'food', 'attribute']
# promenade : ['event', 'artifact', 'act']
# deck : ['artifact', 'group']
# ready : ['state']
# wave : ['event', 'act', 'communication', 'body', 'shape', 'phenomenon', 'person']
# silk : ['artifact', 'substance']
# exchange : ['phenomenon', 'communication', 'act', 'artifact']
# sentiment : ['feeling', 'cognition']
# glimpse : ['act', 'cognition', 'communication']
# land : ['possession', 'object', 'location', 'state', 'group', 'person', 'act']
# call : ['communication', 'cognition', 'act']
# voice : ['attribute', 'communication', 'event', 'act', 'person', 'relation']
# slight : ['act']
# shiver : ['act', 'feeling']
# child : ['person']
# queer : ['person']
# spot : ['location', 'communication', 'attribute', 'artifact', 'act', 'state', 'quantity']
# bingo : ['act']
# dead : ['group', 'time']
# passing : ['act', 'event']
# palm : ['body', 'quantity', 'plant', 'communication']
# brown : ['attribute', 'person', 'artifact']
# rapid : ['object']
# particular : ['cognition', 'relation', 'communication']
# deathbed : ['time', 'artifact']
# scene : ['location', 'event', 'cognition', 'communication', 'state', 'artifact']
# interest : ['cognition', 'attribute', 'possession', 'group', 'act']
# welcome : ['state', 'communication']
# em : ['quantity']
# white : ['person', 'attribute', 'object', 'food', 'artifact']
# licking : ['event', 'act']
# die : ['artifact']
# seasickness : ['state']
# thing : ['state', 'act', 'cognition', 'artifact', 'event', 'communication', 'attribute', 'feeling', 'Tops']
# worth : ['quantity', 'attribute', 'person']
# professional : ['person']
# attendance : ['act', 'time', 'group']
# stem : ['communication', 'plant', 'artifact', 'act']
# stern : ['artifact', 'person', 'body']
# print : ['communication', 'artifact']
# gown : ['artifact', 'group']
# apron : ['artifact', 'location']
# ward : ['person', 'location', 'artifact']
# shoe : ['artifact']
# lack : ['state']
# corner : ['location', 'artifact', 'shape', 'state', 'object']
# divan : ['artifact', 'group', 'communication']
# shirtfront : ['artifact']
# fed : ['person', 'group']
# girl : ['person']
# mackintosh : ['artifact']
# holdall : ['artifact']
# black : ['attribute', 'state', 'person', 'artifact']
# bag : ['artifact', 'quantity', 'person', 'animal', 'act']
# sort : ['cognition', 'attribute', 'person', 'process']
# plump : ['event']
# bow : ['artifact', 'shape', 'communication', 'act']
# air : ['substance', 'location', 'attribute', 'phenomenon', 'communication', 'act']
# get : ['act']
# full : ['time']
# money : ['possession']
# fare : ['cognition', 'possession', 'person', 'food']
# tariff : ['possession']
# score : ['cognition', 'communication', 'quantity', 'group', 'motive', 'state', 'shape', 'feeling', 'act']
# special : ['communication', 'food']
# derrick : ['artifact']
# sling : ['food', 'artifact']
# cage : ['artifact', 'state', 'person']
# capital : ['possession', 'location', 'communication', 'group', 'artifact']
# indian : ['person', 'communication']
# teak : ['plant']
# cost : ['possession', 'attribute']
# mint : ['quantity', 'plant', 'food', 'artifact']
# lot : ['quantity', 'location', 'group', 'state', 'artifact', 'person']
# sweat : ['body', 'state', 'phenomenon', 'act']
# swearing : ['communication']
# funnel : ['shape', 'artifact']
# wire : ['artifact', 'location', 'communication']
# hawser : ['artifact']
# top : ['location', 'time', 'state', 'attribute', 'artifact']
# fast : ['act']
# port : ['location', 'food', 'artifact']
# starboard : ['artifact']
# davit : ['artifact']
# rigging : ['artifact']
# double : ['act', 'person', 'cognition']
# tarpaulin : ['artifact']
# keep : ['possession', 'artifact']
# dry : ['person']
# lee : ['person', 'location']
# forward : ['person', 'act']
# cabin : ['artifact']
# skylight : ['artifact']
# job : ['act', 'artifact', 'state', 'person', 'communication']
# quiet : ['state', 'attribute']
# elbow : ['body', 'artifact', 'animal']
# say : ['state']
# regard : ['cognition', 'communication', 'act', 'state', 'feeling']
# patient : ['person', 'communication']
# wish : ['feeling', 'communication', 'cognition']
# purser : ['person']
# mistake : ['act', 'cognition', 'communication']
# hospital : ['artifact', 'group']
# nurse : ['person']
# bedroom : ['artifact']
# far : ['group']
# night : ['time', 'state', 'person']
# kink : ['state', 'shape', 'person', 'cognition']
# hair : ['body', 'quantity', 'plant', 'artifact', 'animal']
# forehead : ['body']
# want : ['state', 'object', 'feeling']
# move : ['act']
# floor : ['artifact', 'communication', 'object', 'group', 'attribute']
# madam : ['person']
# grin : ['communication']
# enough : ['quantity']
# bungle : ['act']
# make : ['cognition', 'act']
# sea : ['object', 'quantity', 'phenomenon']
# flying : ['act']
# turning : ['act', 'object', 'event', 'artifact']
# cigar : ['artifact']
# teeth : ['body', 'artifact', 'animal', 'act']
# come : ['body']
# side : ['location', 'group', 'body', 'artifact', 'cognition', 'food', 'communication', 'object', 'event']
# may : ['time', 'plant']
# number : ['attribute', 'quantity', 'communication', 'group', 'artifact']
# eye : ['body', 'cognition', 'location', 'artifact']
# flash : ['event', 'attribute', 'cognition', 'time', 'communication', 'artifact']
# sleep : ['state', 'time']
# great : ['person']
# morgan : ['person', 'animal']
# extreme : ['attribute', 'location']
# rapidity : ['attribute']
# drop : ['shape', 'quantity', 'attribute', 'object', 'location', 'event', 'artifact', 'act']
# perspiration : ['body', 'process']
# sallow : ['plant']
# glory : ['state', 'attribute']
# thought : ['cognition']
# run : ['act', 'event', 'group', 'time', 'state', 'quantity', 'object', 'attribute']
# tackle : ['person', 'artifact', 'act']
# tub : ['artifact', 'quantity']
# cap : ['artifact', 'plant', 'object', 'communication']
# keeping : ['act']
# surprise : ['feeling', 'event', 'act']
# felt : ['artifact']
# smile : ['communication']
# nursing : ['act', 'group']
# association : ['group', 'act', 'state', 'cognition', 'relation', 'process']
# american : ['person', 'communication']
# looking : ['act']
# animal : ['Tops']
# voyage : ['act']
# principal : ['possession', 'person']
# condition : ['state', 'communication', 'cognition']
# pay : ['possession']
# attention : ['cognition', 'act', 'attribute']
# pressure : ['phenomenon', 'attribute', 'act', 'state', 'cognition']
# point : ['cognition', 'location', 'communication', 'state', 'time', 'shape', 'quantity', 'object', 'relation', 'attribute', 'artifact', 'possession']
# outside : ['location']
# nigger : ['person']
# three : ['quantity', 'artifact']
# fair : ['act', 'group']
# wind : ['phenomenon', 'act', 'communication', 'artifact']
# nothing : ['quantity']
# like : ['cognition']
# feeding : ['act']
# apple : ['food', 'plant']
# nut : ['plant', 'person', 'artifact', 'quantity', 'body']
# biscuit : ['food']
# saloon : ['artifact']
# table : ['group', 'artifact', 'object', 'food']
# must : ['object', 'food', 'attribute']
# appetite : ['feeling']
# trunk : ['plant', 'artifact', 'body', 'animal']
# round : ['artifact', 'time', 'location', 'act', 'object', 'food', 'communication']
# wild : ['state', 'location']
# put : ['act']
# hogshead : ['quantity', 'artifact']
# good : ['attribute', 'artifact']
# addition : ['artifact', 'act', 'quantity', 'possession', 'location']
# allowance : ['possession', 'attribute', 'act']
# hay : ['food']
# bread : ['food', 'possession']
# beetroot : ['plant', 'food']
# grain : ['object', 'food', 'substance', 'quantity', 'plant', 'attribute']
# cabbage : ['food', 'possession', 'plant']
# ca : ['substance', 'location']
# temper : ['feeling', 'attribute']
# milk : ['food', 'body', 'object']
# breathing : ['act']
# snoring : ['act']
# people : ['group']
# washing : ['act', 'artifact']
# soap : ['artifact', 'possession']
# circular : ['communication']
# expense : ['possession', 'event']
# case : ['event', 'state', 'act', 'cognition', 'artifact', 'person', 'communication', 'quantity', 'body']
# toilet : ['artifact', 'state', 'act']
# complexion : ['attribute', 'group', 'cognition']
# living : ['cognition', 'group', 'state', 'possession']
# standing : ['state', 'communication', 'act']
# morning : ['time', 'communication', 'event']
# water : ['substance', 'object', 'artifact', 'food']
# swabbing : ['act']
# rinse : ['substance', 'act']
# intelligence : ['cognition', 'group', 'communication', 'act']
# sight : ['cognition', 'communication', 'act', 'quantity']
# drew : ['person']
# pantomime : ['act']
# sixth : ['relation', 'quantity', 'communication']
# given : ['cognition']
# weather : ['phenomenon']
# bit : ['quantity', 'object', 'time', 'event', 'artifact', 'food', 'communication']
# ear : ['body', 'cognition', 'plant']
# bugle : ['artifact', 'plant']
# haystack : ['group']
# mound : ['artifact', 'object', 'group', 'act']
# disgust : ['feeling']
# bucket : ['artifact', 'quantity']
# bovril : ['food']
# oh : ['location']
# cheer : ['communication', 'attribute']
# two : ['quantity', 'artifact']
# tear : ['body', 'object', 'act']
# red : ['attribute', 'object', 'person', 'possession']
# worse : ['attribute']
# better : ['attribute', 'person']
# charge : ['act', 'communication', 'possession', 'phenomenon', 'person', 'motive', 'feeling', 'artifact']
# face : ['body', 'attribute', 'artifact', 'person', 'location', 'communication']
# lay : ['communication']
# brow : ['body', 'location']
# upset : ['state', 'act', 'artifact']
# pitching : ['act']
# vessel : ['body', 'artifact']
# gale : ['phenomenon']
# sou : ['possession']
# west : ['location', 'relation', 'person']
# centipede : ['animal']
# nose : ['body', 'artifact', 'quantity', 'communication', 'cognition']
# bee : ['animal', 'group']
# devise : ['possession']
# suggestion : ['cognition', 'communication', 'quantity', 'act']
# stewardess : ['person']
# deal : ['act', 'communication', 'quantity', 'substance', 'group', 'event']
# suffering : ['state', 'feeling']
# stand : ['artifact', 'location', 'group', 'event', 'cognition', 'act']
# hour : ['time', 'attribute']
# wet : ['state']
# planking : ['substance', 'artifact', 'act']
# holding : ['act', 'possession']
# star : ['object', 'person', 'shape', 'communication', 'cognition']
# dozen : ['quantity']
# bottle : ['artifact', 'quantity']
# wonder : ['feeling', 'event', 'cognition']
# moistening : ['act']
# arrowroot : ['substance', 'plant']
# wine : ['food', 'attribute']
# tin : ['substance', 'artifact']
# cuddy : ['artifact']
# nourishment : ['food', 'act']
# touching : ['event', 'act']
# marking : ['communication', 'attribute', 'act']
# word : ['communication', 'quantity', 'person']
# headline : ['communication']
# waist : ['body', 'artifact']
# shoulder : ['body', 'food', 'artifact']
# ladder : ['artifact', 'state', 'event']
# hang : ['cognition', 'attribute', 'act']
# forefoot : ['animal']
# pulse : ['event', 'time', 'food']
# christian : ['person']
# style : ['attribute', 'communication', 'cognition', 'plant', 'artifact', 'animal']
# temperature : ['attribute', 'cognition']
# brute : ['person', 'Tops']
# curl : ['shape', 'person', 'body']
# mouth : ['body', 'object', 'person', 'communication', 'artifact']
# instrument : ['artifact', 'act', 'person', 'communication']
# tongue : ['body', 'communication', 'shape', 'object', 'food', 'artifact']
# story : ['communication', 'artifact']
# going : ['act', 'event']
# knock : ['event', 'cognition', 'act']
# creation : ['act', 'artifact', 'event', 'object']
# wipe : ['act']
# cuff : ['artifact']
# use : ['act', 'attribute', 'process']
# fortune : ['phenomenon', 'possession', 'state']
# check : ['possession', 'cognition', 'communication', 'state', 'act', 'attribute', 'artifact']
# ordinary : ['person', 'state', 'artifact']
# last : ['time', 'relation', 'act', 'quantity', 'event', 'artifact']
# back : ['body', 'artifact', 'location', 'person', 'act']
# large : ['attribute']
# thermometer : ['artifact']
# barometer : ['artifact']
# sorrow : ['feeling', 'cognition', 'state']
# improvement : ['event', 'act', 'state']
# mercury : ['substance', 'person', 'object', 'attribute']
# plain : ['object', 'artifact']
# world : ['object', 'group', 'cognition', 'animal']
# soul : ['person', 'Tops', 'feeling', 'act', 'communication']
# leave : ['time', 'communication', 'act']
# moment : ['time', 'attribute', 'phenomenon', 'cognition']
# saw : ['communication', 'artifact']
# tell : ['person']
# bellow : ['communication', 'person']
# rage : ['feeling', 'state', 'cognition']
# agony : ['feeling', 'state']
# cessation : ['event']
# general : ['person', 'cognition']
# hell : ['location', 'event', 'cognition', 'act']
# trimming : ['act', 'artifact']
# sign : ['communication', 'artifact', 'location', 'state', 'relation', 'event']
# space : ['Tops', 'shape', 'location', 'communication', 'time', 'artifact']
# giant : ['animal', 'person', 'group', 'object']
# nobody : ['person']
# wink : ['time', 'communication', 'act']
# sufferer : ['person']
# end : ['location', 'time', 'event', 'cognition', 'state', 'person', 'act', 'communication', 'artifact']
# snatch : ['communication', 'body', 'act']
# rest : ['relation', 'act', 'time', 'state', 'artifact', 'communication']
# entire : ['animal']
# crew : ['group']
# effort : ['act']
# effect : ['phenomenon', 'attribute', 'cognition', 'communication', 'state']
# ship : ['artifact']
# gooseberry : ['plant', 'food']
# shot : ['act', 'artifact', 'state', 'person', 'communication', 'quantity', 'cognition']
# cocoa : ['food']
# resource : ['possession', 'attribute', 'cognition']
# appearing : ['act']
# heroic : ['communication']
# left : ['location', 'group', 'body', 'artifact', 'act']
# dear : ['person']
# tremble : ['act']
# duty : ['act', 'possession']
# unfolding : ['process']
# queen : ['animal', 'person', 'artifact']
# handkerchief : ['artifact']
# quick : ['body']
# shed : ['artifact']
# object : ['Tops', 'cognition', 'communication']
# minister : ['person', 'act']
# fashion : ['attribute', 'act', 'cognition', 'artifact']
# narrator : ['person']
# struggle : ['act']
# boy : ['person']
# carrot : ['plant', 'food', 'act']
# litter : ['group', 'substance', 'artifact']
# bottom : ['location', 'body', 'time', 'object', 'artifact']
# silence : ['state', 'attribute']
# still : ['artifact', 'attribute']
# sun : ['object', 'phenomenon', 'person', 'time']
# blot : ['attribute', 'act']
# fire : ['event', 'act', 'process', 'artifact', 'substance', 'feeling', 'communication']
# western : ['communication', 'food']
# horizon : ['location', 'attribute']
# office : ['artifact', 'group', 'act', 'state']
# human : ['animal']
# kindness : ['attribute', 'act']
# sinking : ['event', 'feeling']
# tusk : ['substance', 'animal']
# faithful : ['group']
# heavy : ['person', 'cognition']
# groan : ['communication']
# editor : ['person', 'communication']
# opposition : ['act', 'relation', 'person', 'group']
# paper : ['substance', 'communication', 'group', 'artifact']
# tomorrow : ['time']
# smacking : ['act']
# body : ['body', 'group', 'object', 'attribute', 'communication', 'artifact']
# stuff : ['substance', 'artifact', 'possession', 'communication', 'attribute', 'cognition']
# sigh : ['communication', 'event']
# spirit : ['person', 'state', 'attribute', 'communication']
# think : ['cognition']
# operation : ['state', 'act', 'process', 'cognition']
# carcass : ['animal']
# leeward : ['relation', 'location']
# flat : ['object', 'artifact', 'communication']
# surface : ['artifact', 'location', 'object', 'cognition']
# faint : ['event']
# cry : ['communication', 'event']
# arm : ['body', 'artifact', 'group']
# folk : ['group', 'communication']
# luck : ['state', 'phenomenon']
# book : ['communication', 'artifact', 'possession', 'group']
# jotting : ['communication']
# much : ['quantity']
# strike : ['act', 'event']
# glance : ['act']
# true : ['attribute']
# satisfaction : ['feeling', 'state', 'possession', 'act']
# photograph : ['artifact']
# sketch : ['artifact', 'communication']
# heroine : ['person']
# honor : ['communication', 'state', 'attribute']
# shaking : ['act', 'state']
# telling : ['communication']
# trade : ['act', 'group', 'phenomenon']
# place : ['location', 'cognition', 'act', 'state', 'communication']
# president : ['person', 'act']
# muscle : ['body', 'person', 'attribute']
# moisture : ['state']
# member : ['person', 'relation', 'body', 'group']
# audience : ['group', 'state', 'communication']
# male : ['animal', 'person', 'location']
# earshot : ['location']
# victim : ['person']
# symptom : ['state', 'communication']
# listening : ['act']
# stage : ['time', 'state', 'artifact', 'communication', 'act', 'location']
# preservation : ['act', 'state', 'process', 'event']
# conviction : ['cognition', 'act']
# brass : ['substance', 'artifact', 'group', 'attribute']
# coaming : ['artifact']
# gray : ['attribute', 'artifact', 'group', 'animal', 'quantity', 'person']
# beard : ['body', 'plant', 'person', 'animal']
# keen : ['communication']
# peak : ['quantity', 'time', 'state', 'location', 'shape', 'artifact']
# aperture : ['artifact', 'object']
# harbor : ['location', 'artifact']
# custom : ['act', 'cognition', 'possession']
# house : ['artifact', 'group', 'act', 'location']
# u : ['substance', 'communication']
# majority : ['attribute', 'quantity', 'time']
# occupant : ['person']
# newspaper : ['communication', 'group', 'artifact', 'substance']
# permit : ['communication', 'act', 'animal']
# reporter : ['person']
# hat : ['artifact', 'act']
# favor : ['act', 'attribute', 'cognition', 'feeling', 'artifact']
# connection : ['relation', 'state', 'artifact', 'person', 'cognition', 'shape', 'act']
# occurrence : ['event', 'state']
# beginning : ['event', 'time', 'cognition', 'location', 'act']
# choking : ['state', 'act']
# snort : ['communication']
# hearing : ['act', 'state', 'location', 'communication', 'cognition']
# damage : ['event', 'act', 'possession']
# piping : ['artifact', 'act']
# length : ['attribute', 'artifact']
# course : ['act', 'group', 'location', 'object', 'food', 'artifact']
# show : ['act', 'communication']
# collision : ['event', 'communication']
# smiling : ['communication']
# stranger : ['person']
# brain : ['body', 'cognition', 'person', 'food']
# surmise : ['communication']
# go : ['time', 'artifact', 'act']
# evidence : ['cognition', 'communication']
# mustache : ['body']
# noise : ['event', 'cognition', 'communication', 'attribute']
# storage : ['act', 'artifact', 'process']
# chamber : ['artifact', 'body', 'group']
# gear : ['artifact']
# let : ['group', 'act']
# square : ['shape', 'quantity', 'location', 'person', 'artifact']
# glide : ['communication', 'act']
# engine : ['artifact', 'phenomenon']
# fluid : ['substance']
# channel : ['communication', 'artifact', 'shape', 'object', 'body', 'act']
# yorkshire : ['location']
# geology : ['cognition']
# soil : ['state', 'substance', 'object', 'location']
# liar : ['person']
# galahad : ['person']
# ranking : ['state']
# grilling : ['act']
# july : ['time']
# lilac : ['plant']
# envelope : ['artifact', 'shape', 'object', 'attribute']
# sprawling : ['attribute']
# plenty : ['attribute', 'quantity']
# violet : ['plant', 'attribute']
# ink : ['substance', 'body']
# missive : ['communication']
# smelt : ['food', 'animal']
# rhine : ['person', 'object']
# bore : ['person', 'event', 'attribute', 'artifact']
# monogram : ['communication']
# initial : ['communication']
# invitation : ['communication', 'attribute']
# country : ['group', 'location']
# mansion : ['location', 'artifact']
# lawn : ['location']
# reach : ['location', 'attribute', 'act', 'cognition']
# thames : ['object']
# blood : ['body', 'attribute', 'person', 'group']
# marriage : ['state', 'group', 'act']
# widow : ['person']
# thomson : ['person']
# kingdom : ['state', 'location', 'group']
# stout : ['food', 'attribute']
# stock : ['possession', 'artifact', 'group', 'food', 'state', 'plant', 'animal']
# upright : ['artifact']
# linen : ['artifact', 'substance']
# pig : ['animal', 'person', 'artifact']
# peach : ['plant', 'person', 'food', 'attribute']
# hobby : ['act', 'artifact', 'animal']
# seizure : ['state', 'act']
# weakness : ['state', 'attribute', 'feeling']
# city : ['location', 'group']
# european : ['person']
# entente : ['group', 'communication']
# bloom : ['process', 'plant', 'time', 'state', 'phenomenon']
# glove : ['artifact']
# grace : ['state', 'attribute', 'person', 'communication']
# kinsman : ['person']
# funeral : ['event']
# postscript : ['communication']
# letter : ['communication', 'person']
# absolute : ['cognition']
# confidence : ['cognition', 'feeling', 'state', 'communication']
# whole : ['cognition', 'Tops']
# future : ['time', 'communication', 'artifact']
# junior : ['person']
# fourth : ['relation', 'quantity', 'communication']
# battalion : ['group', 'quantity']
# royal : ['artifact', 'animal']
# regiment : ['group']
# pucker : ['shape']
# getting : ['act']
# summit : ['state', 'location', 'group']
# skull : ['body']
# receptacle : ['artifact', 'plant']
# possible : ['cognition', 'person']
# meaning : ['communication', 'cognition']
# appeal : ['communication', 'attribute', 'act']
# small : ['body', 'attribute']
# demeanor : ['attribute']
# led : ['artifact']
# acquaintance : ['cognition', 'state', 'person']
# earth : ['object', 'substance', 'location', 'cognition', 'artifact']
# waving : ['communication']
# direction : ['location', 'relation', 'cognition', 'communication', 'act']
# south : ['location', 'relation']
# africa : ['object']
# pump : ['artifact', 'body']
# poor : ['group']
# devil : ['person', 'communication']
# militiaman : ['person']
# detachment : ['feeling', 'act', 'state', 'group', 'event']
# territorial : ['person', 'group']
# fort : ['artifact']
# springbok : ['animal']
# river : ['object']
# transvaal : ['location']
# boer : ['person']
# relief : ['feeling', 'state', 'possession', 'person', 'act', 'time', 'event', 'artifact']
# necessary : ['object']
# fellow : ['person', 'quantity']
# kitchener : ['person']
# detail : ['cognition', 'relation', 'communication', 'group']
# bringing : ['act']
# bush : ['plant', 'location', 'group', 'person', 'body']
# veldt : ['location']
# crossing : ['act', 'object', 'location', 'artifact']
# enemy : ['group', 'person']
# sharpshooter : ['person', 'artifact']
# chased : ['person']
# picket : ['person', 'group', 'artifact', 'act']
# despatch : ['communication', 'attribute', 'act']
# army : ['group']
# mule : ['animal', 'artifact']
# trample : ['event']
# truth : ['cognition', 'state', 'communication', 'attribute', 'person']
# absence : ['state', 'act', 'time']
# power : ['attribute', 'phenomenon', 'cognition', 'state', 'person', 'communication', 'group']
# orderly : ['person']
# suitcase : ['artifact']
# gladstone : ['person', 'artifact']
# label : ['communication', 'substance']
# found : ['possession']
# omnibus : ['communication', 'artifact']
# automobile : ['artifact']
# luggage : ['artifact']
# tender : ['possession', 'person', 'communication', 'artifact']
# waiting : ['act']
# junction : ['artifact', 'state', 'shape', 'act']
# comparing : ['act']
# dimension : ['attribute', 'cognition']
# vehicle : ['artifact', 'communication', 'substance', 'object']
# size : ['attribute', 'substance', 'state']
# guest : ['person', 'artifact']
# package : ['group', 'artifact', 'communication']
# store : ['artifact', 'possession']
# hamper : ['artifact']
# champagne : ['food', 'location']
# regent : ['person']
# street : ['artifact', 'state', 'group']
# firm : ['group']
# bandbox : ['artifact']
# mammoth : ['animal']
# proportion : ['relation', 'attribute', 'shape']
# dressmaker : ['person']
# cardboard : ['substance']
# cover : ['artifact', 'act', 'object', 'possession']
# bearing : ['relation', 'location', 'attribute', 'artifact']
# signature : ['communication', 'attribute']
# bereavement : ['state']
# recent : ['time']
# bachelor : ['person']
# type : ['cognition', 'person', 'group', 'communication', 'artifact']
# notion : ['cognition', 'artifact']
# extent : ['state', 'attribute']
# mourner : ['person']
# even : ['time']
# clothes : ['artifact']
# concession : ['communication']
# feminine : ['communication']
# idiosyncrasy : ['attribute']
# chauffeur : ['person']
# reaching : ['act']
# pardon : ['act', 'communication']
# fetch : ['act']
# furrow : ['artifact', 'shape']
# mechanic : ['person']
# wearing : ['process', 'act']
# waterproof : ['artifact']
# groom : ['person']
# alertness : ['cognition', 'state', 'attribute']
# civility : ['attribute', 'act']
# cottage : ['artifact']
# cot : ['artifact']
# question : ['communication', 'attribute']
# edge : ['location', 'shape', 'artifact', 'attribute']
# landlord : ['person']
# local : ['artifact']
# hotel : ['artifact']
# couple : ['group', 'quantity', 'object']
# give : ['attribute']
# lift : ['act', 'phenomenon', 'event', 'artifact']
# spoke : ['artifact']
# archway : ['artifact']
# platform : ['artifact', 'communication']
# suit : ['artifact', 'act', 'person', 'communication']
# sleeve : ['artifact']
# pink : ['attribute', 'plant', 'person']
# altitude : ['attribute', 'shape', 'relation']
# six : ['quantity', 'artifact']
# high : ['attribute', 'state', 'location', 'group', 'artifact']
# droop : ['shape']
# chest : ['body', 'artifact']
# narrow : ['object']
# hullo : ['communication']
# watson : ['person']
# tall : ['attribute']
# newcomer : ['person']
# stare : ['act']
# coming : ['act', 'attribute']
# raising : ['event', 'attribute', 'act']
# politeness : ['attribute', 'act']
# inside : ['location']
# drove : ['group', 'artifact']
# hold : ['act', 'cognition', 'attribute', 'time', 'state', 'artifact']
# rank : ['group', 'state']
# majesty : ['attribute']
# shy : ['act']
# thorax : ['body', 'animal']
# instructor : ['person']
# musketry : ['group', 'cognition']
# shrink : ['person']
# schooling : ['act', 'cognition']
# youth : ['person', 'group', 'time', 'state', 'attribute']
# amenity : ['attribute']
# breeding : ['attribute', 'act']
# le : ['state']
# kernel : ['plant', 'cognition']
# roomy : ['person']
# shell : ['artifact', 'substance', 'animal', 'plant', 'object']
# familiar : ['person']
# landscape : ['location', 'artifact', 'cognition']
# pleasure : ['feeling', 'cognition', 'act']
# driver : ['person', 'communication', 'artifact']
# risk : ['state', 'act', 'attribute']
# steep : ['object']
# hill : ['object', 'artifact', 'person']
# signboard : ['artifact']
# crimson : ['attribute']
# facility : ['artifact', 'cognition', 'attribute', 'act']
# exercise : ['act', 'event']
# talent : ['cognition', 'person']
# breath : ['act', 'substance', 'time', 'communication', 'phenomenon']
# dwelling : ['artifact']
# guide : ['person', 'communication', 'cognition', 'artifact']
# villa : ['person', 'artifact']
# sat : ['time']
# meadow : ['location']
# croquet : ['act']
# garden : ['artifact', 'group']
# pug : ['animal']
# poodle : ['animal']
# dog : ['animal', 'person', 'food', 'artifact']
# greeting : ['communication']
# butler : ['person']
# elderly : ['group']
# frill : ['body', 'artifact']
# whisker : ['quantity', 'animal']
# adornment : ['artifact', 'act']
# variety : ['group', 'attribute', 'communication', 'cognition']
# howling : ['communication']
# ape : ['animal', 'person']
# door : ['artifact', 'attribute']
# letting : ['possession']
# avalanche : ['event']
# pomeranian : ['animal']
# persian : ['person', 'communication']
# cat : ['animal', 'person', 'artifact', 'act']
# sofa : ['artifact']
# weed : ['plant', 'artifact']
# sweet : ['person', 'food', 'cognition', 'attribute']
# admiration : ['feeling', 'act']
# assurance : ['cognition', 'communication', 'possession']
# best : ['act', 'person']
# squeeze : ['act', 'state', 'possession', 'person', 'event']
# look : ['attribute', 'act', 'state']
# saying : ['communication']
# wobble : ['event']
# past : ['time', 'communication']
# lean : ['attribute']
# station : ['artifact', 'state', 'location', 'attribute']
# sitting : ['act', 'group', 'communication']
# serge : ['artifact']
# leg : ['body', 'artifact', 'shape', 'food', 'act']
# giggle : ['communication']
# lasher : ['person']
# yellow : ['attribute']
# ceiling : ['artifact', 'attribute', 'communication']
# terseness : ['communication']
# burst : ['act', 'event']
# peal : ['event']
# rippling : ['event']
# laughter : ['communication', 'act']
# clear : ['state', 'location']
# perfect : ['relation']
# de : ['location']
# entrance : ['artifact', 'event', 'act']
# original : ['artifact', 'cognition']
# pair : ['group', 'quantity']
# theodosius : ['person']
# ambrose : ['person']
# tea : ['food', 'plant', 'group']
# leaving : ['act']
# frame : ['artifact', 'body', 'time', 'communication', 'cognition', 'act']
# mind : ['cognition', 'person']
# encounter : ['act', 'event', 'communication']
# dislike : ['cognition', 'feeling']
# bounder : ['person']
# discovery : ['act', 'communication', 'cognition']
# loathing : ['feeling']
# duplicate : ['artifact']
# stiff : ['person', 'body']
# jerky : ['food']
# response : ['phenomenon', 'act', 'communication', 'attribute']
# advance : ['event', 'communication', 'act', 'possession']
# twin : ['person', 'object', 'artifact']
# opposite : ['communication', 'relation', 'person']
# aside : ['communication']
# parent : ['person', 'Tops']
# penny : ['quantity', 'possession']
# eyebrow : ['body']
# greek : ['communication', 'person']
# outline : ['location', 'communication', 'cognition']
# public : ['group']
# advantage : ['attribute', 'quantity']
# rich : ['group']
# son : ['person']
# cachet : ['communication', 'artifact']
# notice : ['communication', 'cognition']
# lower : ['artifact']
# button : ['artifact', 'plant', 'communication', 'body']
# waistcoat : ['artifact']
# men : ['group', 'person', 'animal', 'location', 'artifact']
# tenderness : ['attribute', 'state', 'feeling']
# cake : ['artifact', 'food']
# strawberry : ['food', 'plant', 'attribute']
# greed : ['attribute', 'act']
# manner : ['attribute', 'cognition']
# meet : ['event']
# characteristic : ['cognition', 'attribute', 'communication']
# common : ['location']
# grand : ['quantity', 'artifact']
# family : ['group', 'person']
# proprietorship : ['possession']
# father : ['person']
# age : ['attribute', 'time']
# opening : ['object', 'event', 'act', 'state', 'communication', 'cognition', 'body', 'artifact']
# life : ['state', 'cognition', 'time', 'person', 'attribute', 'Tops', 'phenomenon', 'communication', 'motive']
# find : ['cognition', 'act']
# sarcasm : ['communication']
# increase : ['quantity', 'event', 'process', 'attribute', 'act']
# difficulty : ['act', 'cognition', 'state', 'attribute']
# talk : ['communication', 'act']
# capacity : ['attribute', 'state', 'quantity', 'act', 'phenomenon', 'cognition']
# nature : ['attribute', 'person', 'object', 'cognition']
# bite : ['state', 'food', 'event', 'communication', 'attribute', 'act']
# tail : ['animal', 'time', 'shape', 'body', 'person', 'artifact']
# cherry : ['plant', 'food', 'attribute']
# bell : ['artifact', 'event', 'time', 'shape', 'person']
# married : ['person']
# eighteen : ['quantity']
# noble : ['person']
# awakening : ['act']
# chord : ['shape', 'communication']
# passion : ['feeling', 'attribute', 'state', 'motive', 'cognition']
# help : ['act', 'person', 'attribute']
# happiness : ['state', 'feeling']
# company : ['group', 'state', 'person']
# bacon : ['food', 'person']
# summer : ['time']
# month : ['time']
# emphasis : ['state', 'attribute', 'communication']
# italic : ['communication']
# sense : ['cognition', 'communication']
# humor : ['communication', 'attribute', 'feeling', 'body']
# predilection : ['cognition', 'feeling']
# ride : ['act', 'artifact']
# drive : ['act', 'artifact', 'attribute', 'state']
# horse : ['animal', 'artifact', 'group']
# gardener : ['person']
# advice : ['communication']
# launch : ['artifact', 'act']
# play : ['communication', 'act', 'state', 'time', 'event', 'attribute']
# tennis : ['act']
# dinner : ['food', 'group']
# deceased : ['person']
# evening : ['time']
# garb : ['artifact']
# home : ['location', 'artifact', 'state', 'group']
# dish : ['artifact', 'food', 'quantity', 'person', 'act']
# ravaging : ['act']
# bonbon : ['food']
# dessert : ['food']
# calling : ['act']
# connoisseurship : ['cognition']
# gad : ['state', 'artifact']
# servant : ['person', 'state']
# ant : ['animal']
# miss : ['person', 'event', 'communication']
# attack : ['act', 'communication', 'state', 'process']
# chosen : ['person', 'location', 'group']
# try : ['act']
# liqueur : ['food']
# quality : ['attribute', 'cognition', 'state']
# winding : ['act']
# arcade : ['artifact']
# glimmering : ['cognition']
# shining : ['act']
# leaf : ['plant', 'communication', 'artifact']
# least : ['cognition']
# heart : ['cognition', 'body', 'attribute', 'location', 'shape', 'food', 'feeling', 'artifact']
# jog : ['shape', 'act']
# interrogation : ['communication']
# aching : ['state']
# neighbor : ['person', 'object']
# county : ['location']
# conduct : ['act', 'attribute']
# weeper : ['person']
# deposit : ['phenomenon', 'object', 'process', 'possession', 'communication', 'artifact', 'act']
# woe : ['state', 'feeling']
# portrait : ['communication', 'artifact']
# scowl : ['communication']
# bed : ['artifact', 'object', 'location']
# bower : ['artifact']
# front : ['location', 'cognition', 'artifact', 'person', 'state', 'phenomenon', 'group']
# porch : ['artifact']
# pillow : ['artifact']
# infernal : ['person']
# lunch : ['food']
# add : ['state']
# watch : ['artifact', 'time', 'act', 'person']
# slumber : ['state']
# eyelid : ['body']
# iteration : ['process', 'act']
# domino : ['person', 'artifact']
# dream : ['cognition', 'feeling', 'state']
# reader : ['person', 'communication']
# nerve : ['body', 'attribute']
# lace : ['artifact']
# peekaboo : ['act']
# description : ['communication', 'cognition']
# coffee : ['food', 'plant', 'attribute']
# breakfast : ['food']
# headache : ['cognition', 'state']
# sunshade : ['artifact']
# nook : ['location', 'artifact']
# hammock : ['object', 'artifact']
# installing : ['act']
# husband : ['person']
# repose : ['act', 'feeling', 'attribute']
# lying : ['act']
# counting : ['act']
# ripening : ['process']
# plum : ['plant', 'food', 'act']
# dangling : ['act']
# branch : ['group', 'plant', 'shape', 'phenomenon', 'object', 'artifact']
# bidding : ['communication']
# movement : ['act', 'event', 'group', 'communication', 'phenomenon', 'process', 'cognition', 'artifact']
# workhouse : ['artifact']
# supply : ['quantity', 'process', 'act']
# need : ['state', 'object', 'Tops']
# express : ['communication', 'artifact', 'act']
# knitting : ['artifact', 'act']
# hue : ['attribute']
# blonde : ['person', 'attribute']
# bargain : ['communication', 'possession']
# orphan : ['person', 'communication', 'animal']
# distemper : ['state', 'feeling', 'artifact', 'act']
# pinkness : ['attribute']
# nostril : ['body']
# sunshine : ['phenomenon', 'attribute']
# presence : ['state', 'location', 'person', 'cognition', 'attribute', 'act']
# dark : ['state', 'location', 'time', 'cognition']
# cloud : ['phenomenon', 'object', 'state', 'group']
# tom : ['person', 'animal']
# brace : ['artifact', 'quantity', 'group', 'communication']
# climbing : ['event']
# afterthought : ['cognition', 'artifact']
# trustee : ['person']
# executor : ['person']
# bound : ['shape', 'location', 'attribute', 'act']
# income : ['possession']
# five : ['quantity', 'group', 'artifact']
# hundred : ['quantity']
# pocket : ['artifact', 'shape', 'possession', 'phenomenon', 'group', 'body']
# service : ['act', 'group', 'person', 'attribute', 'artifact']
# adoption : ['act']
# plan : ['cognition', 'artifact']
# relative : ['person', 'animal']
# gather : ['artifact', 'act']
# arrangement : ['cognition', 'group', 'attribute', 'communication', 'act']
# ideal : ['cognition', 'person']
# prof : ['person']
# value : ['cognition', 'attribute', 'possession', 'time']
# judgment : ['cognition', 'act', 'communication', 'attribute']
# friend : ['person']
# cease : ['time']
# visiting : ['act']
# list : ['communication', 'attribute']
# society : ['group', 'state']
# treat : ['food', 'event']
# turn : ['shape', 'act', 'event', 'time', 'communication']
# innocence : ['attribute', 'state']
# speaking : ['communication']
# blush : ['state', 'act']
# tone : ['communication', 'attribute', 'state', 'cognition']
# reproach : ['communication', 'state']
# shade : ['state', 'attribute', 'artifact', 'communication', 'quantity', 'cognition']
# anger : ['feeling', 'state', 'act']
# due : ['attribute', 'possession']
# toot : ['event', 'act']
# scuffle : ['act', 'artifact']
# whirr : ['event']
# brake : ['artifact', 'plant', 'group']
# locomotive : ['artifact']
# avenue : ['act', 'artifact']
# gate : ['artifact', 'possession']
# agility : ['attribute']
# girlhood : ['time']
# stalking : ['act']
# grass : ['plant', 'person', 'food', 'artifact']
# gesture : ['act', 'communication']
# darling : ['person', 'object']
# kiss : ['act', 'food']
# mummy : ['person', 'body']
# uncle : ['person']
# yell : ['communication']
# train : ['artifact', 'group', 'event']
# infatuation : ['feeling', 'cognition']
# grinning : ['communication']
# america : ['location', 'object']
# jaw : ['body', 'artifact']
# gullet : ['body']
# benefactress : ['person']
# bone : ['body', 'substance', 'attribute']
# astonishment : ['feeling']
# necessity : ['state', 'object']
# restraint : ['act', 'attribute', 'state', 'cognition', 'artifact']
# defense : ['act', 'group', 'communication', 'process', 'artifact']
# quarter : ['quantity', 'location', 'time', 'relation', 'possession', 'person', 'artifact', 'act']
# roof : ['artifact', 'object', 'communication']
# change : ['event', 'relation', 'act', 'phenomenon', 'possession', 'artifact', 'attribute']
# instant : ['time']
# summons : ['communication']
# native : ['person', 'Tops']
# aid : ['attribute', 'act', 'possession']
# walking : ['act']
# perspective : ['cognition', 'attribute']
# september : ['time']
# shooting : ['act']
# partridge : ['food', 'animal']
# cork : ['substance', 'location', 'artifact']
# mystery : ['cognition', 'communication']
# trouble : ['cognition', 'event', 'act', 'feeling', 'state']
# cambric : ['artifact']
# feature : ['cognition', 'body', 'communication', 'artifact']
# regret : ['feeling']
# bad : ['attribute']
# scorn : ['feeling', 'communication']
# action : ['act', 'state', 'process', 'communication', 'attribute', 'artifact']
# secret : ['communication', 'cognition']
# gush : ['event', 'communication']
# idea : ['cognition', 'communication']
# feeling : ['Tops', 'cognition', 'state']
# sob : ['state', 'person', 'act']
# beggar : ['person']
# trembling : ['state']
# fist : ['body']
# folly : ['attribute', 'act', 'cognition']
# madness : ['state', 'feeling', 'cognition', 'attribute']
# masculine : ['communication']
# upbraiding : ['communication']
# reason : ['motive', 'communication', 'cognition', 'state']
# upbraider : ['person']
# sweetness : ['cognition', 'attribute']
# realization : ['cognition', 'act', 'communication']
# shock : ['feeling', 'act', 'state', 'event', 'group', 'artifact']
# deed : ['communication', 'Tops']
# settlement : ['group', 'communication', 'act', 'cognition', 'location']
# armchair : ['artifact']
# blow : ['act', 'event', 'phenomenon', 'artifact']
# fell : ['substance', 'artifact', 'act']
# whisper : ['communication', 'event']
# pale : ['artifact']
# interview : ['communication']
# conservatory : ['group', 'artifact']
# private : ['person']
# pavilion : ['artifact']
# shedding : ['process', 'phenomenon']
# heir : ['person']
# poison : ['substance', 'attribute']
# shoot : ['plant', 'act']
# swim : ['act']
# rising : ['event', 'act']
# dive : ['artifact', 'act', 'person']
# bride : ['person']
# england : ['location']
# law : ['group', 'communication', 'cognition', 'act']
# foolishness : ['attribute', 'cognition', 'act']
# set : ['group', 'act', 'artifact', 'cognition', 'time', 'process', 'person', 'event']
# tale : ['communication']
# absurd : ['state']
# dignity : ['attribute', 'state']
# scandalmonger : ['person']
# regaining : ['act']
# ground : ['object', 'motive', 'substance', 'relation', 'location', 'cognition', 'artifact']
# impasse : ['state', 'artifact']
# embrace : ['act', 'state']
# remains : ['object', 'body']
# promise : ['communication', 'cognition']
# occasion : ['event', 'motive', 'time', 'state']
# act : ['communication', 'Tops']
# character : ['person', 'cognition', 'attribute', 'state', 'communication']
# break : ['event', 'object', 'act', 'time', 'state']
# news : ['communication', 'attribute']
# stinging : ['state']
# malacca : ['plant', 'artifact']
# cane : ['artifact', 'plant']
# thompson : ['person']
# collection : ['group', 'communication', 'act']
# hall : ['artifact', 'person']
# tenth : ['quantity', 'relation']
# biennial : ['plant']
# visit : ['act', 'group']
# da : ['person']
# capo : ['person']
# opera : ['communication', 'artifact']
# combination : ['group', 'act']
# musical : ['communication']
# tent : ['artifact', 'object']
# wont : ['cognition']
# crown : ['communication', 'body', 'artifact', 'possession', 'plant', 'location']
# diamond : ['possession', 'substance', 'shape', 'artifact']
# chef : ['person']
# grief : ['feeling', 'cognition']
# british : ['person']
# stomach : ['body', 'feeling']
# joy : ['feeling', 'cognition']
# song : ['communication', 'event', 'act', 'possession', 'group']
# cosmopolitan : ['person']
# gift : ['possession', 'cognition', 'act']
# prime : ['quantity', 'time']
# donne : ['person']
# tenor : ['communication', 'attribute', 'person', 'cognition']
# basso : ['person', 'communication']
# revel : ['act']
# national : ['person']
# palate : ['body']
# mass : ['attribute', 'quantity', 'group', 'act', 'object', 'communication']
# polenta : ['food']
# borsch : ['food']
# sausage : ['food', 'artifact']
# ragout : ['food']
# ...
# mix : ['food', 'event', 'act']
# rubens : ['person']
# academy : ['group', 'artifact']
# bold : ['communication']
# catching : ['act']
# dripping : ['event']
# cobalt : ['substance']
# pasture : ['location', 'food']
# sprig : ['plant', 'artifact']
# learning : ['cognition']
# beech : ['plant']
# preference : ['feeling', 'cognition', 'attribute']
# socket : ['body', 'artifact']
# retina : ['body']
# buffet : ['artifact', 'food']
# traitor : ['person']
# rustic : ['person']
# firing : ['act']
# legislator : ['person']
# railing : ['artifact']
# pedestrian : ['person']
# camphor : ['substance']
# sealskin : ['substance', 'artifact']
# chinchilla : ['substance', 'artifact', 'animal']
# fox : ['animal', 'person', 'substance', 'communication']
# stream : ['object', 'group', 'act', 'state', 'event']
# chrysanthemum : ['plant']
# technical : ['artifact', 'act']
# biologist : ['person']
# chamois : ['substance', 'animal']
# picking : ['quantity', 'act']
# warship : ['artifact']
# squadron : ['group']
# radioactivity : ['process']
# radium : ['substance']
# chloride : ['substance']
# ton : ['quantity']
# uranium : ['substance']
# ore : ['substance', 'quantity']
# residue : ['substance', 'relation']
# fifteen : ['quantity']
# carbonate : ['substance']
# dissolving : ['process']
# acid : ['substance', 'artifact']
# actinium : ['substance']
# barium : ['substance']
# olive : ['plant', 'food', 'attribute']
# planet : ['object', 'person']
# riposte : ['communication', 'act']
# sincerity : ['feeling', 'attribute']
# tissue : ['body', 'substance']
# deterioration : ['state', 'process']
# microbe : ['animal']
# metchnikoff : ['person']
# atrophy : ['state', 'event']
# senility : ['time', 'attribute']
# limousine : ['artifact']
# gliding : ['act']
# turnout : ['group', 'artifact', 'act']
# shimmer : ['event']
# science : ['cognition']
# stanhope : ['artifact']
# ninon : ['artifact']
# contrary : ['relation']
# rejoinder : ['communication']
# iris : ['plant', 'body', 'artifact']
# progeny : ['person']
# observation : ['act', 'communication', 'cognition']
# illusion : ['cognition', 'act']
# motherhood : ['relation']
# puzzle : ['communication', 'artifact']
# vegetarian : ['person']
# tax : ['possession']
# laboratory : ['artifact', 'location']
# phenomenon : ['Tops', 'event']
# evolution : ['process']
# protium : ['plant']
# dwarf : ['person', 'Tops']
# evergreen : ['plant']
# furnace : ['artifact']
# scale : ['relation', 'plant', 'object', 'communication', 'artifact', 'animal']
# jar : ['artifact', 'quantity', 'event']
# flask : ['artifact', 'quantity']
# handful : ['quantity']
# wheat : ['plant', 'food', 'attribute']
# beetle : ['animal', 'artifact']
# proboscis : ['body', 'animal']
# weevil : ['animal']
# feed : ['food']
# cleaner : ['artifact', 'person']
# sounder : ['artifact']
# grub : ['food', 'animal']
# monotone : ['communication']
# hatch : ['process', 'attribute', 'artifact']
# handling : ['act']
# electron : ['object']
# growth : ['process', 'group', 'event', 'state', 'object']
# disciple : ['person']
# tigress : ['animal']
# jungle : ['location', 'group']
# experiment : ['act', 'cognition']
# piper : ['person', 'plant']
# bulb : ['plant', 'artifact', 'shape', 'body']
# receiver : ['artifact', 'person']
# convulsion : ['state', 'event']
# syncope : ['event', 'communication']
# employ : ['state']
# apparatus : ['artifact', 'body']
# nineteen : ['quantity']
# plural : ['communication']
# dowdy : ['person', 'food']
# potentiality : ['state', 'cognition']
# manhood : ['state', 'attribute', 'act']
# flowing : ['event']
# conspiracy : ['communication', 'cognition', 'group']
# approach : ['act', 'artifact', 'location', 'event', 'communication', 'attribute']
# organic : ['substance']
# coast : ['object', 'cognition', 'act']
# perambulator : ['artifact']
# delusion : ['state', 'cognition', 'act']
# forenoon : ['time']
# lunching : ['act']
# viand : ['food']
# esplanade : ['artifact']
# soundness : ['state', 'attribute']
# gravel : ['substance']
# begging : ['communication']
# cipher : ['communication', 'quantity', 'person']
# haste : ['attribute', 'act', 'state']
# thrusting : ['act']
# poker : ['artifact', 'act']
# travesty : ['communication']
# ace : ['quantity', 'artifact', 'person', 'substance', 'group', 'act']
# superfluity : ['attribute']
# fastening : ['artifact', 'act']
# echo : ['attribute', 'person', 'communication', 'act']
# moneylender : ['person']
# cavalry : ['group']
# writ : ['communication']
# dragoon : ['person']
# aristocrat : ['person']
# warrant : ['communication', 'possession']
# cape : ['object', 'artifact']
# packet : ['group', 'communication', 'artifact']
# errand : ['act']
# blackmailer : ['person']
# usurer : ['person']
# endeavor : ['act']
# brighton : ['location']
# fuel : ['substance']
# physiognomy : ['body']
# minnow : ['animal']
# canal : ['object', 'body', 'artifact']
# stuart : ['person', 'group']
# slap : ['event', 'act']
# maker : ['person', 'group']
# salmo : ['animal']
# retirement : ['state', 'act']
# berkeley : ['person', 'location']
# blotter : ['substance', 'communication']
# footing : ['state', 'relation', 'artifact']
# formality : ['event', 'attribute', 'act']
# gall : ['state', 'plant', 'feeling', 'body', 'attribute']
# wormwood : ['plant']
# beach : ['object']
# spate : ['quantity', 'event']
# pool : ['artifact', 'object', 'group', 'possession', 'location', 'act']
# canteen : ['artifact']
# equipment : ['artifact']
# hatchet : ['artifact']
# gaudy : ['group']
# paroquet : ['animal']
# tyro : ['person']
# spoil : ['possession', 'act']
# dismay : ['feeling']
# camelia : ['plant']
# turndown : ['act']
# aquatic : ['plant']
# coracle : ['artifact']
# burden : ['cognition', 'artifact', 'communication']
# beginner : ['person']
# shore : ['object', 'artifact']
# paddle : ['artifact']
# punt : ['quantity', 'artifact', 'act']
# cuckoo : ['person', 'animal']
# riverside : ['object', 'location']
# boat : ['artifact']
# wader : ['animal']
# pier : ['artifact']
# manipulation : ['act']
# bowlder : ['object']
# proof : ['cognition', 'communication', 'quantity', 'artifact', 'act']
# spinning : ['act']
# hook : ['artifact', 'shape', 'cognition', 'act']
# wickerwork : ['artifact']
# notecase : ['artifact']
# goodby : ['communication']
# propagation : ['communication', 'act', 'phenomenon']
# rearing : ['attribute', 'act']
# culture : ['group', 'cognition', 'act', 'state']
# ambition : ['feeling', 'attribute']
# alexander : ['plant', 'person']
# cooter : ['animal']
# teacher : ['person', 'cognition']
# rear : ['group', 'location', 'body', 'artifact']
# multiplicity : ['attribute']
# prodigy : ['person', 'event', 'cognition']
# hireling : ['person']
# saratoga : ['animal', 'act']
# sociality : ['attribute']
# regimen : ['cognition']
# abbreviation : ['communication', 'act']
# maturity : ['time', 'state']
# greenfly : ['animal']
# camera : ['artifact']
# appellation : ['communication']
# countrywoman : ['person']
# repression : ['state', 'process', 'act']
# laundry : ['artifact']
# exile : ['person', 'act']
# reduction : ['act', 'process']
# desertion : ['act']
# cradle : ['artifact', 'location', 'time']
# inaugural : ['communication', 'act']
# frown : ['communication']
# reasoning : ['cognition']
# dribbling : ['act']
# doubling : ['process', 'act']
# caress : ['act']
# assuagement : ['feeling']
# petting : ['act']
# equivalent : ['cognition', 'attribute']
# maw : ['body']
# immaturity : ['state']
# deglutition : ['act']
# throwback : ['person', 'event']
# bearskin : ['substance', 'artifact']
# tertiary : ['time']
# softening : ['process']
# trumpet : ['artifact']
# cope : ['artifact']
# dug : ['animal']
# gymnastics : ['act']
# abacus : ['artifact']
# slate : ['artifact', 'substance', 'communication']
# skill : ['cognition']
# microscope : ['artifact']
# chart : ['communication', 'artifact']
# logbook : ['communication']
# data : ['group', 'cognition']
# disturbance : ['event', 'state', 'act']
# frequency : ['time', 'relation', 'quantity']
# heading : ['communication', 'location', 'artifact']
# attachment : ['feeling', 'artifact', 'communication', 'act']
# rusk : ['food']
# irregular : ['person', 'artifact']
# cube : ['shape', 'quantity', 'plant', 'artifact']
# texture : ['attribute', 'cognition']
# oral : ['communication']
# boredom : ['feeling']
# surroundings : ['state', 'location']
# intermediate : ['substance']
# contracting : ['act']
# incidental : ['possession', 'communication']
# croup : ['state', 'animal']
# kitten : ['animal']
# rhyme : ['communication']
# construction : ['act', 'communication', 'cognition', 'artifact']
# bunting : ['artifact', 'animal']
# rabbit : ['animal', 'substance', 'food']
# stratum : ['location', 'group', 'cognition']
# hudson : ['object', 'person']
# steamboat : ['artifact']
# mammy : ['person']
# liquor : ['food', 'substance']
# dis : ['person']
# balancing : ['act']
# bravo : ['person', 'communication']
# prow : ['artifact']
# depression : ['state', 'object', 'feeling', 'time', 'shape', 'relation', 'act']
# bumper : ['artifact']
# tablecloth : ['artifact']
# thump : ['event', 'act']
# comedian : ['person']
# mummer : ['person']
# protestant : ['person', 'group']
# ion : ['object']
# leapfrog : ['act']
# ram : ['artifact', 'person', 'location', 'animal']
# vat : ['possession', 'artifact']
# viscount : ['person']
# ahem : ['communication']
# ducky : ['person']
# lapsing : ['act']
# atlantic : ['object']
# trial : ['act', 'cognition', 'event']
# charger : ['animal', 'artifact']
# segment : ['artifact', 'object']
# morsel : ['quantity', 'food']
# courtyard : ['artifact']
# fossil : ['person', 'object']
# coulisse : ['artifact']
# deluge : ['quantity', 'phenomenon']
# hairdresser : ['person']
# soaring : ['act']
# bowel : ['body']
# marine : ['person']
# ache : ['state']
# netting : ['artifact', 'act']
# repository : ['artifact', 'person']
# necklace : ['artifact']
# brooch : ['artifact']
# lightship : ['artifact']
# mahogany : ['plant', 'attribute']
# mantel : ['artifact']
# feeder : ['animal', 'person', 'object', 'artifact']
# maintenance : ['act', 'possession']
# exigency : ['state', 'event']
# lemon : ['food', 'attribute', 'plant', 'cognition', 'artifact']
# panacea : ['person', 'artifact']
# alleviation : ['feeling', 'act']
# spine : ['body', 'shape', 'plant', 'artifact', 'animal']
# exercising : ['act']
# flyer : ['communication', 'person']
# flutter : ['act', 'state', 'event']
# tumult : ['state', 'feeling', 'act']
# notability : ['person']
# crop : ['plant', 'group', 'artifact', 'animal']
# india : ['location']
# orangutan : ['animal']
# mayor : ['person']
# corporation : ['group', 'body']
# freak : ['person']
# souvenir : ['artifact', 'cognition']
# hairdressing : ['artifact', 'act']
# jeweler : ['person']
# florist : ['person', 'artifact']
# fuller : ['person']
# palmist : ['person']
# goodness : ['attribute']
# roller : ['act', 'event', 'artifact', 'animal']
# headwind : ['phenomenon']
# render : ['substance']
# clutch : ['act', 'state', 'group', 'artifact']
# malady : ['state']
# crony : ['person']
# quoit : ['artifact']
# spear : ['artifact']
# westward : ['relation']
# shrine : ['artifact']
# miniature : ['artifact']
# suck : ['act']
# benefit : ['possession', 'attribute', 'communication']
# tint : ['attribute']
# bouillon : ['food']
# plush : ['artifact']
# wrapper : ['artifact']
# surveying : ['act']
# recognition : ['state', 'cognition', 'communication', 'phenomenon', 'act']
# splash : ['event', 'state', 'quantity', 'attribute', 'act']
# undertaker : ['person']
# yellowbird : ['animal']
# bigamy : ['state', 'act']
# canary : ['person', 'attribute', 'animal']
# vengeance : ['act']
# corpse : ['body']
# injunction : ['communication']
# wasp : ['person', 'animal']
# wireless : ['communication', 'artifact']
# telegraphy : ['communication', 'artifact']
# vest : ['artifact']
# resurrection : ['event', 'act']
# narrative : ['communication']
# complement : ['communication', 'quantity', 'group', 'attribute', 'substance', 'cognition']
# hearthrug : ['artifact']
# accord : ['state', 'communication', 'attribute']
# thickening : ['substance', 'shape', 'act']
# jot : ['communication', 'quantity']
# feller : ['person']
# resultant : ['state', 'event', 'cognition']
# epoch : ['time']
# simile : ['communication']
# pimple : ['state']
# freshness : ['attribute', 'state', 'cognition']
# ethic : ['cognition', 'communication']
# crinoline : ['artifact']
# vitality : ['attribute', 'state', 'phenomenon']
# victorian : ['person']
# nutshell : ['plant']
# movable : ['possession']
# circumference : ['attribute', 'location']
# era : ['time', 'communication']
# panoply : ['group']
# chaise : ['artifact']
# contra : ['person']
# accident : ['event']
# dover : ['location']
# calais : ['location']
# paddlewheel : ['artifact']
# negligence : ['act', 'attribute']
# sandbank : ['object']
# rowing : ['act']
# birdcage : ['artifact']
# inertia : ['attribute', 'phenomenon']
# december : ['time']
# function : ['relation', 'attribute', 'act', 'group', 'event', 'communication']
# edifice : ['artifact']
# lily : ['plant']
# locket : ['artifact']
# isaac : ['person']
# ninety : ['quantity']
# nowhere : ['state']
# nonconformist : ['person']
# denomination : ['group', 'communication']
# rep : ['person', 'artifact']
# parrot : ['animal', 'person']
# spaniel : ['animal']
# madeira : ['object', 'location', 'food']
# sherry : ['food']
# smith : ['person']
# jones : ['person']
# robinson : ['person']
# psalm : ['communication']
# bulge : ['shape']
# tailcoat : ['artifact']
# item : ['communication', 'relation', 'artifact', 'cognition']
# etruscan : ['person']
# lookout : ['person', 'location', 'artifact', 'act']
# jointure : ['possession', 'act']
# moderate : ['person']
# array : ['group', 'communication', 'artifact']
# campaign : ['event', 'act']
# johnson : ['person']
# steal : ['possession', 'act']
# departed : ['person']
# project : ['act', 'cognition']
# boiling : ['process', 'act']
# gossiping : ['communication']
# district : ['location']
# burglary : ['act']
# tearing : ['process']
# feint : ['act']
# macaw : ['animal']
# dahlia : ['plant']
# partial : ['cognition']
# darkness : ['state', 'location', 'cognition', 'attribute']
# wax : ['substance']
# candle : ['artifact', 'quantity']
# candelabra : ['artifact']
# premise : ['communication']
# communicating : ['communication']
# spinster : ['person']
# rustle : ['event']
# triple : ['act', 'group', 'cognition']
# poplin : ['artifact']
# factor : ['event', 'cognition', 'quantity', 'person', 'body']
# shear : ['phenomenon', 'artifact']
# liberal : ['person']
# parliament : ['group', 'act']
# charlotte : ['location', 'food']
# reset : ['artifact']
# approaching : ['event', 'attribute', 'act']
# drinking : ['act']
# comprehension : ['cognition', 'relation']
# mushroom : ['plant', 'phenomenon', 'food']
# meredith : ['person']
# firework : ['artifact']
# chinese : ['communication', 'person']
# helpfulness : ['attribute']
# sandbag : ['artifact']
# eel : ['food', 'animal']
# normal : ['cognition']
# dumpling : ['food']
# railway : ['artifact']
# destiny : ['event', 'person', 'state']
# sur : ['location']
# tapis : ['artifact']
# repeat : ['event']
# wounded : ['group']
# cure : ['artifact']
# baroness : ['person']
# dy : ['substance']
# jubilee : ['time']
# baronetcy : ['state', 'communication']
# cockney : ['person', 'communication']
# thorn : ['cognition', 'plant', 'communication']
# hockey : ['act']
# finesse : ['attribute']
# greaser : ['person']
# cogwheel : ['artifact']
# hypocrite : ['person']
# plantagenet : ['group']
# intolerance : ['attribute', 'cognition']
# accidental : ['communication']
# monocle : ['artifact']
# warmth : ['cognition', 'feeling', 'attribute']
# intrigue : ['cognition', 'state']
# bicycling : ['act']
# stile : ['artifact']
# mounting : ['event', 'artifact']
# eatable : ['food']
# consumption : ['act', 'state', 'process']
# wolf : ['animal', 'person']
# stodge : ['food']
# chicken : ['food', 'animal', 'person', 'event']
# plunge : ['act', 'event']
# tinge : ['quantity', 'attribute']
# whispering : ['event', 'communication']
# breechloader : ['artifact']
# blaze : ['process', 'event', 'act', 'attribute']
# washstand : ['artifact']
# emphasizing : ['act']
# mixture : ['substance', 'food', 'group', 'event', 'act']
# crevice : ['shape', 'object']
# consolation : ['feeling', 'act']
# cruise : ['act']
# vexation : ['feeling', 'state', 'cognition', 'act']
# persistency : ['attribute']
# lisbon : ['location']
# twopence : ['possession']
# tentacle : ['attribute', 'animal']
# feeler : ['animal', 'communication', 'attribute']
# attending : ['cognition', 'act']
# awfulness : ['attribute']
# welsh : ['person', 'communication', 'animal']
# chine : ['food', 'animal']
# rung : ['artifact']
# pyjama : ['artifact']
# immodesty : ['attribute', 'act']
# entering : ['event', 'act']
# bulwark : ['artifact']
# mast : ['artifact', 'plant', 'food']
# chattering : ['event']
# carp : ['food', 'animal']
# currant : ['food', 'plant']
# au : ['substance', 'quantity']

# %%
verb_dic = {}
for verb in verbs:
    l = []
    for synset in wn.synsets(verb):
        if "verb" in synset.lexname():
            if synset.lexname()[5:] not in l:
                l.append(synset.lexname()[5:])
    verb_dic[verb] = l

for i in verb_dic:
    print(i,":", verb_dic[i])
# Out:
# board : ['motion', 'stative', 'consumption']
# created : ['creation', 'social']
# prevailed : ['stative', 'competition', 'communication']
# neck : ['contact']
# craned : ['body']
# toe : ['motion', 'contact']
# trodden : ['motion', 'contact', 'possession']
# steamer : ['motion']
# slackened : ['change']
# speed : ['motion', 'change']
# line : ['stative', 'contact', 'change']
# thrown : ['contact', 'motion', 'communication', 'creation', 'emotion', 'cognition']
# caught : ['cognition', 'perception', 'contact', 'motion', 'possession', 'competition', 'change', 'social', 'body', 'weather', 'emotion', 'creation']
# yacht : ['motion']
# pilot : ['motion']
# note : ['communication', 'perception']
# divested : ['possession', 'social', 'change']
# bearded : ['stative']
# countenance : ['communication']
# saluted : ['consumption', 'communication', 'perception']
# captain : ['social']
# taking : ['social', 'possession', 'motion', 'contact', 'change', 'cognition', 'stative', 'perception', 'communication', 'consumption', 'competition', 'body']
# proffered : ['possession']
# glass : ['possession', 'perception', 'contact', 'change']
# containing : ['stative', 'social', 'competition']
# concealed : ['perception']
# content : ['consumption', 'emotion']
# went : ['motion', 'social', 'change', 'stative', 'perception', 'contact', 'consumption', 'competition', 'cognition']
# officer : ['communication']
# bridge : ['stative', 'contact', 'motion']
# relieved : ['body', 'social', 'emotion', 'communication', 'possession', 'change']
# skipper : ['social']
# plunged : ['contact', 'motion', 'change', 'cognition']
# telegraph : ['communication']
# clicked : ['motion', 'perception', 'contact', 'communication', 'cognition']
# hulk : ['stative']
# quivered : ['motion']
# began : ['change', 'stative', 'communication', 'social']
# forge : ['creation', 'motion']
# man : ['social', 'competition']
# striped : ['contact', 'possession', 'body', 'change']
# introduced : ['communication', 'creation', 'change', 'motion', 'contact', 'cognition']
# second : ['social']
# press : ['contact', 'communication', 'stative', 'motion', 'creation', 'social', 'competition']
# pleased : ['emotion']
# know : ['cognition', 'contact']
# said : ['communication', 'stative']
# step : ['motion', 'social', 'possession', 'contact', 'change']
# order : ['communication', 'social', 'change', 'cognition']
# habit : ['body']
# hoisting : ['contact']
# afford : ['consumption', 'possession', 'stative']
# presume : ['cognition', 'social', 'communication', 'body']
# observed : ['perception', 'communication', 'social', 'cognition']
# settling : ['motion', 'cognition', 'communication', 'change', 'contact', 'possession', 'competition']
# cushion : ['contact']
# accepting : ['cognition', 'possession', 'communication', 'stative']
# offer : ['possession', 'social', 'cognition', 'perception', 'stative', 'communication']
# green : ['change']
# smooth : ['contact', 'possession']
# time : ['change', 'cognition']
# reversed : ['change', 'cognition', 'communication']
# reply : ['communication']
# remark : ['communication']
# well : ['motion']
# considered : ['cognition', 'perception', 'communication']
# take : ['social', 'possession', 'motion', 'contact', 'change', 'cognition', 'stative', 'perception', 'communication', 'consumption', 'competition', 'body']
# fog : ['perception']
# interrogated : ['communication']
# clicking : ['motion', 'perception', 'contact', 'communication', 'cognition']
# band : ['contact']
# projected : ['communication', 'stative', 'contact', 'perception', 'creation', 'cognition']
# chance : ['social', 'possession']
# pursued : ['social', 'motion', 'contact']
# short : ['social', 'creation']
# drink : ['consumption', 'cognition']
# throwing : ['contact', 'motion', 'communication', 'creation', 'emotion', 'cognition']
# fall : ['motion', 'change', 'stative', 'weather', 'social', 'possession', 'contact']
# bank : ['motion', 'contact', 'possession', 'cognition']
# smell : ['perception', 'cognition']
# replied : ['communication']
# ran : ['motion', 'stative', 'social', 'contact', 'competition', 'creation', 'change', 'possession']
# persisted : ['stative', 'change']
# concealing : ['perception']
# worn : ['body', 'stative', 'change', 'contact']
# sole : ['change']
# wearied : ['body']
# boot : ['contact', 'body']
# searching : ['contact', 'perception', 'cognition']
# glare : ['body', 'weather', 'perception']
# light : ['change', 'consumption', 'motion', 'weather', 'possession']
# tucking : ['contact']
# rubber : ['change']
# baby : ['social']
# lost : ['possession', 'competition', 'emotion', 'contact', 'perception', 'change']
# echoed : ['communication', 'perception', 'stative']
# shook : ['motion', 'body', 'change', 'emotion', 'communication']
# head : ['motion', 'social', 'stative', 'contact']
# thunder : ['motion', 'communication', 'weather']
# manage : ['social', 'contact']
# lose : ['possession', 'competition', 'emotion', 'contact', 'perception', 'change']
# foot : ['possession', 'motion', 'cognition']
# carried : ['contact', 'stative', 'motion', 'communication', 'social', 'change', 'competition', 'cognition', 'possession', 'creation', 'consumption', 'body']
# offering : ['possession', 'social', 'cognition', 'perception', 'stative', 'communication']
# thanks : ['communication']
# eat : ['consumption', 'emotion', 'change']
# mine : ['consumption', 'competition']
# matter : ['stative']
# taste : ['perception', 'consumption', 'cognition']
# blowing : ['body', 'weather', 'motion', 'perception', 'change', 'social', 'possession', 'contact', 'communication']
# blue : ['change']
# ring : ['perception', 'communication', 'contact']
# guess : ['cognition', 'communication']
# knowing : ['cognition', 'contact']
# came : ['motion', 'change', 'stative', 'cognition', 'perception']
# part : ['motion', 'social', 'contact']
# rail : ['communication', 'stative', 'possession', 'motion', 'contact', 'competition']
# see : ['perception', 'cognition', 'creation', 'motion', 'communication', 'social', 'contact', 'competition']
# retorted : ['communication']
# pet : ['contact']
# running : ['motion', 'stative', 'social', 'contact', 'competition', 'creation', 'change', 'possession']
# queried : ['communication']
# returned : ['motion', 'possession', 'change', 'communication', 'contact', 'social', 'creation']
# equal : ['stative', 'change']
# calm : ['emotion', 'change', 'body']
# snap : ['communication', 'contact', 'change', 'motion', 'perception', 'emotion']
# open : ['contact', 'social', 'change', 'stative', 'competition', 'possession', 'perception']
# pencil : ['creation']
# vibrated : ['motion', 'stative', 'perception', 'emotion']
# page : ['communication', 'social']
# wail : ['communication', 'body']
# cough : ['body']
# roar : ['communication', 'motion', 'body']
# made : ['social', 'change', 'creation', 'communication', 'cognition', 'possession', 'stative', 'motion', 'body', 'perception', 'contact']
# hand : ['possession', 'motion']
# held : ['stative', 'contact', 'creation', 'possession', 'cognition', 'emotion', 'social', 'competition', 'communication', 'motion', 'consumption', 'body']
# start : ['change', 'motion', 'stative', 'creation', 'social', 'competition']
# sound : ['perception', 'communication', 'change']
# borne : ['stative', 'body', 'cognition', 'contact', 'creation', 'possession', 'social']
# cool : ['change']
# breeze : ['weather', 'motion']
# march : ['motion', 'social', 'contact']
# lord : ['social']
# love : ['emotion', 'contact']
# added : ['change', 'communication', 'possession', 'cognition', 'stative']
# pause : ['stative', 'communication']
# happen : ['change', 'social', 'possession']
# inquired : ['communication', 'cognition']
# making : ['social', 'change', 'creation', 'communication', 'cognition', 'possession', 'stative', 'motion', 'body', 'perception', 'contact']
# box : ['contact']
# invoiced : ['possession']
# dock : ['motion', 'possession', 'contact']
# state : ['communication']
# iron : ['contact']
# corn : ['consumption', 'change']
# cotton : ['emotion']
# pickle : ['change']
# steady : ['change', 'contact']
# mean : ['communication', 'stative', 'cognition']
# mother : ['social', 'body']
# used : ['consumption', 'social']
# chew : ['consumption']
# gum : ['contact', 'consumption', 'change', 'body']
# school : ['social', 'motion']
# recess : ['contact', 'change']
# guessing : ['cognition', 'communication']
# soar : ['motion', 'change']
# wing : ['motion']
# article : ['communication']
# gilded : ['creation']
# imagine : ['creation', 'cognition']
# name : ['communication', 'social', 'cognition']
# mention : ['communication']
# right : ['social', 'motion', 'change']
# commit : ['social', 'communication', 'possession']
# shipped : ['motion', 'social', 'contact']
# intended : ['cognition', 'communication']
# present : ['perception', 'communication', 'creation', 'possession', 'stative']
# coughing : ['body']
# chorus : ['communication', 'creation']
# hail : ['communication', 'stative', 'weather']
# rose : ['motion', 'change', 'stative', 'body', 'emotion', 'competition', 'social']
# promenade : ['motion']
# deck : ['stative', 'creation', 'contact']
# assembled : ['creation', 'social']
# ready : ['creation', 'change']
# wave : ['communication', 'contact', 'motion', 'body']
# starred : ['stative', 'creation', 'change']
# exchange : ['possession', 'change', 'social']
# glimpse : ['perception']
# land : ['motion', 'change', 'possession']
# call : ['communication', 'social', 'stative', 'possession', 'motion', 'cognition', 'body']
# voice : ['communication']
# controlling : ['social', 'contact', 'emotion', 'cognition']
# slight : ['cognition']
# shiver : ['motion', 'body']
# queer : ['social', 'communication']
# spot : ['perception', 'contact', 'change']
# passing : ['motion', 'social', 'possession', 'stative', 'change', 'contact', 'communication', 'body']
# palm : ['contact']
# brown : ['change']
# interest : ['emotion', 'stative']
# welcome : ['possession', 'communication', 'contact']
# white : ['change']
# licking : ['contact', 'cognition', 'consumption']
# die : ['change', 'perception', 'emotion', 'contact', 'competition']
# seen : ['perception', 'cognition', 'creation', 'motion', 'communication', 'social', 'contact', 'competition']
# complete : ['change', 'social', 'competition', 'communication']
# stem : ['stative', 'change']
# print : ['creation']
# gown : ['body']
# ward : ['competition']
# shoe : ['body']
# grunted : ['communication']
# lack : ['stative']
# doubled : ['change', 'contact', 'motion', 'possession', 'creation']
# corner : ['social', 'motion']
# balanced : ['stative', 'possession', 'contact']
# bulging : ['change', 'stative', 'motion']
# waited : ['stative', 'cognition', 'social']
# seemed : ['perception', 'stative']
# fed : ['consumption', 'change', 'social', 'motion']
# black : ['change']
# bag : ['contact', 'stative', 'possession']
# noticed : ['perception', 'communication']
# sort : ['social', 'cognition']
# plump : ['motion', 'contact', 'consumption', 'cognition']
# bow : ['communication', 'motion', 'creation']
# air : ['perception', 'communication', 'change']
# meant : ['communication', 'stative', 'cognition']
# get : ['possession', 'change', 'motion', 'contact', 'perception', 'competition', 'communication', 'body', 'cognition', 'emotion', 'creation']
# full : ['contact', 'change']
# fare : ['stative', 'consumption']
# tariff : ['possession']
# filled : ['change', 'stative', 'social', 'consumption']
# long : ['emotion']
# score : ['competition', 'contact', 'communication', 'creation', 'cognition']
# attend : ['stative', 'social', 'perception']
# rigged : ['social', 'possession', 'contact', 'change']
# sling : ['contact', 'motion']
# cage : ['social']
# strengthened : ['change', 'body']
# cost : ['stative']
# mint : ['creation']
# stowed : ['contact']
# lot : ['social', 'possession']
# sweat : ['body']
# swearing : ['communication', 'cognition']
# funnel : ['contact']
# bolting : ['motion', 'contact', 'consumption', 'change']
# screwed : ['contact', 'competition']
# wire : ['possession', 'communication', 'contact', 'change']
# top : ['stative', 'motion', 'possession', 'contact', 'change']
# fast : ['consumption']
# port : ['motion', 'contact', 'consumption', 'change']
# starboard : ['motion']
# rigging : ['social', 'possession', 'contact', 'change']
# double : ['change', 'contact', 'motion', 'possession', 'creation']
# keep : ['stative', 'possession', 'social', 'cognition', 'communication', 'consumption', 'contact', 'change']
# warm : ['change']
# dry : ['change']
# forward : ['motion']
# cabin : ['contact']
# got : ['possession', 'change', 'motion', 'contact', 'perception', 'competition', 'communication', 'body', 'cognition', 'emotion', 'creation']
# job : ['social', 'possession']
# quiet : ['perception', 'emotion']
# elbow : ['motion', 'contact']
# say : ['communication', 'stative']
# please : ['emotion']
# regard : ['cognition', 'perception', 'stative']
# wish : ['emotion', 'communication']
# ask : ['communication', 'stative']
# worried : ['emotion', 'stative', 'contact']
# asked : ['communication', 'stative']
# determined : ['communication', 'cognition']
# referred : ['communication', 'stative', 'cognition', 'motion']
# mistake : ['cognition']
# nurse : ['body', 'emotion', 'social', 'consumption']
# allotted : ['possession']
# hear : ['perception', 'cognition', 'social']
# played : ['competition', 'social', 'creation', 'body', 'motion', 'contact', 'consumption', 'cognition', 'stative']
# kink : ['contact', 'change']
# framed : ['contact', 'stative', 'social', 'communication', 'cognition', 'creation']
# want : ['emotion', 'consumption', 'contact', 'cognition', 'stative']
# move : ['motion', 'social', 'body', 'change', 'emotion', 'creation', 'possession', 'competition', 'communication']
# floor : ['emotion', 'contact']
# smoothing : ['contact', 'possession']
# grin : ['body']
# bungle : ['social', 'body']
# make : ['social', 'change', 'creation', 'communication', 'cognition', 'possession', 'stative', 'motion', 'body', 'perception', 'contact']
# flying : ['motion', 'contact', 'change', 'perception']
# stopped : ['motion', 'stative', 'social', 'change', 'competition', 'contact']
# looked : ['perception', 'body', 'stative', 'social', 'communication', 'cognition']
# turning : ['motion', 'change', 'stative', 'contact', 'creation', 'body', 'social', 'possession', 'competition', 'communication']
# shortened : ['change']
# come : ['motion', 'change', 'stative', 'cognition', 'perception']
# occupy : ['social', 'stative', 'competition', 'possession', 'cognition']
# side : ['competition']
# number : ['stative', 'communication', 'change']
# smiled : ['body', 'communication']
# eye : ['perception']
# flash : ['perception', 'change', 'communication', 'motion', 'contact']
# sleep : ['body', 'stative']
# ejaculated : ['communication', 'body']
# became : ['change', 'stative']
# plied : ['consumption', 'social', 'motion', 'contact']
# drop : ['motion', 'change', 'social', 'communication', 'contact', 'competition', 'possession', 'stative', 'consumption', 'cognition', 'body']
# broke : ['change', 'contact', 'social', 'motion', 'emotion', 'stative', 'competition', 'communication', 'possession', 'cognition', 'body']
# sallow : ['change']
# glory : ['communication']
# cried : ['communication', 'body', 'consumption']
# thought : ['cognition', 'creation', 'change']
# run : ['motion', 'stative', 'social', 'contact', 'competition', 'creation', 'change', 'possession']
# tackle : ['social', 'contact', 'competition']
# wallowing : ['consumption', 'motion', 'emotion']
# touched : ['contact', 'perception', 'emotion', 'stative', 'change', 'social', 'communication', 'cognition', 'consumption']
# cap : ['stative', 'change']
# keeping : ['stative', 'possession', 'social', 'cognition', 'communication', 'consumption', 'contact', 'change']
# surprise : ['cognition', 'social', 'competition']
# felt : ['contact', 'change', 'emotion', 'cognition', 'perception', 'body', 'stative', 'possession']
# understand : ['cognition']
# nodded : ['communication', 'body', 'motion']
# smile : ['body', 'communication']
# told : ['communication', 'cognition']
# nursing : ['body', 'emotion', 'social', 'consumption']
# engaged : ['social', 'cognition', 'communication', 'change', 'possession', 'contact']
# bought : ['possession', 'stative', 'cognition']
# prompted : ['creation', 'communication']
# looking : ['perception', 'body', 'stative', 'social', 'communication', 'cognition']
# voyage : ['motion']
# understood : ['cognition']
# condition : ['social', 'communication', 'change', 'body']
# permitted : ['communication', 'social']
# pay : ['possession', 'communication', 'cognition', 'stative', 'social']
# appreciating : ['emotion', 'cognition', 'possession', 'change']
# pressure : ['social']
# point : ['communication', 'stative', 'competition', 'motion', 'contact', 'change']
# coughed : ['body']
# suggested : ['communication']
# heard : ['perception', 'cognition', 'social']
# fair : ['contact']
# wind : ['motion', 'stative', 'contact', 'perception']
# delighted : ['emotion', 'consumption']
# like : ['emotion', 'cognition']
# feeding : ['consumption', 'change', 'social', 'motion']
# nut : ['contact']
# table : ['stative', 'creation']
# sharpened : ['contact', 'change', 'perception']
# suppose : ['communication', 'cognition']
# round : ['motion', 'change', 'communication', 'body']
# put : ['contact', 'communication', 'consumption', 'possession', 'cognition', 'perception', 'creation']
# allowance : ['possession']
# hay : ['change']
# bread : ['contact']
# grain : ['contact', 'change']
# cabbage : ['possession']
# temper : ['change']
# milk : ['change', 'consumption']
# breathed : ['body', 'stative', 'possession', 'communication', 'change']
# breathing : ['body', 'stative', 'possession', 'communication', 'change']
# complain : ['communication']
# snoring : ['body']
# people : ['change', 'stative']
# allow : ['social', 'communication', 'possession', 'cognition', 'stative']
# happened : ['change', 'social', 'possession']
# hinted : ['communication']
# took : ['social', 'possession', 'motion', 'contact', 'change', 'cognition', 'stative', 'perception', 'communication', 'consumption', 'competition', 'body']
# washing : ['contact', 'body', 'motion', 'stative', 'change']
# scented : ['perception', 'body']
# soap : ['body']
# expense : ['change']
# case : ['perception', 'contact']
# complexion : ['change']
# living : ['stative', 'cognition']
# harry : ['emotion', 'change']
# standing : ['contact', 'stative', 'cognition', 'competition']
# water : ['change', 'possession', 'body']
# swabbing : ['contact']
# soaped : ['body']
# squirting : ['contact']
# rinse : ['contact', 'body']
# believed : ['cognition']
# sight : ['perception']
# drew : ['contact', 'possession', 'cognition', 'motion', 'creation', 'communication', 'emotion', 'consumption', 'competition', 'change', 'stative', 'social', 'body']
# pantomime : ['creation']
# given : ['possession', 'communication', 'creation', 'cognition', 'social', 'motion', 'consumption', 'contact', 'change', 'body']
# weather : ['stative', 'motion', 'change']
# bit : ['contact', 'perception']
# bugle : ['creation']
# blew : ['body', 'weather', 'motion', 'perception', 'change', 'social', 'possession', 'contact', 'communication']
# turned : ['motion', 'change', 'stative', 'contact', 'creation', 'body', 'social', 'possession', 'competition', 'communication']
# mound : ['creation']
# disgust : ['perception', 'emotion']
# bucket : ['contact']
# oblige : ['social', 'communication']
# cheer : ['emotion', 'communication']
# brisk : ['change']
# considering : ['cognition', 'perception', 'communication']
# sighed : ['body', 'communication']
# tear : ['contact', 'motion', 'body']
# trickled : ['motion']
# swayed : ['motion', 'social']
# better : ['competition', 'change']
# charge : ['competition', 'communication', 'possession', 'motion', 'social', 'contact', 'emotion', 'creation', 'cognition', 'change']
# face : ['communication', 'competition', 'stative', 'motion', 'perception', 'contact']
# streaked : ['motion', 'creation']
# lay : ['contact', 'creation', 'possession', 'stative', 'communication', 'motion']
# glued : ['contact', 'change']
# devouring : ['contact', 'emotion', 'consumption']
# upset : ['change', 'emotion', 'motion', 'contact', 'competition']
# pitching : ['contact', 'motion', 'change', 'possession', 'competition']
# dipped : ['contact', 'consumption', 'change', 'possession', 'perception', 'motion', 'creation']
# nose : ['perception', 'motion', 'contact', 'competition']
# busy : ['social']
# endeavoring : ['social']
# devise : ['creation', 'possession']
# adopt : ['possession', 'social', 'change', 'creation', 'cognition']
# showed : ['perception', 'cognition', 'communication', 'creation', 'motion', 'competition']
# deal : ['communication', 'cognition', 'social', 'possession']
# alleviate : ['body', 'change']
# suffering : ['perception', 'body', 'emotion', 'cognition', 'change', 'stative']
# stand : ['contact', 'stative', 'cognition', 'competition']
# wet : ['change', 'body']
# planking : ['contact', 'consumption']
# holding : ['stative', 'contact', 'creation', 'possession', 'cognition', 'emotion', 'social', 'competition', 'communication', 'motion', 'consumption', 'body']
# soaked : ['contact', 'possession', 'change', 'consumption']
# jotted : ['communication']
# muttered : ['communication']
# slathers : ['contact']
# spared : ['social', 'possession', 'consumption', 'contact', 'communication']
# reminded : ['cognition', 'communication']
# star : ['stative', 'creation', 'change']
# bottle : ['possession', 'contact']
# blamed : ['communication', 'cognition']
# wonder : ['cognition', 'communication']
# ached : ['perception', 'emotion']
# moistening : ['change', 'contact']
# except : ['communication', 'cognition']
# wine : ['consumption']
# tin : ['contact', 'change']
# continued : ['stative', 'communication', 'motion', 'social', 'change']
# grew : ['change', 'stative', 'creation', 'body']
# touching : ['contact', 'perception', 'emotion', 'stative', 'change', 'social', 'communication', 'cognition', 'consumption']
# clung : ['contact', 'emotion']
# wrote : ['creation', 'communication']
# marking : ['contact', 'communication', 'cognition', 'change', 'social', 'perception']
# word : ['communication']
# headline : ['communication', 'possession']
# shoulder : ['contact']
# stood : ['contact', 'stative', 'cognition', 'competition']
# ladder : ['change']
# lashed : ['contact', 'motion']
# hang : ['contact', 'social', 'motion', 'stative', 'perception', 'creation', 'change']
# pulse : ['motion', 'creation']
# style : ['communication', 'creation']
# wanted : ['emotion', 'consumption', 'contact', 'cognition', 'stative']
# curl : ['change', 'motion', 'contact', 'competition']
# mouth : ['communication', 'contact']
# instrument : ['possession', 'creation', 'communication']
# placed : ['contact', 'social', 'cognition', 'possession', 'communication', 'competition', 'creation', 'stative']
# tongue : ['creation', 'contact']
# going : ['motion', 'social', 'change', 'stative', 'perception', 'contact', 'consumption', 'competition', 'cognition']
# knock : ['contact', 'perception', 'communication']
# gasped : ['body']
# pausing : ['stative', 'communication']
# wipe : ['contact']
# cuff : ['contact']
# use : ['consumption', 'social']
# robbed : ['possession']
# passed : ['motion', 'social', 'possession', 'stative', 'change', 'contact', 'communication', 'body']
# check : ['cognition', 'social', 'motion', 'change', 'stative', 'possession', 'creation', 'competition', 'communication']
# last : ['stative']
# obliged : ['social', 'communication']
# back : ['social', 'motion', 'possession', 'stative', 'competition', 'change']
# combined : ['stative', 'change', 'contact', 'possession', 'social']
# hung : ['contact', 'social', 'motion', 'stative', 'perception', 'creation', 'change']
# recorded : ['communication', 'perception', 'cognition']
# sorrow : ['emotion']
# sank : ['motion', 'change', 'contact']
# plain : ['communication']
# believe : ['cognition']
# deigned : ['social']
# leave : ['motion', 'cognition', 'stative', 'change', 'social', 'possession']
# trumpeted : ['communication', 'creation']
# saw : ['contact', 'perception', 'cognition', 'creation', 'motion', 'communication', 'social', 'competition']
# quit : ['stative', 'social', 'motion', 'possession', 'competition']
# forgot : ['cognition']
# tell : ['communication', 'cognition']
# attacked : ['competition', 'communication', 'change', 'body']
# bellow : ['communication']
# rage : ['stative', 'emotion']
# excited : ['emotion', 'change', 'perception']
# roared : ['communication', 'motion', 'body']
# snarled : ['communication', 'contact', 'change']
# raised : ['change', 'motion', 'communication', 'possession', 'creation', 'social', 'emotion', 'competition', 'cognition', 'body']
# general : ['communication']
# trimming : ['contact', 'creation', 'change', 'stative']
# sign : ['communication', 'social', 'contact']
# leaded : ['motion', 'stative', 'communication', 'social', 'creation']
# space : ['motion']
# wink : ['body', 'perception']
# devoted : ['communication', 'cognition', 'possession']
# end : ['stative', 'change', 'creation']
# exhausted : ['body', 'consumption', 'possession', 'change']
# retired : ['social', 'motion', 'possession', 'emotion', 'contact', 'competition', 'body']
# snatch : ['contact']
# rest : ['contact', 'communication', 'stative', 'body', 'change', 'social']
# crew : ['competition']
# vied : ['competition']
# pacify : ['emotion', 'creation']
# effect : ['creation', 'social']
# tried : ['social', 'consumption', 'emotion', 'change', 'body']
# mashed : ['contact', 'communication', 'change']
# ship : ['motion', 'social', 'contact']
# shot : ['competition', 'social', 'communication', 'motion', 'contact', 'weather', 'perception', 'consumption', 'cognition', 'change', 'body']
# offered : ['possession', 'social', 'cognition', 'perception', 'stative', 'communication']
# appearing : ['perception', 'change', 'creation', 'social']
# pacified : ['emotion', 'creation']
# left : ['motion', 'cognition', 'stative', 'change', 'social', 'possession']
# begged : ['communication', 'possession']
# consider : ['cognition', 'perception', 'communication']
# tremble : ['motion']
# deny : ['communication', 'possession']
# producing : ['creation', 'perception', 'body']
# unfolding : ['change', 'perception', 'motion', 'contact']
# kissed : ['contact']
# queen : ['social', 'motion']
# shed : ['contact', 'body']
# object : ['communication', 'stative']
# minister : ['social']
# surprised : ['cognition', 'social', 'competition']
# fashion : ['creation']
# struggle : ['social', 'contact', 'motion', 'competition']
# described : ['communication', 'contact', 'cognition']
# denied : ['communication', 'possession']
# litter : ['stative', 'contact', 'body']
# bottom : ['possession', 'contact', 'cognition']
# ceased : ['stative']
# trumpeting : ['communication', 'creation']
# silence : ['change']
# fallen : ['motion', 'change', 'stative', 'weather', 'social', 'possession', 'contact']
# still : ['emotion', 'change']
# rolled : ['motion', 'stative', 'contact', 'perception', 'change', 'body', 'possession', 'communication']
# sun : ['body', 'perception']
# blot : ['contact']
# fire : ['competition', 'change', 'social', 'motion', 'emotion', 'possession']
# rendered : ['change', 'possession', 'creation', 'communication', 'contact']
# sinking : ['motion', 'change', 'contact']
# sponging : ['contact', 'possession']
# fanning : ['contact', 'change', 'motion']
# whispered : ['communication']
# near : ['motion']
# opened : ['contact', 'social', 'change', 'stative', 'competition', 'possession', 'perception']
# expiring : ['stative', 'change', 'body']
# lifted : ['motion', 'contact', 'communication', 'possession', 'change', 'stative', 'body']
# broken : ['change', 'contact', 'social', 'motion', 'emotion', 'stative', 'competition', 'communication', 'possession', 'cognition', 'body']
# tusk : ['contact', 'change']
# dropped : ['motion', 'change', 'social', 'communication', 'contact', 'competition', 'possession', 'stative', 'consumption', 'cognition', 'body']
# uttered : ['communication', 'motion']
# groan : ['communication']
# threw : ['contact', 'motion', 'communication', 'creation', 'emotion', 'cognition']
# died : ['change', 'perception', 'emotion', 'contact', 'competition']
# paper : ['contact']
# smacking : ['contact', 'perception', 'consumption']
# yanked : ['contact']
# body : ['stative']
# stuff : ['contact', 'motion', 'consumption', 'change']
# sigh : ['body', 'communication']
# preserving : ['stative', 'possession', 'change']
# spirit : ['change']
# think : ['cognition', 'creation', 'change']
# heaved : ['communication', 'contact', 'motion', 'body', 'change']
# carrying : ['contact', 'stative', 'motion', 'communication', 'social', 'change', 'competition', 'cognition', 'possession', 'creation', 'consumption', 'body']
# guessed : ['cognition', 'communication']
# floated : ['motion', 'social', 'contact', 'cognition', 'change']
# resting : ['contact', 'communication', 'stative', 'body', 'change', 'social']
# surface : ['motion', 'contact', 'change']
# faint : ['body']
# cry : ['communication', 'body', 'consumption']
# swooned : ['body']
# arm : ['competition', 'possession']
# commented : ['communication']
# book : ['cognition', 'social']
# jotting : ['communication']
# strike : ['contact', 'emotion', 'competition', 'communication', 'social', 'stative', 'change', 'possession', 'creation', 'perception', 'motion', 'cognition']
# glance : ['perception', 'motion']
# crammed : ['contact', 'cognition', 'change']
# true : ['change']
# photograph : ['communication', 'stative']
# sketch : ['creation', 'communication']
# honor : ['social', 'possession']
# shaking : ['motion', 'body', 'change', 'emotion', 'communication']
# telling : ['communication', 'cognition']
# deserves : ['stative']
# trade : ['possession', 'stative']
# place : ['contact', 'social', 'cognition', 'possession', 'communication', 'competition', 'creation', 'stative']
# appeared : ['perception', 'change', 'creation', 'social']
# struggling : ['social', 'contact', 'motion', 'competition']
# muscle : ['motion']
# worked : ['social', 'contact', 'creation', 'body', 'motion', 'stative', 'perception', 'emotion', 'consumption', 'cognition', 'change']
# reddened : ['body', 'change']
# shone : ['weather', 'perception', 'stative', 'emotion', 'contact']
# gathered : ['contact', 'social', 'change', 'communication']
# manifested : ['communication', 'change']
# glancing : ['perception', 'motion']
# listening : ['perception', 'social']
# observing : ['perception', 'communication', 'social', 'cognition']
# stamped : ['motion', 'contact', 'perception', 'cognition', 'change', 'creation']
# encircled : ['contact']
# crinkled : ['contact', 'change']
# fringed : ['creation', 'contact']
# stage : ['creation']
# grasped : ['contact', 'cognition']
# pointed : ['communication', 'stative', 'competition', 'motion', 'contact', 'change']
# gray : ['change']
# beard : ['stative']
# keen : ['emotion']
# sheltered : ['stative', 'possession']
# peak : ['motion']
# harbor : ['emotion', 'stative', 'possession', 'perception']
# house : ['stative', 'social']
# glided : ['motion']
# missing : ['perception', 'emotion', 'stative', 'cognition', 'motion', 'contact', 'communication']
# permit : ['communication', 'social']
# introduce : ['communication', 'creation', 'change', 'motion', 'contact', 'cognition']
# hat : ['body', 'possession']
# favor : ['social', 'cognition']
# beginning : ['change', 'stative', 'communication', 'social']
# choking : ['body', 'contact', 'social', 'change']
# snort : ['communication', 'body', 'consumption']
# rushed : ['motion', 'competition', 'change', 'creation']
# hearing : ['perception', 'cognition', 'social']
# damage : ['change']
# repaired : ['change', 'possession', 'motion', 'body']
# piping : ['communication', 'motion', 'creation', 'social', 'competition']
# course : ['motion', 'competition']
# show : ['perception', 'cognition', 'communication', 'creation', 'motion', 'competition']
# smiling : ['body', 'communication']
# proclaimed : ['communication']
# emanated : ['change', 'body']
# teeming : ['stative', 'motion']
# brain : ['contact']
# surmise : ['cognition', 'communication']
# go : ['motion', 'social', 'change', 'stative', 'perception', 'contact', 'consumption', 'competition', 'cognition']
# evidence : ['communication']
# noise : ['perception']
# exclaimed : ['communication']
# forcing : ['social', 'creation', 'motion', 'communication', 'contact']
# chamber : ['stative']
# gear : ['change']
# let : ['social', 'communication', 'change', 'possession']
# square : ['change', 'cognition', 'stative', 'motion', 'possession', 'competition']
# murmured : ['communication']
# glide : ['motion']
# checked : ['cognition', 'social', 'motion', 'change', 'stative', 'possession', 'creation', 'competition', 'communication']
# throbbed : ['perception', 'motion']
# dull : ['contact', 'change', 'perception']
# pressed : ['contact', 'communication', 'stative', 'motion', 'creation', 'social', 'competition']
# drank : ['consumption', 'cognition']
# traversed : ['motion', 'stative', 'communication']
# channel : ['motion', 'contact']
# acquainted : ['communication']
# soil : ['contact']
# grows : ['change', 'stative', 'creation', 'body']
# ranking : ['cognition', 'stative']
# grilling : ['change', 'communication']
# addressed : ['communication', 'competition', 'consumption', 'social', 'possession', 'change']
# sprawling : ['contact', 'motion']
# ink : ['communication', 'change']
# smelt : ['creation', 'perception', 'cognition']
# bore : ['emotion', 'contact', 'stative', 'body', 'cognition', 'creation', 'possession', 'social']
# initial : ['communication']
# intertwined : ['contact', 'creation']
# dated : ['social', 'cognition']
# situate : ['stative', 'contact']
# blushing : ['body', 'change']
# reach : ['motion', 'contact', 'communication', 'social', 'stative', 'possession', 'competition']
# blood : ['contact']
# widow : ['change']
# stock : ['possession', 'body']
# startling : ['emotion', 'motion']
# printed : ['creation']
# pig : ['stative', 'consumption', 'body']
# peach : ['communication']
# rallied : ['contact', 'competition', 'change', 'communication']
# induced : ['creation', 'communication', 'cognition']
# caused : ['creation', 'communication']
# bloom : ['change']
# purchased : ['possession']
# grace : ['creation', 'stative']
# done : ['social', 'creation', 'stative', 'body', 'motion']
# letter : ['possession', 'creation']
# consult : ['communication']
# affecting : ['change', 'body', 'stative', 'communication', 'emotion']
# regiment : ['social']
# wrinkled : ['contact', 'change']
# freckled : ['change']
# pucker : ['contact']
# rubbed : ['contact', 'perception']
# getting : ['possession', 'change', 'motion', 'contact', 'perception', 'competition', 'communication', 'body', 'cognition', 'emotion', 'creation']
# thin : ['change', 'body']
# summit : ['motion']
# puzzled : ['cognition', 'emotion']
# meaning : ['communication', 'stative', 'cognition']
# appeal : ['social', 'communication', 'emotion']
# led : ['motion', 'stative', 'communication', 'social', 'creation']
# earth : ['perception', 'contact']
# managed : ['social', 'contact']
# waving : ['communication', 'contact', 'motion', 'body']
# pump : ['contact', 'competition', 'motion', 'possession', 'communication']
# devil : ['emotion', 'creation']
# attached : ['contact', 'social', 'possession']
# garrisoned : ['competition']
# fort : ['motion', 'contact', 'competition']
# besieged : ['competition', 'emotion', 'communication']
# brought : ['motion', 'contact', 'creation', 'change', 'possession', 'emotion', 'communication']
# admitted : ['communication', 'social', 'possession', 'stative']
# detail : ['communication', 'cognition']
# bringing : ['motion', 'contact', 'creation', 'change', 'possession', 'emotion', 'communication']
# involved : ['stative', 'cognition', 'change']
# scorching : ['change']
# tangled : ['stative', 'contact']
# bush : ['possession']
# crossing : ['motion', 'social', 'stative', 'creation', 'contact']
# sniped : ['competition', 'communication', 'contact']
# chased : ['motion', 'social', 'contact']
# picket : ['social', 'contact']
# refer : ['communication', 'stative', 'cognition', 'motion']
# despatch : ['motion']
# stampeding : ['motion', 'social']
# trample : ['motion', 'body']
# wrung : ['contact', 'possession']
# power : ['consumption']
# packed : ['contact', 'motion', 'social', 'stative', 'body']
# battered : ['contact', 'change']
# spent : ['stative', 'possession']
# label : ['communication', 'contact', 'cognition']
# found : ['social', 'creation', 'cognition', 'possession', 'perception', 'communication', 'change', 'motion']
# automobile : ['motion']
# tender : ['possession', 'change']
# waiting : ['stative', 'cognition', 'social']
# comparing : ['cognition', 'stative', 'communication']
# dimension : ['communication', 'change']
# size : ['contact', 'cognition', 'change']
# package : ['contact']
# store : ['possession']
# hamper : ['change', 'competition']
# firm : ['change']
# blinked : ['body', 'perception']
# bewildered : ['cognition', 'emotion']
# proportion : ['change']
# cover : ['contact', 'stative', 'communication', 'motion', 'competition', 'social', 'perception', 'possession', 'body']
# bearing : ['stative', 'body', 'cognition', 'contact', 'creation', 'possession', 'social']
# flourishing : ['change', 'possession', 'contact']
# bachelor : ['stative']
# type : ['communication', 'cognition']
# exaggerated : ['communication', 'social']
# expected : ['cognition', 'communication', 'body']
# bewail : ['communication']
# even : ['contact', 'change']
# requires : ['stative', 'communication', 'consumption']
# clothes : ['body', 'social', 'contact']
# ousted : ['social']
# chauffeur : ['motion']
# assuming : ['cognition', 'social', 'change', 'possession', 'motion', 'creation', 'contact', 'body']
# reaching : ['motion', 'contact', 'communication', 'social', 'stative', 'possession', 'competition']
# beg : ['communication', 'possession']
# pardon : ['communication']
# fetch : ['contact', 'possession']
# furrow : ['contact']
# forming : ['social', 'stative', 'change', 'creation']
# wearing : ['body', 'stative', 'change', 'contact']
# waterproof : ['contact']
# groom : ['social', 'body']
# staying : ['change', 'motion', 'stative', 'social', 'contact', 'consumption']
# adding : ['change', 'communication', 'possession', 'cognition', 'stative']
# recalled : ['cognition', 'communication', 'stative', 'social', 'possession']
# question : ['communication']
# perched : ['contact', 'motion']
# edge : ['motion', 'possession', 'contact']
# honeymooning : ['stative']
# couple : ['contact', 'social']
# give : ['possession', 'communication', 'creation', 'cognition', 'social', 'motion', 'consumption', 'contact', 'change', 'body']
# lift : ['motion', 'contact', 'communication', 'possession', 'change', 'stative', 'body']
# spoke : ['communication', 'perception']
# emerged : ['change', 'motion', 'stative']
# dim : ['perception', 'change']
# echoing : ['communication', 'perception', 'stative']
# disgorged : ['contact', 'body']
# wore : ['body', 'stative', 'change', 'contact']
# suit : ['stative']
# pink : ['perception', 'contact']
# adorned : ['creation', 'stative', 'social']
# disconcerting : ['emotion']
# maddening : ['emotion']
# categorized : ['cognition']
# gratified : ['emotion', 'consumption']
# observe : ['perception', 'communication', 'social', 'cognition']
# boasted : ['communication', 'stative']
# droop : ['motion', 'stative', 'change']
# narrow : ['change', 'cognition']
# favored : ['social', 'cognition']
# stare : ['perception', 'body']
# coming : ['motion', 'change', 'stative', 'cognition', 'perception']
# raising : ['change', 'motion', 'communication', 'possession', 'creation', 'social', 'emotion', 'competition', 'cognition', 'body']
# stared : ['perception', 'body', 'stative', 'creation', 'change']
# drove : ['motion', 'contact', 'social', 'creation', 'communication', 'stative', 'consumption', 'competition']
# astonished : ['cognition']
# hold : ['stative', 'contact', 'creation', 'possession', 'cognition', 'emotion', 'social', 'competition', 'communication', 'motion', 'consumption', 'body']
# rank : ['cognition', 'stative']
# shy : ['motion', 'contact']
# earned : ['possession']
# adorn : ['creation', 'stative', 'social']
# shrink : ['change', 'motion']
# schooling : ['social', 'motion']
# breeding : ['creation', 'contact', 'body']
# relate : ['cognition', 'stative', 'communication', 'social']
# shell : ['competition', 'creation', 'contact', 'change']
# rattled : ['perception', 'motion']
# landscape : ['creation']
# reeled : ['motion', 'contact']
# risk : ['social']
# steep : ['cognition', 'change']
# curving : ['motion', 'stative', 'change']
# hill : ['creation']
# announced : ['communication']
# lettered : ['possession', 'creation']
# appropriate : ['cognition', 'possession']
# crimson : ['body']
# afforded : ['consumption', 'possession', 'stative']
# exercise : ['consumption', 'social', 'body', 'cognition']
# deprived : ['possession', 'change']
# dwelling : ['cognition', 'stative', 'communication']
# guide : ['motion', 'social', 'perception', 'contact']
# sat : ['contact', 'stative', 'motion', 'perception', 'social', 'competition']
# croquet : ['contact', 'competition']
# garden : ['creation']
# swirled : ['motion']
# welcomed : ['possession', 'communication', 'contact']
# barking : ['communication', 'contact', 'change']
# dog : ['motion']
# responded : ['cognition', 'communication']
# greeting : ['communication', 'cognition', 'perception']
# whisker : ['possession']
# howling : ['communication', 'body']
# ape : ['stative', 'communication']
# swung : ['motion', 'social', 'contact', 'stative', 'competition', 'change', 'creation']
# letting : ['social', 'communication', 'change', 'possession']
# avalanche : ['motion']
# cat : ['contact', 'body']
# advanced : ['motion', 'communication', 'change', 'social', 'competition', 'possession']
# weed : ['change']
# becoming : ['change', 'stative']
# cooed : ['communication']
# weary : ['body']
# gave : ['possession', 'communication', 'creation', 'cognition', 'social', 'motion', 'consumption', 'contact', 'change', 'body']
# sugared : ['perception']
# best : ['competition']
# squeeze : ['contact', 'social', 'possession', 'motion']
# confirmed : ['cognition', 'communication', 'change', 'social']
# look : ['perception', 'body', 'stative', 'social', 'communication', 'cognition']
# saying : ['communication', 'stative']
# undulating : ['motion', 'stative', 'change']
# wobble : ['motion']
# lean : ['motion', 'contact', 'stative', 'cognition']
# driven : ['motion', 'contact', 'social', 'creation', 'communication', 'stative', 'consumption', 'competition']
# hustled : ['motion', 'possession', 'communication']
# station : ['competition']
# sitting : ['contact', 'stative', 'motion', 'perception', 'social', 'competition']
# mistaken : ['cognition']
# giggle : ['body']
# yellow : ['change']
# soared : ['motion', 'change']
# met : ['motion', 'social', 'stative', 'consumption', 'competition', 'perception', 'contact']
# frightened : ['emotion']
# scorched : ['change']
# burst : ['change', 'emotion', 'motion', 'stative']
# peal : ['perception']
# rippling : ['motion', 'perception']
# struck : ['contact', 'emotion', 'competition', 'communication', 'social', 'stative', 'change', 'possession', 'creation', 'perception', 'motion', 'cognition']
# forced : ['social', 'creation', 'motion', 'communication', 'contact']
# clear : ['change', 'weather', 'communication', 'social', 'possession', 'perception', 'motion', 'cognition']
# perfect : ['change']
# entrance : ['emotion', 'body']
# strolling : ['motion']
# pair : ['social', 'contact']
# rustled : ['perception', 'possession']
# pour : ['motion', 'possession', 'weather']
# leaving : ['motion', 'cognition', 'stative', 'change', 'social', 'possession']
# jaundiced : ['change', 'body']
# frame : ['contact', 'stative', 'social', 'communication', 'cognition', 'creation']
# mind : ['communication', 'cognition', 'social']
# hated : ['emotion', 'body', 'possession']
# mystified : ['cognition', 'change']
# taken : ['social', 'possession', 'motion', 'contact', 'change', 'cognition', 'stative', 'perception', 'communication', 'consumption', 'competition', 'body']
# encounter : ['motion', 'possession', 'stative', 'competition']
# dislike : ['emotion']
# termed : ['communication']
# loathing : ['emotion']
# existed : ['stative']
# duplicate : ['creation', 'stative', 'change']
# patronizing : ['possession', 'social', 'communication']
# advance : ['motion', 'communication', 'change', 'social', 'competition', 'possession']
# twin : ['stative', 'contact', 'change', 'body']
# accepted : ['cognition', 'possession', 'communication', 'stative']
# parent : ['social']
# crumpled : ['motion', 'contact', 'change']
# outline : ['communication', 'creation']
# educated : ['social', 'cognition']
# advantage : ['social']
# expect : ['cognition', 'communication', 'body']
# recognized : ['cognition', 'perception', 'social', 'communication', 'stative']
# notice : ['perception', 'communication']
# lower : ['motion', 'change', 'contact', 'body']
# button : ['contact']
# undone : ['contact', 'creation', 'social']
# dwelt : ['cognition', 'stative', 'communication']
# romping : ['motion', 'competition']
# cake : ['contact']
# meet : ['motion', 'social', 'stative', 'consumption', 'competition', 'perception', 'contact']
# belong : ['possession', 'stative']
# father : ['body']
# age : ['change']
# opening : ['contact', 'social', 'change', 'stative', 'competition', 'possession', 'perception']
# find : ['possession', 'perception', 'communication', 'cognition', 'creation', 'change', 'motion']
# imagined : ['creation', 'cognition']
# suggest : ['communication']
# increase : ['change']
# expostulated : ['communication']
# talk : ['communication']
# changed : ['change', 'possession', 'motion']
# grown : ['change', 'stative', 'creation', 'body']
# charming : ['emotion', 'social', 'competition', 'communication']
# confiding : ['communication', 'possession']
# bite : ['contact', 'perception']
# tail : ['motion', 'contact']
# bell : ['contact']
# married : ['social']
# awakening : ['body', 'cognition']
# chord : ['creation', 'change']
# dine : ['consumption']
# help : ['social', 'body', 'stative', 'consumption', 'change']
# entertain : ['social', 'cognition', 'emotion']
# drooped : ['motion', 'stative', 'change']
# blushed : ['body', 'change']
# company : ['stative']
# summer : ['stative']
# lends : ['possession', 'stative']
# sense : ['perception', 'cognition']
# humor : ['communication']
# obscured : ['perception', 'cognition', 'change']
# ride : ['motion', 'stative', 'communication', 'contact']
# drive : ['motion', 'contact', 'social', 'creation', 'communication', 'stative', 'consumption', 'competition']
# horse : ['consumption']
# launch : ['social', 'contact', 'change']
# play : ['competition', 'social', 'creation', 'body', 'motion', 'contact', 'consumption', 'cognition', 'stative']
# gulped : ['consumption', 'communication']
# deceased : ['change']
# confessed : ['communication']
# evening : ['contact', 'change']
# garb : ['body']
# home : ['social', 'motion']
# recommending : ['communication', 'change']
# dish : ['consumption', 'change']
# criticizing : ['communication', 'competition']
# ravaging : ['change']
# reveling : ['consumption', 'social']
# calling : ['communication', 'social', 'stative', 'possession', 'motion', 'cognition', 'body']
# laid : ['contact', 'creation', 'possession']
# known : ['cognition', 'contact']
# awaken : ['body', 'cognition']
# gad : ['motion']
# distracted : ['emotion']
# miss : ['perception', 'emotion', 'stative', 'cognition', 'motion', 'contact', 'communication']
# encouraging : ['social', 'emotion', 'communication']
# renewed : ['creation', 'change']
# attack : ['competition', 'communication', 'change', 'body']
# submitted : ['communication', 'competition', 'possession', 'social', 'cognition']
# patronized : ['possession', 'social', 'communication']
# chosen : ['cognition']
# recommended : ['communication', 'change']
# try : ['social', 'consumption', 'emotion', 'change', 'body']
# walked : ['motion', 'competition', 'social']
# paused : ['stative', 'communication']
# behold : ['perception']
# vanished : ['change', 'perception', 'motion']
# winding : ['motion', 'stative', 'contact', 'perception']
# shrugging : ['body']
# picked : ['cognition', 'contact', 'communication', 'creation', 'change', 'possession', 'consumption']
# glimmering : ['perception']
# shining : ['weather', 'perception', 'stative', 'emotion', 'contact', 'motion']
# leaf : ['perception', 'motion', 'body']
# wondering : ['cognition', 'communication']
# dragged : ['contact', 'stative', 'motion', 'consumption', 'communication', 'change']
# required : ['stative', 'communication', 'consumption']
# sickening : ['emotion', 'body', 'perception']
# jog : ['stative', 'motion', 'contact', 'communication']
# realized : ['cognition', 'creation', 'possession']
# fretted : ['emotion', 'possession', 'perception', 'creation', 'contact', 'change']
# aching : ['perception', 'emotion']
# neighbor : ['stative']
# conduct : ['social', 'creation', 'motion']
# emancipated : ['social']
# bordered : ['contact', 'stative', 'possession']
# deposit : ['contact', 'possession']
# biting : ['contact', 'perception']
# frowning : ['body']
# scowl : ['body']
# bed : ['possession', 'contact', 'body']
# returning : ['motion', 'possession', 'change', 'communication', 'contact', 'social', 'creation']
# shrugged : ['body']
# bower : ['contact']
# front : ['stative', 'competition']
# cropped : ['contact', 'creation']
# plumped : ['motion', 'contact', 'consumption', 'cognition']
# pillow : ['contact']
# jolted : ['motion', 'emotion']
# ...
# riposte : ['motion', 'communication']
# swerved : ['motion']
# tissue : ['creation']
# slow : ['change']
# atrophy : ['body']
# varnished : ['contact']
# gliding : ['motion']
# shimmer : ['weather', 'stative']
# deteriorated : ['change', 'body']
# reflect : ['perception', 'cognition', 'weather', 'communication']
# denies : ['communication', 'possession']
# mentioning : ['communication']
# asks : ['communication', 'stative']
# assumes : ['cognition', 'social', 'change', 'possession', 'motion', 'creation', 'contact', 'body']
# assert : ['communication', 'social', 'cognition']
# sustains : ['stative', 'body', 'consumption', 'contact', 'communication', 'cognition']
# puzzle : ['cognition', 'emotion']
# tax : ['possession', 'consumption', 'communication']
# fished : ['contact', 'competition']
# traced : ['cognition', 'contact', 'motion', 'perception', 'creation']
# anticipate : ['cognition', 'social', 'communication', 'emotion', 'change']
# mildewed : ['change']
# dwarf : ['stative', 'social']
# tiled : ['contact']
# stained : ['change', 'contact']
# spilt : ['contact', 'motion', 'communication', 'change']
# scale : ['stative', 'creation', 'possession', 'motion', 'contact', 'change']
# jar : ['stative', 'motion', 'emotion', 'contact']
# decayed : ['change']
# beetle : ['stative', 'motion', 'contact']
# resigned : ['social', 'possession', 'cognition']
# feed : ['consumption', 'change', 'social', 'motion', 'possession']
# stored : ['possession']
# grub : ['possession', 'contact']
# drawling : ['communication']
# hatch : ['body', 'creation', 'contact']
# avoid : ['communication', 'social', 'consumption']
# handling : ['social', 'communication', 'contact', 'emotion']
# nourish : ['consumption']
# emanating : ['change', 'body']
# obstructed : ['social', 'contact', 'perception']
# hatched : ['body', 'creation', 'contact']
# contain : ['stative', 'social', 'competition']
# retain : ['stative', 'social', 'possession', 'cognition']
# astonishing : ['cognition']
# sowed : ['contact', 'communication']
# fostered : ['social', 'communication']
# acceded : ['communication', 'social']
# knotted : ['creation', 'contact']
# experiment : ['social']
# blown : ['body', 'weather', 'motion', 'perception', 'change', 'social', 'possession', 'contact', 'communication']
# employ : ['consumption', 'social']
# concentrated : ['change', 'cognition', 'motion']
# imbued : ['contact', 'change']
# sublime : ['change']
# dizzy : ['change']
# attains : ['social', 'motion', 'possession']
# flowing : ['motion', 'stative', 'contact', 'change', 'body']
# allows : ['social', 'communication', 'possession', 'cognition', 'stative']
# approach : ['motion', 'stative', 'social', 'communication']
# detained : ['social', 'change']
# committed : ['social', 'communication', 'possession']
# theorized : ['cognition']
# located : ['possession', 'stative', 'change']
# coast : ['motion']
# allay : ['emotion', 'consumption']
# lunching : ['consumption']
# shielded : ['competition', 'perception']
# gravel : ['emotion', 'contact', 'cognition']
# begging : ['communication', 'possession']
# seared : ['change']
# cipher : ['communication', 'cognition']
# stepping : ['motion', 'social', 'possession', 'contact', 'change']
# thrusting : ['motion', 'communication', 'contact', 'stative']
# travesty : ['creation']
# regarding : ['cognition', 'perception', 'stative']
# discomposed : ['emotion']
# snuffling : ['perception', 'body']
# ace : ['social', 'competition']
# festooned : ['creation']
# fastening : ['contact', 'change']
# echo : ['communication', 'perception', 'stative']
# guided : ['motion', 'social', 'perception', 'contact']
# steered : ['motion', 'social']
# dragoon : ['social']
# warrant : ['communication']
# labeled : ['communication', 'contact', 'cognition']
# procures : ['possession', 'consumption']
# communicate : ['communication', 'possession', 'contact']
# nonplussed : ['cognition']
# relieve : ['body', 'social', 'emotion', 'communication', 'possession', 'change']
# endeavor : ['social']
# fuel : ['possession', 'emotion']
# dissolved : ['change', 'motion', 'emotion']
# canal : ['possession']
# slap : ['contact']
# angled : ['motion', 'contact', 'competition', 'cognition']
# footing : ['possession', 'motion', 'cognition']
# gall : ['perception', 'emotion']
# gushing : ['motion', 'communication', 'contact']
# sickened : ['emotion', 'body', 'perception']
# blacken : ['change']
# beach : ['motion']
# tinged : ['communication', 'change', 'perception']
# raced : ['motion', 'competition', 'social']
# pool : ['possession', 'competition']
# alarming : ['emotion', 'communication']
# frighten : ['emotion']
# spoil : ['social', 'change', 'emotion', 'contact']
# dismay : ['emotion']
# evoked : ['emotion', 'creation', 'communication']
# strapped : ['contact', 'change', 'body']
# waded : ['motion', 'contact']
# unhitched : ['contact']
# burden : ['contact', 'communication']
# shore : ['stative', 'motion', 'contact']
# paddle : ['motion', 'social', 'contact']
# punt : ['contact', 'competition']
# beckoning : ['communication', 'emotion']
# cuckoo : ['communication']
# boat : ['motion']
# baited : ['communication', 'social', 'competition']
# bobbing : ['motion', 'contact', 'communication', 'body']
# proof : ['creation', 'contact', 'cognition', 'change']
# destroyed : ['creation', 'contact', 'competition']
# spinning : ['motion', 'creation', 'contact', 'communication', 'change']
# hook : ['contact', 'possession', 'creation', 'consumption', 'competition', 'communication']
# rearing : ['motion', 'social', 'stative', 'creation']
# culture : ['change']
# ambition : ['emotion']
# reassured : ['emotion', 'communication']
# clanking : ['perception']
# coupled : ['contact', 'social']
# imported : ['possession', 'communication']
# rear : ['motion', 'social', 'stative', 'creation']
# expanded : ['motion', 'change', 'communication']
# expanding : ['motion', 'change', 'communication']
# registering : ['social', 'communication', 'perception', 'creation', 'cognition']
# relegated : ['social', 'cognition']
# compassionating : ['emotion']
# exile : ['social']
# stunned : ['change', 'contact', 'perception']
# vocalized : ['communication', 'creation']
# cradle : ['contact', 'social', 'motion', 'competition']
# frown : ['body']
# reasoning : ['cognition', 'communication']
# punish : ['social']
# hiccoughed : ['body']
# dribbling : ['motion', 'contact', 'body']
# doubling : ['change', 'contact', 'motion', 'possession', 'creation']
# caress : ['contact']
# prohibited : ['communication']
# petting : ['contact']
# denounced : ['communication', 'social']
# consuming : ['consumption', 'contact', 'cognition']
# opine : ['communication', 'cognition']
# environed : ['contact']
# softening : ['perception', 'change', 'stative', 'contact', 'communication']
# civilizing : ['social', 'change']
# recommend : ['communication', 'change']
# sterilized : ['body']
# trumpet : ['communication', 'creation']
# cope : ['social']
# acclimatize : ['change']
# acclimatized : ['change']
# dug : ['contact', 'social', 'perception', 'motion', 'cognition']
# slate : ['cognition', 'social', 'contact']
# convincing : ['communication']
# chart : ['cognition', 'creation']
# distressing : ['social', 'emotion']
# heading : ['motion', 'social', 'stative', 'contact']
# dubbed : ['communication', 'social']
# derived : ['cognition', 'possession', 'change', 'stative']
# cube : ['cognition', 'contact']
# surroundings : ['contact', 'competition']
# intermediate : ['communication']
# papered : ['contact']
# carpeted : ['stative', 'contact']
# ventilated : ['change', 'perception', 'motion', 'communication']
# thrive : ['change', 'possession']
# contracting : ['communication', 'social', 'contact', 'body', 'change']
# complicated : ['change']
# resign : ['social', 'possession', 'cognition']
# kitten : ['body']
# attenuated : ['change']
# chanted : ['communication']
# rhyme : ['creation', 'stative']
# bunting : ['contact']
# rabbit : ['competition']
# burrowed : ['motion']
# hailed : ['communication', 'stative', 'weather']
# spangled : ['perception', 'creation']
# remarking : ['communication']
# advocated : ['communication']
# managing : ['social', 'contact']
# noding : ['communication', 'body', 'motion']
# balancing : ['stative', 'possession', 'contact']
# nodings : ['communication', 'body', 'motion']
# hooding : ['contact']
# bravo : ['communication']
# weep : ['body']
# intensified : ['change']
# alleviated : ['body', 'change']
# frequent : ['social', 'motion']
# collapsed : ['motion', 'body', 'emotion', 'change']
# thump : ['motion', 'perception', 'contact']
# strained : ['competition', 'emotion', 'consumption', 'contact', 'body', 'change']
# leapfrog : ['motion', 'change']
# ram : ['contact']
# darting : ['motion']
# propped : ['contact']
# giggled : ['body']
# prim : ['change', 'body']
# reminiscing : ['cognition']
# lapsing : ['motion', 'change', 'body', 'possession']
# deserved : ['stative']
# segment : ['contact']
# shied : ['motion', 'contact']
# trimmed : ['contact', 'creation', 'change', 'stative']
# leveled : ['competition', 'creation', 'contact', 'communication', 'change']
# forged : ['creation', 'motion']
# electrifying : ['emotion', 'change']
# deluge : ['contact', 'communication', 'change']
# beetling : ['stative', 'motion', 'contact']
# scurrying : ['motion']
# soaring : ['motion', 'change']
# ache : ['perception', 'emotion']
# netting : ['possession', 'creation', 'contact']
# bounded : ['motion', 'stative', 'change']
# retaining : ['stative', 'social', 'possession', 'cognition']
# brooch : ['contact']
# reaped : ['contact', 'possession']
# daunts : ['emotion']
# switched : ['change', 'possession', 'contact']
# carved : ['contact']
# inlaid : ['creation']
# hurled : ['contact', 'motion', 'communication']
# shunned : ['communication', 'social']
# preserved : ['stative', 'possession', 'change']
# ensured : ['communication', 'cognition']
# formulated : ['communication', 'creation']
# iced : ['contact', 'change']
# intervene : ['social', 'stative', 'change']
# exercising : ['consumption', 'social', 'body', 'cognition']
# unpack : ['contact']
# flutter : ['motion', 'body']
# promising : ['communication', 'stative']
# crop : ['contact', 'creation']
# fulfill : ['creation', 'stative', 'consumption']
# freak : ['emotion']
# pondered : ['cognition']
# manicuring : ['body']
# sliding : ['motion']
# dividing : ['social', 'cognition', 'stative', 'contact', 'motion']
# render : ['change', 'possession', 'creation', 'communication', 'contact']
# imbibed : ['contact', 'consumption', 'cognition']
# clutch : ['contact', 'cognition']
# spear : ['contact', 'stative']
# bedecked : ['creation']
# shrine : ['contact']
# showered : ['possession', 'contact', 'body', 'weather', 'consumption']
# suck : ['consumption', 'motion', 'weather', 'stative', 'perception', 'contact']
# benefit : ['possession']
# tint : ['change']
# ingratiating : ['emotion']
# enveloping : ['contact']
# surveying : ['cognition', 'perception']
# splash : ['contact', 'motion', 'perception']
# reformed : ['change']
# delayed : ['change', 'stative']
# swooped : ['motion', 'contact']
# tidying : ['change']
# winked : ['body', 'perception']
# buzzed : ['perception', 'motion', 'stative', 'communication']
# taxed : ['possession', 'consumption', 'communication']
# astounding : ['cognition']
# owing : ['possession', 'stative']
# vest : ['social', 'possession', 'body']
# reconciled : ['change', 'communication', 'cognition']
# complement : ['change']
# grouped : ['cognition', 'competition']
# accord : ['stative', 'possession']
# thickening : ['change']
# encased : ['contact']
# jot : ['communication']
# knitted : ['creation', 'contact']
# revive : ['body', 'change']
# accompanying : ['stative', 'motion', 'creation']
# simulate : ['creation']
# decide : ['cognition']
# enclose : ['contact', 'stative', 'change']
# furnishes : ['possession']
# woo : ['social']
# eloping : ['motion']
# disapproved : ['cognition', 'communication']
# lowered : ['motion', 'change', 'contact', 'body']
# rowing : ['motion']
# tempted : ['communication', 'emotion']
# function : ['contact', 'stative', 'competition']
# invented : ['creation']
# patented : ['possession', 'social', 'change']
# specified : ['communication', 'stative', 'cognition']
# parrot : ['communication']
# psalm : ['creation']
# scraped : ['contact', 'creation', 'motion', 'possession', 'communication', 'change']
# bulge : ['change', 'stative', 'motion']
# elicited : ['emotion', 'creation', 'cognition']
# filed : ['communication', 'contact', 'motion']
# including : ['stative', 'cognition', 'change', 'social']
# moderate : ['communication', 'change', 'social']
# array : ['contact', 'cognition']
# complexioned : ['change']
# appease : ['emotion', 'consumption', 'communication']
# campaign : ['competition', 'social']
# waterproofed : ['contact']
# steal : ['possession', 'motion', 'competition']
# departed : ['motion', 'stative', 'social']
# project : ['communication', 'stative', 'contact', 'perception', 'creation', 'cognition']
# boiling : ['change', 'motion', 'emotion']
# paced : ['motion', 'change', 'cognition']
# gossiping : ['communication']
# district : ['social']
# wriggling : ['motion']
# tearing : ['contact', 'motion', 'body']
# harking : ['perception']
# feint : ['creation']
# wax : ['contact', 'change']
# candle : ['perception']
# premise : ['communication', 'cognition']
# communicating : ['communication', 'possession', 'contact']
# resuscitated : ['body']
# deposited : ['contact', 'possession']
# rustle : ['perception', 'possession']
# triple : ['change', 'contact']
# factor : ['cognition', 'possession']
# shear : ['contact', 'change']
# marries : ['social']
# abolishing : ['social']
# reset : ['communication', 'change']
# approaching : ['motion', 'stative', 'social', 'communication']
# drinking : ['consumption', 'cognition']
# warranted : ['communication']
# mushroom : ['contact', 'change']
# cemented : ['contact']
# sandbag : ['social', 'contact', 'communication', 'change']
# cowes : ['emotion']
# partook : ['stative', 'possession', 'consumption']
# allured : ['communication']
# assured : ['communication', 'cognition', 'emotion']
# tittered : ['body']
# repeat : ['communication', 'creation', 'change', 'social']
# hating : ['emotion', 'body', 'possession']
# wounded : ['body', 'emotion']
# create : ['creation', 'social']
# agitating : ['social', 'emotion', 'motion', 'contact']
# flattered : ['communication']
# undergoing : ['perception']
# cure : ['body', 'change']
# bonded : ['contact', 'social', 'possession']
# inherit : ['possession']
# cajole : ['communication']
# gnashing : ['body']
# reminds : ['cognition', 'communication']
# ambling : ['motion']
# contused : ['contact']
# relaxing : ['body', 'change', 'social']
# intrigue : ['stative', 'cognition']
# conceived : ['creation', 'cognition', 'body']
# exerted : ['consumption', 'possession', 'social']
# bicycling : ['motion']
# gripping : ['contact', 'emotion']
# crimsoned : ['body']
# mounting : ['contact', 'change', 'creation', 'motion']
# placing : ['contact', 'social', 'cognition', 'possession', 'communication', 'competition', 'creation', 'stative']
# trusting : ['cognition', 'social', 'emotion', 'possession']
# devour : ['contact', 'emotion', 'consumption']
# wolf : ['consumption']
# plunge : ['contact', 'motion', 'change', 'cognition']
# tinge : ['communication', 'change']
# whispering : ['communication']
# loathes : ['emotion']
# bred : ['creation', 'contact', 'body']
# blaze : ['weather', 'competition', 'motion', 'communication']
# charging : ['competition', 'communication', 'possession', 'motion', 'social', 'contact', 'emotion', 'creation', 'cognition', 'change']
# disagreed : ['communication', 'stative']
# emphasizing : ['communication']
# permeates : ['contact']
# inherits : ['possession']
# persuaded : ['social', 'communication']
# lingers : ['stative', 'motion']
# cruise : ['motion', 'perception']
# continuing : ['stative', 'communication', 'motion', 'social', 'change']
# assure : ['communication', 'cognition', 'emotion']
# conversing : ['communication']
# dismayed : ['emotion']
# excused : ['communication']
# attract : ['contact', 'emotion']
# reviving : ['body', 'change']
# inhaled : ['consumption', 'body']
# discouraged : ['communication', 'emotion']
# ornamented : ['creation', 'stative']
# attending : ['stative', 'social', 'perception']
# manufactured : ['creation']
# welsh : ['social']
# embedded : ['contact', 'competition']
# graven : ['contact']
# chine : ['contact']
# rung : ['perception', 'communication', 'contact']
# rebuked : ['communication']
# entering : ['motion', 'competition', 'social', 'stative', 'communication', 'creation', 'contact', 'change']
# bulwark : ['competition']
# chattering : ['perception', 'contact', 'communication']
# carp : ['communication']

# %%
noun_cate_dic = {}

for i in noun_dic:
    for j in noun_dic[i]:
        if j not in noun_cate_dic:
            noun_cate_dic[j] = 1
        else:
            noun_cate_dic[j] +=1

print(noun_cate_dic)
# Out:
# {'group': 433, 'substance': 255, 'artifact': 1474, 'food': 307, 'act': 1280, 'quantity': 257, 'time': 204, 'state': 572, 'person': 1127, 'location': 328, 'cognition': 614, 'feeling': 199, 'attribute': 707, 'event': 406, 'body': 234, 'object': 249, 'animal': 271, 'relation': 101, 'communication': 1002, 'shape': 135, 'phenomenon': 126, 'possession': 203, 'Tops': 46, 'process': 95, 'motive': 13, 'plant': 191}

# %%
verb_cate_dic = {}

for i in verb_dic:
    for j in verb_dic[i]:
        if j not in verb_cate_dic:
            verb_cate_dic[j] = 1
        else:
            verb_cate_dic[j] +=1

print(verb_cate_dic)
# Out:
# {'motion': 1106, 'stative': 865, 'consumption': 310, 'creation': 600, 'social': 1057, 'competition': 430, 'communication': 1383, 'contact': 1486, 'body': 626, 'possession': 754, 'change': 1261, 'emotion': 516, 'cognition': 777, 'perception': 569, 'weather': 99}

# %%
plt.figure()
plt.bar(noun_cate_dic.keys(),noun_cate_dic.values())
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure()
plt.bar(verb_cate_dic.keys(),verb_cate_dic.values())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Book 2

# %%
#Reading Book
file = open("book2.txt",encoding="utf8")

# variable T
S = file.read()

# variable T2
S2=S

# Printing the contents of the book stored in T
print(S[:1000])
# Out:
# ﻿The Project Gutenberg EBook of A Book, by Djuna Barnes
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever.  You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this eBook or online at
# www.gutenberg.org.  If you are not located in the United States, you'll
# have to check the laws of the country where you are located before using
# this ebook.
#
#
#
# Title: A Book
#
# Author: Djuna Barnes
#
# Release Date: December 11, 2019 [EBook #60904]
#
# Language: English
#
# Character set encoding: UTF-8
#
# *** START OF THIS PROJECT GUTENBERG EBOOK A BOOK ***
#
#
#
#
# Produced by Richard Tonsing, Tim Lindell, and the Online
# Distributed Proofreading Team at http://www.pgdp.net (This
# book was produced from images made available by the
# HathiTrust Digital Library.)
#
#
#
#
#
#
#
#
#
#                                  A BOOK
#
#
# [Illustration]
#
#
#
#
#                                  A BOO

# %%
translator = str.maketrans("","",string.punctuation)
S=S.translate(translator)
print(S[:1000])
# Out:
# ﻿The Project Gutenberg EBook of A Book by Djuna Barnes
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever  You may copy it give it away or reuse it under the terms
# of the Project Gutenberg License included with this eBook or online at
# wwwgutenbergorg  If you are not located in the United States youll
# have to check the laws of the country where you are located before using
# this ebook
#
#
#
# Title A Book
#
# Author Djuna Barnes
#
# Release Date December 11 2019 EBook 60904
#
# Language English
#
# Character set encoding UTF8
#
#  START OF THIS PROJECT GUTENBERG EBOOK A BOOK
#
#
#
#
# Produced by Richard Tonsing Tim Lindell and the Online
# Distributed Proofreading Team at httpwwwpgdpnet This
# book was produced from images made available by the
# HathiTrust Digital Library
#
#
#
#
#
#
#
#
#
#                                  A BOOK
#
#
# Illustration
#
#
#
#
#                                  A BOOK

# %%
# Removing acknowledgement
S = re.sub("Project[\s\S]*CONTENTS","",S)
S = re.sub("TRANSCRIBER[\s\S]*","",S)
print(S[:1000])
# Out:
# ﻿The
#
#
#                                                   PAGE
#
#                   A NIGHT AMONG THE HORSES           1
#
#                   THREE FROM THE EARTH              15
#
#                   THE VALET                         31
#
#                   TO THE DOGS                       44
#
#                   BEYOND THE END                    59
#
#                   PASTORAL                          74
#
#                   OSCAR                             76
#
#                   ANTIQUE                          103
#
#                   KATRINA SILVERSTAFF              104
#
#                   HUSH BEFORE LOVE                 116
#
#                   THE ROBIN’S HOUSE                117
#
#                   PARADISE                         131
#
#                   NOMAN’SMARE                    132
#
#                   SIX SONGS OF KHALIDINE           145
#
#                   THE DOVE                         147
#
#                   MOTHER                           164
#
#                   SONG IN AUTUMN

# %%
# Removing Chapter Names
S=re.sub("[A-Z]{2,}","",S)
print(S[:1000])
# Out:
# ﻿The
#
#
#
#
#                   A               1
#
#                                    15
#
#                                             31
#
#                                            44
#
#                                         59
#
#                                             74
#
#                                                76
#
#                                             103
#
#                                  104
#
#                                      116
#
#                    ’S                 117
#
#                                            131
#
#                   ’                    132
#
#                                 145
#
#                                             147
#
#                                              164
#
#                                        172
#
#                                           173
#
#                                             179
#
#                                        180
#
#                   I’D              194

# %%
# Removing Chapter Numbers
S=re.sub("[0-9]+","",S)
print(S)
# Out:
# ﻿The
#
#
#
#
#                   A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                    ’S
#
#
#
#                   ’
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                   I’D
#
#
#
#
#
#                   A   A   A
#
#
#
#
#
#
#
#
#
#
#
#                      Study          Frontispiece
#
#                                      Facing page
#
#                      Portrait
#
#                      Portrait
#
#                      Drawing
#
#                      Portrait Study
#
#                      Portrait
#
#
#
#
#                                  A
#
#
#
#
#                         A
#
#
# Toward dusk in the Summer of the year a man dressed in a frock coat
# and top hat and carrying a cane crept through the underbrush bordering
# the corral of the Buckler farm
#
# As he moved small twigs snapped fell and were silent His knees were
# green from wounded shrubbery and grass and his outspread hands tore
# unheeded plants His wrists hurt him and he rested from time to time
# always caring for his hat and knotted yellow cane blowing through his
# moustache
#
# Dew had been falling covering the twilight leaves like myriad faces
# damp with the perspiration of the struggle for existence and half a
# mile away standing out against the darkness of the night a grove of
# white birches shimmered like teeth in a skull
#
# He heard the creaking of a gate and the splashing of late rain into the
# depths of a dark cistern His heart ached with the nearness of the
# earth the faint murmur of it moving upon itself like a sleeper who
# turns to throw an arm about a beloved
#
# A frog began moaning among the skunk cabbages and John thrust his hand
# deep into his bosom
#
# Something somnolent seemed to be here and he wondered It was like a
# deep heavy yet soft prison where without sin one may suffer
# intolerable punishment
#
# Presently he went on feeling his way He reached a high plank fence and
# sensing it with his fingers he lay down resting his head against the
# ground
#
# He was tired he wanted to sleep but he searched for his hat and cane
# and straightened out his coat beneath him before he turned his eyes to
# the stars
#
# And now he could not sleep and wondered why he had thought of it
# something quick was moving the earth it seemed to live to shake with
# sudden immensity
#
# He heard a dog barking and the dim light from a farm window kept
# winking as the trees swung against its square of light The odor of
# daisies came to him and the assuring powerful smell of the stables he
# opened his mouth and drew in his moustache
#
# A faint tumult had begun A tremor ran under the length of his body and
# trembled off into the earth like a shudder of joy—died down and repeated
# itself And presently he began to tremble answering throwing out his
# hands curling them up weakly as if the earth were withholding
# something precious necessary
#
# His hat fell off striking a log with a dull hollow sound and he
# pressed his red moustache against the grass weeping
#
# Again he heard it felt it a hundred hoofs beat upon the earth and he
# knew the horses had gone wild in the corral on the other side of the
# fence for animals greet the Summer striking the earth as friends
# strike the back of friends He knew he understood a hail to Summer to
# life to death
#
# He drew himself against the bars pressing his eyes under them peering
# waiting
#
# He heard them coming up across the heavy turf rounding the curve in the
# Willow Road He opened his eyes and closed them again The soft menacing
# sound deepened as heat deepens strikes through the skin into the very
# flesh Head on with long legs rising falling rising again striking
# the ground insanely like needles taking terrible impossible and
# purposeless stitches
#
# He saw their bellies fawncoloured pitching from side to side
# flashing by straining the fence and he rose up on his feet and
# silently swiftly fled on beside them
#
# Something delirious hysterical came over him and he fell Blood
# trickled into his eyes down from his forehead It had a fine feeling for
# a moment like a mane like that roan mare’s mane that had passed
# him—red and long and splendid
#
# He lifted his hand and closed his eyes once more but the soft pounding
# did not cease though now in his sitting position it only jogged him
# imperceptibly as a child on a knee
#
# It seemed to him that he was smothering and he felt along the side of
# his face as he had done in youth when they had put a cap on him that was
# too large Twining green things moist with earthblood crept over his
# fingers the hot impatient leaves pressed in and the green of the
# matted grass was deathly thick He had heard about the freeness of
# nature thought it was so and it was not so
#
# A trailing ground pine had torn up small blades in its journey across
# the hill and a vine wristthick twisted about a pale oak hideously
# gloriously killing it dragging it into dust
#
# A wax Patrick Pipe leaned against his neck staring with black eyes and
# John opened his mouth running his tongue across his lips snapping it
# off sighing
#
# Move as he would the grass was always under him and the crackling of
# last Autumn’s leaves and last Summer’s twigs—minute dead of the infinite
# greatness—troubled him Something portentous seemed connected with the
# patient noises about him An acorn dropped striking a thin fine powder
# out of a frail oak pod He took it up tossing it He had never liked to
# see things fall
#
# He sat up with the dim thunder of the horses far off but quickening
# his heart
#
# He went over the scene he had with Freda Buckler back there in the
# house the long quivering spears of potgrass standing by the window as
# she walked up and down pulling at them talking to him
#
# Small with cunning fiery eyes and a pink and pointed chin A daughter
# of a mother who had known too many admirers in her youth a woman with
# an ample lap on which she held a Persian kitten or a trifle of fruit
# Bounty avarice desire intelligence—both of them had always what they
# wanted
#
# He blew down his moustache again thinking of Freda in her floating
# yellow veil that he had called ridiculous She had not been angry he
# was nothing but a stable boy then It was the way with those small
# intriguing women whose nostrils were made delicate through the pain of
# many generations that they might quiver whenever they caught a whiff of
# the stables
#
# “As near as they can get to the earth” he had said and was Freda
# angry She stroked his arm always softly looking away an inner
# bitterness drawing down her mouth
#
# She said walking up and down quickly looking ridiculously small
#
# “I am always gentle John”—frowning trailing her veil thrusting out
# her chin
#
# He answered “I liked it better where I was”
#
# “Horses” she said showing sharp teeth “are nothing for a man with your
# bile—potboy—curry comber smelling of saddle soap—lovely” She
# shrivelled up her nose touching his arm “Yes but better things I
# will show you—you shall be a gentleman—fine clothes you will like them
# they feel nice” And laughing she turned on one high heel sitting down
# “I like horses they make people better you are amusing intelligent
# you will see——”
#
# “A lackey” he returned passionately throwing up his arm “What is
# there in this for you what are you trying to do to me The
# family—askance—perhaps—I don’t know”
#
# He sat down pondering He was getting used to it or thought he was all
# but his wordy remonstrances He knew better when thinking of his horses
# realizing that when he should have married this small unpleasant and
# clever woman he would know them no more
#
# It was a game between them which was the shrewder which would win out
# He A boy of ill breeding grown from the gutter fancied by this woman
# because he had called her ridiculous or for some other reason that he
# would never know This kind of person never tells the truth and this
# more than most things troubled him Was he a thing to be played with
# debased into something better than he was—than he knew
#
# Partly because he was proud of himself in the costume of a groom partly
# because he was timid he desired to get away to go back to the stables
# He walked up to the mirrors as if about to challenge them peering in
# He knew he would look absurd and then knew with shame that he looked
# splendidly better than most of the gentlemen that Freda Buckler knew He
# hated himself A man who had grown out of the city’s streets a fine
# common thing
#
# She saw him looking into the mirrors one after the other and drew her
# mouth down She got up walking beside him in the end between him and
# them taking his arm
#
# “You shall enter the army—you shall rise to General or Lieutenant at
# least—and there are horses there and the sound of stirrups—with that
# physique you will be happy—authority you know” she said shaking her
# chin smiling
#
# “Very well but a common soldier——”
#
# “As you like—afterward”
#
# “Afterward”
#
# “Very well a common soldier”
#
# He sensed something strange in her voice a sort of irony and it took
# the patience out of him
#
# “I have always been common I could commit crimes easily gladly—I’d
# like to”
#
# She looked away “That’s natural” she said faintly “it’s an instinct
# all strong men have——”
#
# She knew what was troubling him thwarted instincts common beautiful
# instincts that he was being robbed of He wanted to do something final
# to prove his lower order caught himself making faces idiot faces and
# she laughed
#
# “If only your ears stuck out chin receded” she said “you might look
# degenerate common but as it is——”
#
# And he would creep away in hat coat and with his cane to peer at his
# horses never daring to go in near them Sometimes when he wanted to
# weep he would smear one glove with harness grease but the other one he
# held behind his back pretending one was enough to prove his revolt
#
# She would torment him with vases books pictures making a fool of him
# gently persistently making him doubt by cruel means the means of
# objects he was not used to eternally taking him out of his sphere
#
# “We have the best collection of miniatures” she would say with one knee
# on a low ottoman bringing them out in her small palm
#
# “Here look”
#
# He would put his hands behind him
#
# “She was a great woman—Lucrezia Borgia—do you know history——” She put it
# back because he did not answer letting his mind a curious one torment
# itself
#
# “You love things very much don’t you” she would question because she
# knew that he had a passion for one thing only She kept placing new
# ladders beneath his feet only to saw them off at the next rung making
# him nothing more than a nervous irritable experiment He was uneasy
# like one given food to smell and not to taste and for a while he had
# not wanted to taste and then curiosity began and he wanted to and he
# also wanted to escape and he could do neither
#
# Well after he had married her what then Satisfy her whim and where
# would he be He would be nothing neither what he had been nor what
# other people were This seemed to him at times her wish—a sort of
# place between lying down and standing up a cramped position a slow
# death A curious woman
#
# This same evening he had looked at her attentively for the first time
# Her hair was rather pretty though too mousy yet just in the nape of
# the neck where it met the lawn of the collar it was very attractive
# She walked well for a little woman too
#
# Sometimes she would pretend to be lively would run a little catch
# herself at it as if she had not intended to do it and calm down once
# more or creeping up to him stroking his arm talking to him she would
# walk beside him softly slowly that he might not step out that he
# would have to crawl across the carpet
#
# Once he had thought of trying her with honesty with the truth of the
# situation Perhaps she would give him an honest answer and he had
# tried
#
# “Now Miss Freda—just a word—what are you trying to do What is it you
# want What is there in me that can interest you I want you to tell me—I
# want to know—I have got to ask someone and I haven’t anyone to ask but
# you”
#
# And for a moment she almost relented only to discover that she could
# not if she had wished She did not know always what she meant herself
#
# “I’ll tell you” she said hoping that this somehow might lead her
# into the truth for herself if not for him but it did not “you are a
# little nervous you will get used to it—you will even grow to like it
# Be patient You will learn soon enough that there is nothing in the
# world so agreeable as climbing changing”
#
# “Well” he said trying to read her “and then”
#
# “That’s all you will regret the stables in the end—that’s all” Her
# nostrils quivered A light came into her eyes a desire to defy to be
# defied
#
# Then on this last night he had done something terrible he had made a
# blunder There had been a party The guests a lot of them were mostly
# drunk or touched with drink And he too had too much He remembered
# having thrown his arms about a tall woman gowned in black with loose
# shoulder straps dragging her through a dance He had even sung a bit of
# a song madly wildly horribly And suddenly he had been brought up
# sharp by the fact that no one thought his behaviour strange that no one
# thought him presumptuous Freda’s mother had not even moved or dropped
# the kitten from her lap where it sat its loud resolute purr shaking the
# satin of her gown
#
# And he felt that Freda had got him where she wanted him between two
# rungs Going directly up to her he said
#
# “You are ridiculous” and twirled his moustache spitting into the
# garden
#
# And he knew nothing about what happened until he found himself in the
# shrubbery crawling toward the corral through the dusk and the dampness
# of the leaves carrying his cane making sure of his hat looking up at
# the stars
#
# Now he knew why he had come He was with his horses again His eyes
# pressed against the bars stared in The black stallion in the lead had
# been his special pet a rough animal but kindly knowing And here they
# were once more tearing up the grass galloping about in the night like
# a ballroom full of real people people who wanted to do things who did
# what they wanted to do
#
# He began to crawl through the bars slowly deftly and when half way
# through he paused thinking
#
# Presently he went on again and drawing himself into the corral his hat
# and cane thrown in before him he lay there mouth to the grass
#
# They were still running but less madly one of them had gone up the
# Willow Road leading into a farther pasture in a flare of dust through
# which it looked immense and faint
#
# On the top of the hill three or four of the horses were standing
# testing the weather He would mount one he would ride away he would
# escape And his horses the things he knew would be his escape
#
# Bareback he thought would be like the days when he had taken what he
# could from the rush of the streets joy exhilaration life and he was
# not afraid He wanted to stand up to cry aloud
#
# And he saw ten or twelve of them rounding the curb and he did stand up
#
# They did not seem to know him did not seem to know what to make of him
# and he stared at them wondering He did not think of his white shirt
# front his sudden arising the darkness their excitement Surely they
# would know in a moment more
#
# Wheeling flaring their wet nostrils throwing up their manes striking
# the earth in a quandary they came on whinnied faintly and he knew
# what it was to be afraid
#
# He had never been afraid and he went down on his knees With a new
# horror in his heart he damned them He turned his eyes up but he could
# not open them He thought rapidly calling on Freda in his heart
# speaking tenderly promising
#
# A flare of heat passed his throat and descended into his bosom
#
# “I want to live I can do it—damn it—I can do it I can forge ahead
# make my mark”
#
# He forgot where he was for a moment and found new pleasure in this
# spoken admission this new rebellion He moved with the faint shaking of
# the earth like a child on a woman’s lap
#
# The upraised hoofs of the first horse missed him but the second did
# not
#
# And presently the horses drew apart nibbling here and there switching
# their tails avoiding a patch of tall grass
#
#
#
#
#
#
#
#         │
#            │ brothers
#            │                          〃
#             │                          〃
#
#      —│An adventuress a lady of leisure
#
#   —Late afternoon
#
#   — ’S boudoir A long narrow room with a great many
#         lacquer screens in various shades of blue a tastefully
#         decorated room though rather extreme
#
# At the rise of the curtain the three  brothers are discovered
# sitting together on a couch to the left They look like peasants of the
# most obvious type They are tall rather heavy—and range in age from
# nineteen to twentyfive They have sandy sunbleached hair that insists
# upon sticking straight up—oily sweaty skins—large hanging lips and
# small eyes on which a faint whitish down moves for lashes They are
# clumsy and ill clothed Russet shoes are on all six feet They each
# wear a purple aster and each has on a tie of the superstunning
# variety—they have evidently done their best to be as one might say “well
# dressed”
#
# When they speak—aside from their grunts—their voices are rough nasal
# and occasionally crack They are stoopshouldered and their hands are
# excessively ugly
#
# Yet in spite of all this their eyes are intelligent their smiles
# gentle melancholy compassionate And though they have a look of
# formidable grossness and stupidity there is on second observation a
# something beneath all this in no way in keeping with this first
# impression
#
#  the youngest and the smallest looks around the room carefully
#
#
# —A nice room eh He tries to whisper but it comes forth buzzing
# and harsh
#
# —A woman’s room
#
# —How
#
# —A narrow room John
#
# —Well
#
# —Cats and narrow walls
#
# —Grunting Ugh
#
# —Hush—I hear her coming The curtains part and
# enters She is a woman of about forty Handsome Dark She is
# beautifully dressed—in a rather seductive fashion She has a very
# interesting head she has an air of one used to adulation and the
# pleasure of exerting her will She has a trick of narrowing her eyes As
# she comes forward there is a general commotion among the brothers but
# none manages to stand up
#
# —Good day gentlemen
#
#  —Good day
#
# —Nice of you to call on me She seats herself crossing her
# legs You are the three Carsons John James and Henry aren’t you I
# haven’t seen you for years yet I think I should have known you
#
#  —Ah ha
#
# —Yes I presume I should have known you I have a good memory Well
# as I said it’s nice of you to come to see me Social
#
# —You might call it that
#
# —It’s quite nice to get an unexpected visitor or so I’m the kind of
# woman who knows just who is going to call on Monday Tuesday Thursday——
#
#  —Ah ha
#
# —How’s the country
#
# —Just the same
#
# —It always is—Don’t you go mad—watching it
#
# —Now and again
#
# —And how’s your father Not pausing for an answer—almost to
# herself I remember—he was always mad He used to wear a green cloth
# suit and he carried white rats all over his shoulders Remembering
# the three Ah yes your father—he was a barber wasn’t he
#
# —No a chemist
#
# —Laughing uneasily I have a bad memory after all Well anyway
# in those days he had begun to be queer—everyone noticed it—even that
# funny man who had those three flaxenhaired daughters with the thin
# ankles who lives at the end of the street—— And your mother—a
# prostitute I believe
#
# —Calmly At times
#
# —A dancing girl without a clean word in her vocabulary or a whole
# shirt to her name——
#
# —But a woman with fancies
#
# —Sarcastically And what ability
#
# —Oh none just a burning desire
#
# —What’s the use of going into that How did you get here—what for
#
#  —On bicycles
#
# —Bursting into laughter How exactly ridiculous and
# appropriate—and what else
#
# —To see how the sun falls in a place like this
#
# —Angrily rising Well you see from left to right and right
# to left——
#
# —True
#
# —Quietly And we wanted to see how you walked and sat down and
# crossed your legs——
#
# —And to get father’s letters
#
# —Well you see how I walk sit down cross my legs What letters
#
# —Letters to you
#
# —Uneasily So you know about that—well and what would you
# fellows do with them—read them to see how clever they are
#
# —No we have the clever ones
#
# —Mine
#
#  and —Nodding Exactly
#
# —Oh
#
# —You suffer
#
# —From time to time—there’s always a reaction
#
# —That’s vulgar isn’t it
#
# —Not unusually
#
# —The letters
#
# —To herself Well there is malice in me—what of it We’ve all
# been a while with the dogs we don’t all learn to bark
#
# —Ah ha
#
# —See here what will you do with your father’s letters
#
# —Destroy them perhaps
#
# —And if I give them to you—will your father be as generous with
# mine
#
# —Father is undoubtedly a gentleman—even at this moment
#
# —Well we shall see about that—first tell me how you live
#
# —We go down on the earth and find things tear them up shaking the
# dirt off Making motions to illustrate Then there are the cows to
# be milked the horses—a few—to be fed shod and curried—do you wish me
# to continue
#
# —Yes yes go on
#
# —Taking the tale up We get up at dawn and our father turns
# over in bed and whispers “If you meet anyone say nothing if you are
# asked a question look stupid——”
#
# —I believe you
#
# —And he says “Go about your work as if you had neither sight
# speech nor hearing——”
#
# —Yes——
#
# —And he adds “If you should meet a woman in the road——”
#
# —Excited Then what
#
# —That’s enough Then of a Sunday we watch the people going to
# church when we hear the “Amen” we lift a little and sit back—and then
# again——
#
# —Religion
#
# —Enough for our simple needs
#
# —Poor sheep
#
# —Wise sheep
#
# —What Well perhaps No one is any longer sure of anything Then
# what
#
# —When we come home he says “What have you seen and heard today” He
# never asks “What have you said”
#
# —He trusts you
#
# —Undoubtedly Sometimes we say “We saw a hawk flying” or “A
# badger passed” and sometimes we bring him the best treat of all——
#
# —Well
#
# —Something dead
#
# —Dead
#
# —Anything that has destroyed the crops—a mole—a fieldmouse
#
# —And never anything that’s harmless
#
# —Never
#
# —Well see here I’ll give you those letters Suddenly my heart says
# to me “Kate give the oxen the rope they won’t run away”—Isn’t it so
# Very well I put my hand on a certain package and all is over—I’m about
# to be married you know She has risen and gone over to a little box
# standing on the desk Out from this she takes a package of letters tied
# with a red ribbon She turns and walks straight up to  I’ll give
# them to you You are the youngest the gentlest and you have the nicest
# hands She sits down breathing with difficulty
#
# —Putting them into his blouse Thank you Kate Morley
#
# —Now tell me about everything How is that mother of yours I
# remember her—she was on the stage—she danced as they say and she sang
# She had a pet monkey—fed it honey out of a jar kept full by her
# admirers grooms stage hands what not——
#
# —Yes and she used to draw pictures of it in the style of
# Dürer—almost morbid—and later it caught a disease and died——
#
# —I don’t doubt it—and she she had an underlip like a balloon—and
# your father kissed that mouth was even tempted——
#
# —My father often saw beyond the flesh
#
# —Kissed such a creature
#
# —At such times she was beautiful
#
# —With a touch of humility Yes I’m sorry—I remember Once I
# passed her and instead of saying something something horrible—she
# might—she looked down
#
# —She was beautiful looking down
#
# —Angry And I I suppose I wasn’t beautiful to look at——
#
# —No I suppose not that is not for her
#
# —Viciously Well let me tell you you haven’t inherited her
# beauty Look at your hands—thick hard ugly—and the life lines in them
# like the life lines in the hands of every laborer digging sewers——
#
# —There’s something in that but they are just beginning
#
# —Turning on them Look at you You’re ugly and clumsy and
# uncouth You grunt and roar you wear abominable clothes—and you have no
# manners—and all because of your father your mighty righteous and
# original father You don’t have to be like this You needn’t have little
# pigs’ eyes with bleached lashes and thick hanging lips—and noses—but I
# suppose you’ve got adenoids and you may suffer from the fact that your
# mother had a rupture and in all probability you have the beginning of
# ulcers of the stomach for God knows your father couldn’t keep a meal
# down like a gentleman
#
# —He was delicate
#
# —And why was he delicate He called himself “The little Father” as
# one might say “The great Emperor” Well to have a father to whom you
# can go and say “All is not as it should be”—that would have been
# everything But what could you say to him and what had he to say to
# you Oh we all have our pathetic moments of being at our best but he
# wasn’t satisfied with that he wanted to be at it all the time And the
# result the life of a mole “Listen and say nothing” Then he becomes
# the gentleman farmer because he discovers he cannot be the Beloved Fool
# Suddenly he is the father of three creatures for all the world like
# Russian peasants—without an idea a subtlety—it’s wicked that’s all
# wicked—and as for that how do you know but that all three of you had a
# different mother Why great God I might be the mother of one of you
#
# —Significantly So I believe madam
#
# —Unheeding Do you think a man like your father had any right to
# bring such children as you into the world—three columns of flesh without
# one of the five senses She suddenly buries her head in her hands
#
# —Gently You loved our father
#
# —And you also had your pot of honey——
#
# —Thank God I had no ideals—I had a religion
#
# —Just what
#
# —You wouldn’t understand
#
# —Shoes to the needy
#
# —No I’m not that kind vicious boy
#
# —Are you quite certain
#
# —I’ll admit all my candles are not burning for God Well then blow
# them out still I’ll have a light burning somewhere for all your great
# breaths you oxen
#
# —You were never a tower builded of ivory——
#
# —You’re too stupid to be bitter—your voices are too
# undeveloped—you’d say “love” and “hate” the same way
#
# —True we have been shut away from intonations
#
# —You wouldn’t even wish to die
#
# —We shall learn
#
# —Why bother
#
# John—Abruptly rising You have posed for the madonna
#
# —Every woman has
#
# —You have done it better than most
#
# —What do you mean
#
# —I looked at it when I came in He picks up the photograph
#
# —Let it be—I was playing in the “Crown of Thorns” an amateur
# theatrical
#
# —Yes I presumed it was amateur——
#
# —You were a devoted mother
#
# —I have no virtues
#
# —And vices
#
# —Weak in one weak in the other
#
# —However the baby had nice hands——
#
# —Looking at him That is true
#
# —But then babies only use their hands to lift the breast and
# occasionally to stroke the cheek——
#
# —Or throw them up in despair—not a heavy career
#
# —And then
#
# —In an entirely new tone Won’t you have tea— But no pay no
# attention to me that’s another of my nasty malicious tricks Curse
# life
#
# —Your life is drawing to a close
#
# —And from time to time you place your finger on a line of Nietzsche
# or Schopenhauer wondering “How did he say it all in two lines” Eh
#
# —As you say She looks at them slowly one by one You are
# strange things Coming back But at least I’ve given up
# something—look at your mother what did she give up for your father—a
# drunken husband——
#
# —A drunken lover—that’s different
#
# —I can’t help thinking of that great gross stomach of hers
#
# —Gross indeed it won’t trouble him any more
#
# —What’s that
#
# —He cut his throat with a knife——
#
# —Oh my God Pause How did he look
#
# —You can’t satisfy your æsthetic sense that way—he looked—well
# ugly played out yes played out Everything had been too much for
# him—you—us—you could see that in the way he——
#
# —In a whisper Well that’s strange—everything seems—I knew him
# you know She begins to laugh And the dogs barked
#
# —So I believe
#
# —Dazed And you what are you three going to do
#
# —We are coming out of the country—we are going abroad—we can listen
# there
#
# —Abroad—listen—what are you saying
#
# —There are great men abroad
#
# —Anatole France De Gourmont——
#
# —De Gourmont is dead
#
# —There will be others
#
# —Still dully And how did you come to know such names—oh your
# father of course——
#
# —We needed them
#
# —Strange I’ve been prepared for every hour but this——
#
# —Yet I dare say you’ve never cried out
#
# —You are mistaken I’ve cried “To the evil of mind all is evil——”
#
# —Ah ha and what happened
#
# —Sometimes I found myself on my knees——
#
# —And sometimes
#
# —That’s enough haven’t we about cleared all the shavings out of the
# carpenter shop
#
# —You at least will never kill yourself
#
# —Not likely I’ll probably die in bed with my slippers on—you see I
# have a pretty foot
#
# —We understand—you are about to be married
#
# —To a supreme court judge—so I’m cleaning house
#
# —Standing with the photograph But it won’t be quite cleared out
# until this goes He takes it out of the frame and turning it over
# reads “Little John God bless him” He turns it back God bless
# him Well just for that I’d like to keep it
#
# —That’s my affair
#
# —So I see He puts the photo in his blouse with the letters
#
# —Well perhaps—well you’re not so stupid after all—— Come for the
# madonna give me back the letters—I’ll burn them I swear and you can put
# the madonna at the foot of the bed
#
# —I shan’t put it at the foot of the bed—I don’t look at the foot of
# the bed——
#
#  and —Rising And now we shall go
#
# —Her hands to her head But gentlemen gentlemen——
#
# —We won’t need to bother you again We are leaving the country and
# going elsewhere—and there was only one of us to whom you might have
# shown a little generosity—in other words we do not wish to be reminded
# and now we can forget and in time become quite hilarious——
#
# —But gentlemen gentlemen not this way——
#
# —Well Quite suddenly he takes her in his arms raises her face
# and kisses her on the mouth
#
# —Crying out Not that way Not that way
#
# —That’s the way you bore him
#
#
#                    The curtain drops behind them
#
# Illustration
#
#
#
#
#
#
#
# The fields about LouisGeorges’ house grew green in early Spring
# leaving the surrounding country in melancholy grey for LouisGeorges
# was the only man who sowed his ground to rye
#
# LouisGeorges was of small stature His face was oblong too pale A dry
# mouth lay crookedly beneath a nose ending in a slight bulb His long
# animallike arms swung half a rhythm ahead of his legs
#
# He prided himself on his farming though he knew nothing about it He
# surveyed the tender coming green with kindly good nature his acres were
# always a month ahead of his neighbours’
#
# Sometimes standing in the doorway breathing through the thick hair in
# his nostrils stretching his gloves he would look at the lowlying
# sheds and the stables and the dull brown patches of ploughed earth and
# mutter “Splendid splendid”
#
# Finally he would stroll in among the cattle where in dizzy circles
# large coloured flies swayed emitting a soft insistent drone like
# taffeta rubbed against taffeta
#
# He liked to think that he knew a great deal about horses He would look
# solemnly at the trainer and discuss length of neck thinness and shape
# of flank by the hour stroking the hocks of his pet racer Sometimes he
# would say to Vera Sovna “There’s more real breeding in the rump of a
# mare than in all the crowned heads of England”
#
# Sometimes he and Vera Sovna would play in the hay and about the grain
# bins She in her long flounces leaping in and out screaming and
# laughing stamping her high heels setting up a great commotion among
# her ruffles
#
# Once LouisGeorges caught a rat barehanded and with such skill that
# it could not bite He disguised his pride in showing it to her by
# pretending that he had done so to inform her of the rodent menace to
# Winter grain
#
# Vera Sovna was a tall creature with thin shoulders she was always
# shrugging them as if her shoulderblades were heavy She dressed in
# black and laughed a good deal in a very high key
#
# She had been a great friend of LouisGeorges’ mother but since her
# death she had fallen into disrepute It was hinted that she was
# “something” to LouisGeorges and when the townsfolk and neighbouring
# landholders saw her enter the house they would not content themselves
# until they saw her leave it
#
# If she came out holding her skirts crookedly above her thin ankles they
# would find the roofs of their mouths in sudden disapproval while if she
# walked slowly dragging her dress they would say “See what a dust Vera
# Sovna brings up in the driveway she stamps as if she were a mare”
#
# If she knew anything of this feeling she never showed it She would
# drive through the town and turn neither to right nor left until she
# passed the markets with their bright yellow gourds and squashes their
# rosy apples and their splendid tomatoes exhaling an odour of decaying
# sunlight On the rare occasions when LouisGeorges accompanied her she
# would cross her legs at the knee leaning forward pointing a finger at
# him shaking her head laughing
#
# Sometimes she would go into the maids’ quarters to play with Leah’s
# child a little creature with weak legs and neck who always thrust out
# his stomach for her to pat
#
# The maids Berthe and Leah were wellbuilt complacent women with serene
# blue eyes quite far apart and good mouths in which fine teeth grew
# gratefully and upon whom round ample busts flourished like plants They
# went about their work singing or chewing long green salad leaves
#
# In her youth Leah had done something for which she prayed at intervals
# Her memory was always taking her hastily away to kneel before the gaudy
# wax Christ that hung on a beam in the barn Resting her head against the
# boards she would lift her workworn hands bosomhigh sighing praying
# murmuring
#
# Or she would help Berthe with the milking throwing her thick ankles
# under the cow’s udders bringing down a sudden fury of milk shining and
# splashing over her big clean knuckles saying quietly evenly
#
# “I think we will have rain before dawn”
#
# And her sister would answer “Yes before dawn”
#
# Leah would spend hours in the garden her little one crawling after her
# leaving childish smears on the dusty leaves of the growing corn digging
# his hands into the vegetable tops falling and pretending to have fallen
# on purpose grinning up at the sun foolishly until his eyes watered
#
# These two women and LouisGeorges’ valet Vanka made up the household
# saving occasional visits from LouisGeorges’ aunts Myra and Ella
#
# This man Vanka was a mixture of Russian and Jew He bit his nails
# talked of the revolution moved clumsily
#
# His clothes fitted him badly he pomaded his hair which was reddish
# yellow pulled out the short hairs that tormented his throat and from
# beneath his white brows distributed a kindly intelligent look The most
# painful thing about him was his attempt to seem alert his effort to
# keep pace with his master
#
# LouisGeorges would say “Well now Vanka what did they do to you in
# Russia when you were a boy”
#
# “They shot my brother for a red” Vanka would answer pulling the hairs
# “They threw him into prison and my sister took him his food One day
# our father was also arrested then she took two dinner pails instead of
# one Once she heard a noise it sounded like a shot and our father
# returned her one of the pails They say he looked up at her like a man
# who is gazed at over the shoulder” He had told the tale often adding
# “My sister became almost bald later on yet she was a handsome woman
# the students used to come to her chambers to hear her talk”
#
# At such times LouisGeorges would excuse himself and shut himself up to
# write in a large and scrawling hand letters to his aunts with some of
# Vanka’s phrases in them
#
# Sometimes Vera Sovna would come in to watch him lifting her ruffles
# raising her brows Too she would turn and look for a long time at Vanka
# who returned her look with cold persistence the way of a man who is
# afraid who does not approve and yet who likes
#
# She would stand with her back to the fireplace her high heels a little
# apart tapping the stretched silk of her skirt saying
#
# “You will ruin your eyes” adding “Vanka won’t you stop him”
#
# She seldom got answers to her remarks LouisGeorges would continue
# grunting at her to be sure and smiling but never lifting his eyes
# and as for Vanka he would stand there catching the sheets of paper as
# they were finished
#
# Finally LouisGeorges would push back his chair saying “Come we will
# have tea”
#
# In the end he fell into a slow illness It attacked his limbs he was
# forced to walk with a cane He complained of his heart but he persisted
# in going out to look at the horses to the barn to amuse Vera Sovna
# swaying a little as he watched the slowcircling flies sniffing the
# pleasant odours of cow’s milk and dung
#
# He still had plans for the haying season for his crops but he gave
# them over to his farm hands who left to themselves wandered aimlessly
# home at odd hours
#
# About six months later he took to his bed
#
# His aunts came testing with their withered noses the smell of decaying
# wood and paregoric whispering that “he never used to get like this”
#
# Raising their ample shoulders to ease the little black velvet straps
# that sunk into their flesh they sat on either side of his bed
#
# They looked at each other in a pitifully surprised way They had never
# seen illness and death but once—a suicide and this they understood
# one has impulses but not maladies
#
# They were afraid of meeting Vera Sovna Their position was a difficult
# one having been on friendly terms while LouisGeorges’ mother lived
# they had nevertheless to maintain a certain dignity and reserve when the
# very townsfolk had turned against her Therefore they left her an hour
# in the evening to herself She would come creeping in saying
#
# “Oh my dear” telling him long unheard stories about a week she had
# spent in London A curious week full of near adventure with amusing
# tales of hotel keepers nobility And sometimes leaning close to him
# that he might hear he saw that she was weeping
#
# But in spite of this and of his illness and the new quality in the air
# Vera Sovna was strangely gay
#
# During this illness the two girls served as nurses changing the sheets
# turning him over rubbing him with alcohol bringing him his soup
# crossing themselves
#
# Vanka stood long hours by the bedside coughing Sometimes he would fall
# off into sleep at others he would try to talk of the revolution
#
# Vera Sovna had taken to dining in the kitchen a long bare room that
# pleased her From the window one could see the orchards and the pump and
# the long slope down to the edge of the meadow And the room was pleasant
# to look upon The table like the earth itself was simple and abundant
# It might have been a meadow that Leah and Berthe browsed in
# redcheeked gaining health strength
#
# Great hams smoked fowl with oddly taut legs hung from the beams and
# under these the girls moved as if there were some bond between them
#
# They accepted Vera Sovna’s company cheerfully uncomplainingly and when
# she went away they cleared up her crumbs thinking and talking of other
# things forgetting
#
# Nothing suffered on account of his illness The household matters went
# smoothly the crops ripened the haying season passed and the sod in
# the orchards sounded with the thud of ripe falling fruit LouisGeorges
# suffered alone detached as if he had never been Even about Vera Sovna
# there was a strange quiet brilliancy the brilliancy of one who is about
# to receive something She caressed the medicine bottles tended the
# flowers
#
# Leah and Berthe were unperturbed except from overwork the face of
# Vanka alone changed
#
# He bore the expression at once of a man in pain and of a man who is
# about to come into peace The flickering light in LouisGeorges’ face
# cast its shadow on that of his valet
#
# Myra and Ella became gradually excited They kept brushing imaginary
# specks of dust from their shoulders and bodices sending each other in
# to observe him They comforted themselves looking at him pretending
# each to the other that he was quite improved It was not so much that
# they were sorry to have him die as it was that they were not prepared
# to have him die
#
# When the doctor arrived they shifted their burden of worry They bought
# medicine with great relish hurriedly Finally to lessen the torment
# they closed their eyes as they sat on either side of his bed picturing
# him already dead laid out hands crossed that they might gain comfort
# upon opening them to find him still alive
#
# When they knew that he was really dying they could not keep from
# touching him They tried to cover him up in those parts that exposed too
# plainly his illness the thin throat the damp pulsing spot in the neck
# They fondled his hands driving doctor and nurse into a passion
#
# At last in desperation Myra knelt by his bed touched his face
# stroked his cheeks trying to break the monotonous calm of approaching
# death
#
# Death did not seem to be anywhere in him saving in his face  it
# seemed to Myra that to drive it from his eyes would mean life It was
# then that she and her sister were locked out to wander up and down the
# hall afraid to speak afraid to weep unless by that much they might
# hasten his death
#
# When he finally died they had the problem of Vera Sovna
#
# But they soon forgot her trying to follow the orders left by the dead
# man LouisGeorges had been very careful to see to it that things should
# go on growing he had given many orders planned new seasons talked of
# “next year” knowing that he would not be there
#
# The hens cackled with splendid performances the stables resounded with
# the good spirits of the horses the fields were all but shedding their
# very life on the earth as Vanka moved noiselessly about folding the
# dead man’s clothes
#
# When the undertaker arrived Vanka would not let him touch the body He
# washed and dressed it to suit himself It was he who laid LouisGeorges
# in the shiny coffin it was he who arranged the flowers and he who
# finally left the room on the flat of his whole noisy feet for the first
# time in years He went to his own room overlooking the garden
#
# He paced the room It seemed to him that he had left something undone
# He had loved service and order he did not know that he also loved
# LouisGeorges who made service necessary and order desirable
#
# This distressed him he rubbed his hands holding them close to his
# mouth as if by the sound of one hand passing over the other he might
# learn some secret in the stoppage of sound
#
# Leah had made a scene he thought of that A small enough scene
# considering She had brought her baby in dropping him beside the body
# giving the flatvoiced “Now you can play with him a minute”
#
# He had not interfered the child had been too frightened to disturb the
# cold excellence of LouisGeorges’ arrangement and Leah had gone out
# soon enough in stolid silence He could hear them descending the steps
# her heavy slow tread followed by the quick uneven movements of the
# child
#
# Vanka could hear the rustling of the trees in the garden the call of an
# owl from the barn one of the mares whinnied and stamping fell off
# into silence
#
# He opened the window He thought he caught the sound of feet on the
# pebbles that bordered the hydrangea bushes a faint perfume such as the
# flounces of Vera Sovna exhaled came to him Irritated he turned away
# when he heard her calling
#
# “Vanka come my foot is caught in the vine”
#
# Her face with wide hanging lips came above the sill and the same
# moment she jumped into the room
#
# They stood looking at each other They had never been alone together
# before He did not know what to do
#
# She was a little dishevelled twigs from the shrubbery clung to the
# black flounces of her gown She raised her thin shoulders once twice
# and sighed
#
# She reached out her arm whispering
#
# “Vanka”
#
# He moved away from her staring at her
#
# “Vanka” she repeated and came close leaning a little on him
#
# In a voice of command she said simply “You must tell me something”
#
# “I will tell you” he answered automatically
#
# “See look at your hands——” She kissed them suddenly dropping her wet
# lips into the middle of the palms making him start and shiver
#
# “Look at these eyes—ah fortunate man” she continued “most fortunate
# Vanka he would let you touch him close near the heart the skin You
# could know what he looked like how he stood how his ankle went into
# his foot” He ceased to hear her
#
# “And his shoulders how they set You dressed and undressed him knew
# him all of him for many years—you see you understand Tell me tell
# me what he was like”
#
# He turned to her “I will tell you” he said “if you are still if you
# will sit down if you are quiet”
#
# She sat down with another sigh with a touch of her old gaiety she
# raised her eyes watching him
#
# “His arms were too long you could tell that—but beautiful and his back
# was thin tapering—full of breeding——”
#
#
#
#
#
#
#
#         │
#           │
#       │
#      —│Her neighbour
#
#   —Late afternoon
#
#   —In the mountains of CornwallonHudson—the  house
#
#   —The inner room of the  cottage
#
# To the left in the back wall a large window overlooks a garden Right
# centre a door leads off into a bedroom and from the bedroom one may
# see the woods of the mountain The door is slightly open showing a
# glimpse of a tall mirror and the polished pole of a bed
#
# In the right wall there is a fireplace
#
# A dog lies across the threshold asleep head on paws
#
# About this room there is perhaps just a little too much of a certain
# kind of frail beauty of object Crystal glasses scent bottles bowls of
# an almost too perfect design furniture that is too antiquely
# beautiful
#
#   a woman of about thirtyfive stands almost back
# view to the audience one arm lying along the mantel She is rather
# under medium in height Her hair which is dark and curling is done
# carefully about a small fine head She is dressed in a dark long gown
# a gown almost too faithful to the singular sadness of her body
#
# At about the same moment as the curtain’s rising   vaults
# the windowsill He is a man of few years a welltodo man of property
# brought up very carefully by upright women the son of a conscientious
# physician the kind of man who commutes with an almost religious
# fervour and who keeps his wife and his lawns in the best possible trim
# without any particular personal pleasure
#
#  is tall but much too honourable to be jaunty he is decidedly
# masculine He walks deliberately getting all the use possible out of
# his bootleather his beltstrap and hatbands
#
# His face is one of those which for fear of misuse has not been used
# at all
#
#   does not appear to be in the least astonished at his
# mode of entrance
#
#
#  —As you never let me in at the door I thought of the window
#  remains silent I hope I did not startle you Pause
# Women are better calm that is some kinds of calm——
#
# —Yes
#
# —Noticing the dog which has not stirred You’ve got funny
# dogs they don’t even bark Pause I expected you’d set them on me
# however perhaps that will come later——
#
# —Perhaps
#
# —Are you always going to treat me like this For days I’ve watched
# you walking with your dogs of an evening—that little black bullpup and
# then those three setters—you’ve fine ways with you Helena Hucksteppe
# though there are many tales of how you came by them——
#
# —Yes
#
# —Yes Pause You know you surprise me
#
# —Why Because I do not set my dogs on you
#
# —Something like that
#
# —I respect my dogs
#
# —What does that mean
#
# —Had I a daughter would I set her on every man
#
# —Trying to laugh That’s meant for an insult isn’t it Well I
# like the little insulting women——
#
# —You are a man of taste
#
# —I respect you
#
# —What kind of a feeling is that
#
# —A gentleman’s——
#
# —I see
#
# —People say of you “She has a great many ways——”
#
# —Yes
#
# —Sitting on the edge of the table “But none of them simple”
#
# —Do they
#
# —Without attempting to hide his admiration I’ve watched your
# back “There goes a fine woman a fine silent woman she wears long
# skirts but she knows how to move her feet without kicking up a dust—a
# ...
# seemed for which people framed him in white enamel and hung him upon
# their bedroom walls but chiefly he had been renowned for his killing
# Rugo thought about that awhile and came to the illuminating conclusion
# that all heroes were men who killed or were killed
#
# Well the last was impossible if he was killed he might just as well
# have starved in the country and not have laid eyes on Addie Therefore
# he must kill—but what—but whom
#
# Of course he might save something or somebody but they would have to
# be in danger first and there might not be any danger for days and days
# and he was tired of waiting
#
# Presently he laid his work aside lowered the shade and lying face
# down on his bed he tried to think it all out clearly
#
# Presently he got a vivid picture of killing in his mind He sat up and
# put his hands two or three times over his face It was damp He sat on
# the edge of the bed and looked at the carpet His mind wandered He
# thought of the ducks he had longed to stroke of the gentle feeding
# cows of the fresh clean air—then he thought again of Addie and of what
# he must do He tried to picture himself killing someone He put his two
# hands together and looked at them—there that was the way Then he
# smiled His hands set as they were could not have choked anything
# larger than a thrush He widened them but he separated them instantly
# and rubbed them down his legs breathing heavily What a terrible
# business a hero’s was He thought of the throbbing that must stop
# beneath such hands as his He got up shaking his shoulders from side to
# side as if his back hurt him He pulled up the shade
#
# The butcher’s windows opposite attracted his attention Two gas lights
# were burning there vividly Rugo could see flanks of beef laid out in
# pans little ruddy pools collecting about them like insertion Fowl hung
# by the necks and several hams lured the passerby as they swung softly
# this way and that
#
# He opened his door hesitatingly and shutting it carefully stepped out
# into the roadway
#
# He crossed over and leaned his head against the glass He looked in very
# close now and he could see the film that shrouded the dead eyes of the
# fowl and the hares Slabs of liver laid out in heaps flanked by cuts of
# tripe drew his attention
#
# A strange sensation had hold of him in the pit of his stomach It seemed
# to him that he was turning pale He raised his hand to his beard and
# tugged at it
#
# Two or three red hairs separated and came out He held them up between
# him and the light Then he darted in the back door of the shop
#
# Presently he emerged carrying a box With the furtive and hurried step
# of a man who is being observed he crossed the street He opened the door
# of his own little shop and locking it quickly he put the box in the
# corner and turned down the light
#
# It was very dark and he stumbled A little reflection came from the meat
# shop window and touched the rims of his cardboards and his pattern book
# full of the funny strutting gentlemen His heart was beating horribly
# against his side He began to question himself and stopped He could
# never do it unless he made his mind a resolute thing He clenched his
# teeth blinking his eyes as he did so He began to shiver
#
# Presently he threw himself on the ground in the corner near the box his
# arms over his head his face flat upon the dust and grime of the boards
# He must do it quickly—but he couldn’t do it
#
# His mind began to wander again He thought of the road red and yellow
# with the dying leaves of Autumn of the great swaying shadows and the
# sunlight breaking in between in little jagged spots like flowers He
# remembered the mosquitoes and he got to his knees and let his hands
# hang down at his sides
#
# The Summer had always been so pretty the rains left the fields so
# bright and sudden when they came into view over the top of the hill The
# ploughing had been good he had really enjoyed that after all only then
# he had not known just how much he did enjoy it What a pity that he had
# not known what a good thing it all was then
#
# Something moved beside him breathing softly He uttered a sharp cry and
# the same thing moved back hitting a board and was again silent
#
# He bent forward thrust his two hands out closed them—tighter tighter
# and tighter A faint cry a little jerking to and fro—that was all
#
# He stood up and turned the light on He looked at his hands Then
# backing away from the corner never letting his eyes rest there he
# plunged his hands up to the elbows in a pail of water He threw a cupful
# of it inside his shirt at the neck He opened the door Addie was there
#
# She came in softly gently insinuatingly She could see by his face
# that something very horrible and necessary had been done She saw by his
# face how it had hurt by his hands what it must have cost him
#
# She came close to him “What have you done Rugo” she said
#
# “I—I have killed” he said almost in a whisper
#
# “What—where” She moved toward the centre of the room and then looked
# into the corner
#
# “That” she began to laugh
#
# “Take it or leave it” he said suddenly in a loud and penetrating voice
#
# She stooped and lifted it up—a small grey rabbit
#
# She laid it down again She placed her arm about him
#
# “Come quickly” she said “Comb your hair”
#
# She pushed him into the street She was afraid of him for there was
# something strange and hard in his mouth and he walked putting each foot
# down very flat and steady
#
# “Where are you going What are you going to do” He did not seem to know
# that she was there clinging to him her arm about his waist He had
# forgotten her He looked up into the air sniffing it and smiling
#
# “Come” she said “we are going to have your boots shined”
#
#
#
#
#
#
#
#              So still she lies in this closed place apart
#              Her feet grown fragile for the ghostly tryst
#              Her pulse no longer striking in her wrist
#              Nor does its echo wander through her heart
#
#              Over the body and the quiet head
#              Like stately ferns above an austere tomb
#              Soft hairs blow and beneath her armpits bloom
#              The drowsy passion flowers of the dead
#
#
#
#
#                     A   A   A
#
#
# The days had been very warm and quick It was Fall now and everything
# was drawing to a close It had been a bad but somehow pleasant year A
# great number of people had been disillusioned and were not seen hurrying
# from one place to another as is customary with those of undisturbed
# habit They went slowly and it was said that Winter with its snow and
# frost would be most welcome
#
# Carmen la Tosca was in the habit of riding at a swift gallop down the
# lane and into the copse beyond She leaned ever so little in her saddle
# as she went under the boughs The plume of her hat bent and swung
# smartly back into place as she rounded the curve
#
# Her horse was a clear cascade of white The shining forelock the soft
# descending plane of the frontal bone melted into a taut nostril And
# where Carmen la Tosca broke the living line of its back with her own
# the spine flowed beneath her as deftly as water and quivered into
# massive alert haunches which in turn socketed in velvet a foaming
# length of tail
#
# Carmen la Tosca rode well She let more than usual of her pelvis drop
# into the saddle Upon the reins she kept gloved hands in a grip that was
# consciously lacking in direction
#
# Carmen la Tosca was an actress She had played in “Fife and Fiddle” and
# “Drums of the King”
#
# She took parts suggesting a love of danger and intrigue She was always
# handsomely gloved and shod and her dresses were widely copied
#
# She had been in stock and in the beginning had sung in opera she had
# been the Queen in “Aïda” and she had played a boy’s part in vaudeville
# Now she was resting
#
# She was not the kind of woman who usually came to this quiet country
# town snuggled as they say among the foothills The boy who kept the
# general store said she was “stunning” Little children ran backward
# ahead of her crying provokingly “Red lips red lips” But no one
# really knew her
#
# She had appeared in the Spring of the year with a manservant and a
# maid For two days she had been seen at the windows hanging curtains
# When they were all hung no one saw her for some time Then she bought a
# white horse and rode it And after that she always rode on the white
# horse though she had six or seven others before the Fall came Usually
# she rode alone Now and again a gentleman with a birthmark twisting
# his face into an unwilling irony rode beside her There was a goat path
# in the underbrush and here two boys sometimes came and lay and talked of
# her and waited for her to pass riding that smart way on the white mare
# These boys were Brandt and Bailey Wilson a farmer’s sons Sometimes
# couples going berrying by the mountain road came near enough to hear
# her laughing behind the casement
#
# Sometimes she walked descending the hill carefully avoiding the melon
# plants talking brightly to a young man but paying little attention to
# the effect of her words not through vanity but simply through lack of
# interest in the effect itself
#
# There was a great deal of gossip about her of course She did not court
# mystery but it was all about her
#
# People said that she was not exactly beautiful neither was she ugly
# Her face held the elements of both in perfect control She was brutally
# chic
#
# A lean tall woman of the village who had come from London said Carmen
# la Tosca’s back was like the Queen’s This was probably an exaggeration
#
# Carmen la Tosca breakfasted in bed and late She dusted her arms with
# talc and she languidly settled into a light lace peignoir She had tea
# and rolls and the bed stood between two unvarnished cherrywood ovals
# in which were imprisoned two engravings of officials of the Tower of
# London in its bloodiest hour
#
# The double windows faced the orchard She turned her back to the orchard
# and its falling apples and read St Francis or the morning paper which
# was by the time she received it a day or two old
#
# The room was bare and grey and rustic And in this Carmen la Tosca and
# her bed made a strange contrast She liked to think of it unless she had
# other things on her mind If the morning was chilly she had a quilted
# jacket and if it was raining she had the shades raised that she might
# watch the rain falling a long way
#
# Early in the morning the boy chose it had been raining but about eleven
# it had stopped and the sun was trying to come out Carmen la Tosca could
# smell how wet everything was
#
# The boy was Brandt Wilson fourteen he had done rather well at the high
# school of the nearest large town He was short and his head was large
# and his face already a little prematurely softened by melancholy He was
# splashed with mud and his red tie stuck out ridiculously at the top of a
# vest that was too large for his small shyly muscular chest
#
# He stood before her on the rug his hat in his hand
#
# Carmen la Tosca with a single movement rolled over in bed
#
# “Who are you Where did you come from”
#
# “I am Brandt Wilson I came through the window It was very easy”
#
# “Well” she said “What is it”
#
# The child hesitated and with a look of distress managed to say
#
# “I have a brother”
#
# Carmen la Tosca pushed away the paper and regarded him with amusement
# and a little amazement
#
# “He is two years older than I am—and there’s something I don’t
# understand—and you know everything”
#
# “Who said so”
#
# “The neighbours my father my mother my sister the schoolmaster the
# postman——”
#
# “That will do”
#
# “You are a woman of the world” The childish sound of his voice became
# terribly apparent
#
# “My brother is where no one understands—My sister said ‘I don’t like
# Bailey any more he has lost that cunning little light in his eyes’—and
# I said ‘It’s still there when you give him something he likes and he
# is untying it with his head bent down——’”
#
# “How do you come to think of all this”
#
# “Once the sun was shining and we had been lying out on the bank with our
# arms under our heads and then he said—he confessed”—the child faltered
# then looking at her directly and fixedly said “Bailey cried when he
# knew it was over——”
#
# “What was over”
#
# “I asked him and he answered ‘I am a man now’ Shall I cry too when
# I know that What is it all about”
#
# Carmen la Tosca rose on her elbow and looked at him with suffused eyes
# as if she had been crying but it was all an illusion
#
# “How many of you are there”
#
# “Three A married brother”
#
# “And how old is he”
#
# “Twentyfour He cried once too but differently about his sweetheart
# She died you know and when they told him he said crying out ‘I could
# have saved her’ We asked him how but he would not tell us but he told
# mother he said ‘I would have said I love you’ Is there such a power”
#
# Carmen la Tosca lay on her back her hands beside her
#
# “That was innocence We are all waiting for the day when people shall
# learn of our innocence all over again” she said brightly
#
# “And is that suffering”
#
# “Yes a special kind for everyone” she said gravely “But not a
# personal torment You are not to believe in that Suffering is all
# alike yours mine everybody’s All these distinctions and what people
# say about them is nonsense Suffering is all the same everywhere for
# everyone” She suddenly rose up in bed and said softly “Now you do not
# want to talk to me any more”
#
# He moved his fingers on the footboard of the bed
#
# “I’m sorry” she said hastily covered with confusion “It’s my
# indolence that does it”
#
# “What” he asked timidly
#
# “Embarrasses you”
#
# “It’s all right”
#
# “Now see here” she continued “Do you ever think of animals”
#
# “Why”
#
# “Do you”
#
# “I don’t know I notice them——”
#
# “Capital” she cried clapping her hands “that’s what I wanted to know
# Well then what would all this you and I and your great trouble mean
# to them”
#
# “I don’t know what you mean”
#
# “Your questions my answers Nothing”
#
# He coloured and looked down “What does it mean” he repeated and as
# he said it he could not remember what he had come for or what he had
# said and while she was answering he tried desperately to reestablish
# himself
#
# He said “And you do not know what I must go through before I feel like
# Bailey”
#
# “A little evil day by day that makes everything grow”
#
# “Yes that is what I wanted to know” he said breathlessly
#
# “Listen then it’s all that makes the difference between a gentleman and
# a fool Never do evil to good people they always forgive it and that
# is nasty”
#
# “But what about all these things that people talk of and I do not
# understand”
#
# “The simple story simply told by simple people—that in the end is all
# you will listen to”
#
# “And I’m not to try to make anything out of all this”
#
# “No” she said “nothing at all leave it alone”
#
# “And not to try to understand what made him cry”
#
# “Just as it is The calf is born she lies in the sun she waits for the
# end That is dignity”
#
# “But sometimes I’m unhappy”
#
# “In the end you will know you know nothing That will be the death of
# you”
#
# Brandt stood still though she had taken up her paper
#
# “Just that”
#
# “Come here” she said and he came quickly She put her hand out with a
# gentle laugh and touched him “There that’s all”
#
# He went away then
#
#
#
#
#
#
#
#                  The mortal fruit upon the bough
#                  Hangs above the nuptial bed
#                  The catbird in the tree returns
#                  The forfeit of his mutual vow
#
#                  The hard untimely apple of
#                  The branch that feeds on watered rain
#                  Takes the place upon her lips
#                  Of her late lamented love
#
#                  Many hands together press
#                  Shaped within a static prayer
#                  Recall to one the chorister
#                  Docile in his sexless dress
#
#                  The temperate winds reclaim the iced
#                  Remorseless vapours of the snow
#                  The only pattern in the mind
#                  Is the cross behind the Christ
#
#
#
#
#
#
#
#             For you for me Why then the striking hour
#             The wind among the curtains and the tread
#             Of some late gardener pulling at the flower
#             They’ll lay between our hearts when we are dead

# %%
# Converting text to lowercase
S = S.lower()
print(S[:1000])
# Out:
# ﻿the
#
#
#
#
#                   a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                    ’s
#
#
#
#                   ’
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                   i’d

# %%
# splitting the lines and joining them into one.
S = " ".join(S.split())
wordcloudS=S
S2=S
print(T[:1000])
# Out:
# ['\ufeff', 'a', '“', '”', '“', '’', 's', '”', 'a', '’', 's', 'a', 'a', 'a', '’', 's', '’', 's', '’', 's', 'a', '“', '—', '—', '”', 'on', 'board', 'the', 'rampatina', 'liner', 'eleven', 'days', 'and', 'a', 'half', 'out', 'from', 'liverpool', 'the', 'usual', 'terrific', 'sensation', 'created', 'by', 'the', 'appearance', 'of', 'the', 'pilotyacht', 'prevailed', 'necks', 'were', 'craned', 'and', 'toes', 'were', 'trodden', 'on', 'as', 'the', 'steamer', 'slackened', 'speed', 'and', 'a', 'line', 'dexterously', 'thrown', 'by', 'a', 'bluejerseyed', 'deckhand', 'was', 'caught', 'by', 'somebody', 'aboard', 'the', 'yacht', 'the', 'pilot', 'not', 'insensible', 'to', 'the', 'fact', 'of', 'his', 'being', 'a', 'personage', 'of', 'note', 'carefully', 'divested', 'his', 'bearded', 'countenance', 'of', 'all', 'expression', 'as', 'he', 'saluted', 'the', 'captain', 'and', 'taking', 'from', 'the', 'decksteward', '’', 's', 'obsequiously', 'proffered', 'salver', 'a', 'glass', 'containing', 'fourfingers', 'of', 'neat', 'bourbon', 'whisky', 'concealed', 'its', 'contents', 'about', 'his', 'person', 'without', 'perceptible', 'emotion', 'and', 'went', 'up', 'with', 'the', 'first', 'officer', 'upon', 'the', 'upper', 'bridge', 'as', 'the', 'relieved', 'skipper', 'plunged', 'below', 'the', 'telegraphs', 'clicked', 'their', 'message—the', 'leviathan', 'hulk', 'of', 'the', 'liner', 'quivered', 'and', 'began', 'to', 'forge', 'slowly', 'ahead', 'and', 'an', 'intelligentlooking', 'thinlipped', 'badlyshaved', 'young', 'man', 'in', 'a', 'bowler', 'tweeds', 'and', 'striped', 'necktie', 'introduced', 'himself', 'to', 'the', 'second', 'officer', 'as', 'an', 'emissary', 'of', 'the', 'press', '“', 'mr', 'cyrus', 'k', 'pillson', 'new', 'york', 'yeller', 'pleased', 'to', 'know', 'you', 'sir', '”', 'said', 'the', 'second', 'officer', '“', 'step', 'into', 'the', 'smokeroom', 'this', 'way', 'barsteward', 'a', 'brandy', 'cocktail', 'for', 'me', 'and', 'you', 'sir', 'order', 'whatever', 'you', 'are', 'most', 'in', 'the', 'habit', 'of', 'hoisting', 'whisky', 'straight', 'now', 'sir', 'happy', 'to', 'afford', 'you', 'what', 'information', 'i', 'can', '”', '“', 'i', 'presume', '”', 'observed', 'the', 'young', 'gentleman', 'of', 'the', 'press', 'settling', 'himself', 'on', 'the', 'springy', 'morocco', 'cushions', 'and', 'accepting', 'the', 'second', 'officer', '’', 's', 'polite', 'offer', 'of', 'a', 'green', 'havana', 'of', 'the', 'strongest', 'kind', '“', 'that', 'you', 'have', 'had', 'a', 'smooth', 'passage', 'considerin', '’', 'the', 'time', 'of', 'year', '”', '“', 'smooth', '”', 'the', 'second', 'officer', 'carefully', 'reversed', 'in', 'his', 'reply', 'the', 'pressman', '’', 's', 'remark', '“', 'well', 'yes', 'the', 'time', 'of', 'year', 'considered', 'a', 'smooth', 'passage', 'i', 'take', 'it', 'we', 'have', 'had', '”', '“', 'no', 'fogs', '”', 'interrogated', 'the', 'young', 'gentleman', 'clicking', 'the', 'elastic', 'band', 'of', 'a', 'notebook', 'which', 'projected', 'from', 'his', 'breastpocket', '“', 'fogs', 'no', '”', 'said', 'the', 'second', 'officer', '“', 'you', 'didn', '’', 't', 'chance', '”', 'pursued', 'the', 'young', 'gentleman', 'of', 'the', 'press', 'taking', 'his', 'short', 'drink', 'from', 'the', 'steward', '’', 's', 'salver', 'and', 'throwing', 'it', 'contemptuously', 'down', 'his', 'throat', '“', 'to', 'fall', 'in', 'with', 'a', 'berg', 'off', 'the', 'bank', 'did', 'you', '”', '“', 'not', 'a', 'smell', 'of', 'one', '”', 'replied', 'the', 'second', 'officer', 'with', 'decision', '“', 'ran', 'into', 'a', 'derelict', 'hencoop', 'perhaps', '”', 'persisted', 'the', 'young', 'gentleman', 'concealing', 'the', 'worn', 'sole', 'of', 'a', 'wearied', 'boot', 'from', 'the', 'searching', 'glare', 'of', 'the', 'electric', 'light', 'by', 'tucking', 'it', 'underneath', 'him', '“', 'or', 'an', 'old', 'lady', '’', 's', 'bonnetbox', 'or', 'a', 'rubber', 'doll', 'some', 'woman', '’', 's', 'baby', 'had', 'lost', 'overboard', 'no', '”', 'he', 'echoed', 'as', 'the', 'second', 'off ...

# %%
# Tokenisation
from nltk.tokenize import word_tokenize

S = word_tokenize(S)
print(S[:1000])
# Out:
# ['\ufeffthe', 'a', '’', 's', '’', 'i', '’', 'd', 'a', 'a', 'a', 'study', 'frontispiece', 'facing', 'page', 'portrait', 'portrait', 'drawing', 'portrait', 'study', 'portrait', 'a', 'a', 'toward', 'dusk', 'in', 'the', 'summer', 'of', 'the', 'year', 'a', 'man', 'dressed', 'in', 'a', 'frock', 'coat', 'and', 'top', 'hat', 'and', 'carrying', 'a', 'cane', 'crept', 'through', 'the', 'underbrush', 'bordering', 'the', 'corral', 'of', 'the', 'buckler', 'farm', 'as', 'he', 'moved', 'small', 'twigs', 'snapped', 'fell', 'and', 'were', 'silent', 'his', 'knees', 'were', 'green', 'from', 'wounded', 'shrubbery', 'and', 'grass', 'and', 'his', 'outspread', 'hands', 'tore', 'unheeded', 'plants', 'his', 'wrists', 'hurt', 'him', 'and', 'he', 'rested', 'from', 'time', 'to', 'time', 'always', 'caring', 'for', 'his', 'hat', 'and', 'knotted', 'yellow', 'cane', 'blowing', 'through', 'his', 'moustache', 'dew', 'had', 'been', 'falling', 'covering', 'the', 'twilight', 'leaves', 'like', 'myriad', 'faces', 'damp', 'with', 'the', 'perspiration', 'of', 'the', 'struggle', 'for', 'existence', 'and', 'half', 'a', 'mile', 'away', 'standing', 'out', 'against', 'the', 'darkness', 'of', 'the', 'night', 'a', 'grove', 'of', 'white', 'birches', 'shimmered', 'like', 'teeth', 'in', 'a', 'skull', 'he', 'heard', 'the', 'creaking', 'of', 'a', 'gate', 'and', 'the', 'splashing', 'of', 'late', 'rain', 'into', 'the', 'depths', 'of', 'a', 'dark', 'cistern', 'his', 'heart', 'ached', 'with', 'the', 'nearness', 'of', 'the', 'earth', 'the', 'faint', 'murmur', 'of', 'it', 'moving', 'upon', 'itself', 'like', 'a', 'sleeper', 'who', 'turns', 'to', 'throw', 'an', 'arm', 'about', 'a', 'beloved', 'a', 'frog', 'began', 'moaning', 'among', 'the', 'skunk', 'cabbages', 'and', 'john', 'thrust', 'his', 'hand', 'deep', 'into', 'his', 'bosom', 'something', 'somnolent', 'seemed', 'to', 'be', 'here', 'and', 'he', 'wondered', 'it', 'was', 'like', 'a', 'deep', 'heavy', 'yet', 'soft', 'prison', 'where', 'without', 'sin', 'one', 'may', 'suffer', 'intolerable', 'punishment', 'presently', 'he', 'went', 'on', 'feeling', 'his', 'way', 'he', 'reached', 'a', 'high', 'plank', 'fence', 'and', 'sensing', 'it', 'with', 'his', 'fingers', 'he', 'lay', 'down', 'resting', 'his', 'head', 'against', 'the', 'ground', 'he', 'was', 'tired', 'he', 'wanted', 'to', 'sleep', 'but', 'he', 'searched', 'for', 'his', 'hat', 'and', 'cane', 'and', 'straightened', 'out', 'his', 'coat', 'beneath', 'him', 'before', 'he', 'turned', 'his', 'eyes', 'to', 'the', 'stars', 'and', 'now', 'he', 'could', 'not', 'sleep', 'and', 'wondered', 'why', 'he', 'had', 'thought', 'of', 'it', 'something', 'quick', 'was', 'moving', 'the', 'earth', 'it', 'seemed', 'to', 'live', 'to', 'shake', 'with', 'sudden', 'immensity', 'he', 'heard', 'a', 'dog', 'barking', 'and', 'the', 'dim', 'light', 'from', 'a', 'farm', 'window', 'kept', 'winking', 'as', 'the', 'trees', 'swung', 'against', 'its', 'square', 'of', 'light', 'the', 'odor', 'of', 'daisies', 'came', 'to', 'him', 'and', 'the', 'assuring', 'powerful', 'smell', 'of', 'the', 'stables', 'he', 'opened', 'his', 'mouth', 'and', 'drew', 'in', 'his', 'moustache', 'a', 'faint', 'tumult', 'had', 'begun', 'a', 'tremor', 'ran', 'under', 'the', 'length', 'of', 'his', 'body', 'and', 'trembled', 'off', 'into', 'the', 'earth', 'like', 'a', 'shudder', 'of', 'joy—died', 'down', 'and', 'repeated', 'itself', 'and', 'presently', 'he', 'began', 'to', 'tremble', 'answering', 'throwing', 'out', 'his', 'hands', 'curling', 'them', 'up', 'weakly', 'as', 'if', 'the', 'earth', 'were', 'withholding', 'something', 'precious', 'necessary', 'his', 'hat', 'fell', 'off', 'striking', 'a', 'log', 'with', 'a', 'dull', 'hollow', 'sound', 'and', 'he', 'pressed', 'his', 'red', 'moustache', 'against', 'the', 'grass', 'weeping', 'again', 'he', 'heard', 'it', 'felt', 'it', 'a', 'hundred', 'hoofs', 'beat', 'upon', 'the', 'earth', 'and', 'he', 'knew', 'the', 'horses', 'had', 'gone', 'wild', 'in', 'the', 'corral', 'on', 'the', 'other', 'side', 'of', 'the', ...

# %%
# Lemmatisation
lemmatizer2 = WordNetLemmatizer()

# forming a set of stopwords from english language
stop_words2 = set(stopwords.words('english'))

# creating an empty list
lemmatized_S=[]

# traversing all the words
for word in S:
    # if the word has a length greater than or equal to 2 and is not a stopword
    if len(word) >= 2 and word not in stop_words2:
        # then we append the word into the list lemmatized_T after performing lemmatization 
        # using the lemmatize() function
        lemmatized_S.append(lemmatizer2.lemmatize(word))
        
# printing the list of lemmatized words
print(lemmatized_S[:1000])
# Out:
# ['\ufeffthe', 'study', 'frontispiece', 'facing', 'page', 'portrait', 'portrait', 'drawing', 'portrait', 'study', 'portrait', 'toward', 'dusk', 'summer', 'year', 'man', 'dressed', 'frock', 'coat', 'top', 'hat', 'carrying', 'cane', 'crept', 'underbrush', 'bordering', 'corral', 'buckler', 'farm', 'moved', 'small', 'twig', 'snapped', 'fell', 'silent', 'knee', 'green', 'wounded', 'shrubbery', 'grass', 'outspread', 'hand', 'tore', 'unheeded', 'plant', 'wrist', 'hurt', 'rested', 'time', 'time', 'always', 'caring', 'hat', 'knotted', 'yellow', 'cane', 'blowing', 'moustache', 'dew', 'falling', 'covering', 'twilight', 'leaf', 'like', 'myriad', 'face', 'damp', 'perspiration', 'struggle', 'existence', 'half', 'mile', 'away', 'standing', 'darkness', 'night', 'grove', 'white', 'birch', 'shimmered', 'like', 'teeth', 'skull', 'heard', 'creaking', 'gate', 'splashing', 'late', 'rain', 'depth', 'dark', 'cistern', 'heart', 'ached', 'nearness', 'earth', 'faint', 'murmur', 'moving', 'upon', 'like', 'sleeper', 'turn', 'throw', 'arm', 'beloved', 'frog', 'began', 'moaning', 'among', 'skunk', 'cabbage', 'john', 'thrust', 'hand', 'deep', 'bosom', 'something', 'somnolent', 'seemed', 'wondered', 'like', 'deep', 'heavy', 'yet', 'soft', 'prison', 'without', 'sin', 'one', 'may', 'suffer', 'intolerable', 'punishment', 'presently', 'went', 'feeling', 'way', 'reached', 'high', 'plank', 'fence', 'sensing', 'finger', 'lay', 'resting', 'head', 'ground', 'tired', 'wanted', 'sleep', 'searched', 'hat', 'cane', 'straightened', 'coat', 'beneath', 'turned', 'eye', 'star', 'could', 'sleep', 'wondered', 'thought', 'something', 'quick', 'moving', 'earth', 'seemed', 'live', 'shake', 'sudden', 'immensity', 'heard', 'dog', 'barking', 'dim', 'light', 'farm', 'window', 'kept', 'winking', 'tree', 'swung', 'square', 'light', 'odor', 'daisy', 'came', 'assuring', 'powerful', 'smell', 'stable', 'opened', 'mouth', 'drew', 'moustache', 'faint', 'tumult', 'begun', 'tremor', 'ran', 'length', 'body', 'trembled', 'earth', 'like', 'shudder', 'joy—died', 'repeated', 'presently', 'began', 'tremble', 'answering', 'throwing', 'hand', 'curling', 'weakly', 'earth', 'withholding', 'something', 'precious', 'necessary', 'hat', 'fell', 'striking', 'log', 'dull', 'hollow', 'sound', 'pressed', 'red', 'moustache', 'grass', 'weeping', 'heard', 'felt', 'hundred', 'hoof', 'beat', 'upon', 'earth', 'knew', 'horse', 'gone', 'wild', 'corral', 'side', 'fence', 'animal', 'greet', 'summer', 'striking', 'earth', 'friend', 'strike', 'back', 'friend', 'knew', 'understood', 'hail', 'summer', 'life', 'death', 'drew', 'bar', 'pressing', 'eye', 'peering', 'waiting', 'heard', 'coming', 'across', 'heavy', 'turf', 'rounding', 'curve', 'willow', 'road', 'opened', 'eye', 'closed', 'soft', 'menacing', 'sound', 'deepened', 'heat', 'deepens', 'strike', 'skin', 'flesh', 'head', 'long', 'leg', 'rising', 'falling', 'rising', 'striking', 'ground', 'insanely', 'like', 'needle', 'taking', 'terrible', 'impossible', 'purposeless', 'stitch', 'saw', 'belly', 'fawncoloured', 'pitching', 'side', 'side', 'flashing', 'straining', 'fence', 'rose', 'foot', 'silently', 'swiftly', 'fled', 'beside', 'something', 'delirious', 'hysterical', 'came', 'fell', 'blood', 'trickled', 'eye', 'forehead', 'fine', 'feeling', 'moment', 'like', 'mane', 'like', 'roan', 'mare', 'mane', 'passed', 'him—red', 'long', 'splendid', 'lifted', 'hand', 'closed', 'eye', 'soft', 'pounding', 'cease', 'though', 'sitting', 'position', 'jogged', 'imperceptibly', 'child', 'knee', 'seemed', 'smothering', 'felt', 'along', 'side', 'face', 'done', 'youth', 'put', 'cap', 'large', 'twining', 'green', 'thing', 'moist', 'earthblood', 'crept', 'finger', 'hot', 'impatient', 'leaf', 'pressed', 'green', 'matted', 'grass', 'deathly', 'thick', 'heard', 'freeness', 'nature', 'thought', 'trailing', 'ground', 'pine', 'torn', 'small', 'blade', 'journey', 'across', 'hill', 'vine', 'wristthick', 'twisted', 'pale', 'oak', 'hideously', 'gloriously', 'killing', 'dragging', 'dust', 'wax', 'patrick', 'p ...

# %%
from nltk.corpus import wordnet as wn
nouns2 = []
verbs2 = []
for word in lemmatized_S:
    for synset in wn.synsets(word):
        if "noun" in synset.lexname() and word not in nouns2:
            nouns2.append(word)
            
        elif "verb" in synset.lexname() and word not in verbs2:
            verbs2.append(word)

# %%
print(nouns2)
# Out:
# ['study', 'frontispiece', 'facing', 'page', 'portrait', 'drawing', 'dusk', 'summer', 'year', 'man', 'frock', 'coat', 'top', 'hat', 'cane', 'underbrush', 'corral', 'buckler', 'farm', 'small', 'twig', 'fell', 'knee', 'green', 'wounded', 'shrubbery', 'grass', 'hand', 'tore', 'plant', 'wrist', 'hurt', 'time', 'caring', 'yellow', 'blowing', 'moustache', 'dew', 'covering', 'twilight', 'leaf', 'like', 'myriad', 'face', 'damp', 'perspiration', 'struggle', 'existence', 'half', 'mile', 'standing', 'darkness', 'night', 'grove', 'white', 'birch', 'teeth', 'skull', 'creaking', 'gate', 'splashing', 'rain', 'depth', 'dark', 'cistern', 'heart', 'nearness', 'earth', 'faint', 'murmur', 'sleeper', 'turn', 'throw', 'arm', 'beloved', 'frog', 'skunk', 'cabbage', 'john', 'thrust', 'deep', 'bosom', 'heavy', 'prison', 'sin', 'one', 'may', 'punishment', 'feeling', 'way', 'high', 'plank', 'fence', 'sensing', 'finger', 'lay', 'head', 'ground', 'sleep', 'eye', 'star', 'thought', 'quick', 'shake', 'immensity', 'dog', 'light', 'window', 'winking', 'tree', 'square', 'odor', 'daisy', 'smell', 'stable', 'mouth', 'drew', 'tumult', 'tremor', 'length', 'body', 'shudder', 'tremble', 'curling', 'withholding', 'necessary', 'striking', 'log', 'hollow', 'sound', 'red', 'weeping', 'felt', 'hundred', 'hoof', 'beat', 'horse', 'wild', 'side', 'animal', 'friend', 'strike', 'back', 'hail', 'life', 'death', 'bar', 'pressing', 'waiting', 'coming', 'turf', 'rounding', 'curve', 'willow', 'road', 'heat', 'skin', 'flesh', 'leg', 'rising', 'needle', 'taking', 'impossible', 'stitch', 'saw', 'belly', 'pitching', 'flashing', 'straining', 'rose', 'foot', 'blood', 'forehead', 'fine', 'moment', 'mane', 'roan', 'mare', 'pounding', 'cease', 'sitting', 'position', 'child', 'youth', 'put', 'cap', 'large', 'thing', 'thick', 'nature', 'trailing', 'pine', 'blade', 'journey', 'hill', 'vine', 'pale', 'oak', 'killing', 'dust', 'wax', 'patrick', 'pipe', 'neck', 'black', 'running', 'tongue', 'lip', 'move', 'crackling', 'last', 'autumn', 'dead', 'infinite', 'patient', 'noise', 'acorn', 'powder', 'frail', 'pod', 'see', 'fall', 'sat', 'thunder', 'far', 'quickening', 'scene', 'house', 'quivering', 'spear', 'pulling', 'talking', 'cunning', 'pink', 'chin', 'daughter', 'mother', 'admirer', 'woman', 'lap', 'persian', 'kitten', 'trifle', 'fruit', 'bounty', 'avarice', 'desire', 'thinking', 'floating', 'veil', 'nothing', 'boy', 'nostril', 'pain', 'generation', 'might', 'quiver', 'whiff', 'get', 'looking', 'bitterness', 'walking', 'thrusting', 'better', 'showing', 'sharp', 'comber', 'smelling', 'saddle', 'nose', 'touching', 'yes', 'show', 'clothes', 'feel', 'nice', 'heel', 'make', 'people', 'lackey', 'know', 'getting', 'remonstrance', 'married', 'game', 'win', 'ill', 'breeding', 'gutter', 'reason', 'kind', 'person', 'tell', 'truth', 'costume', 'groom', 'timid', 'go', 'mirror', 'challenge', 'look', 'absurd', 'shame', 'gentleman', 'city', 'street', 'common', 'end', 'rise', 'general', 'lieutenant', 'physique', 'shaking', 'smiling', 'well', 'soldier', 'voice', 'sort', 'irony', 'patience', 'crime', 'natural', 'instinct', 'men', 'final', 'lower', 'order', 'making', 'idiot', 'ear', 'degenerate', 'creep', 'peer', 'daring', 'smear', 'glove', 'harness', 'grease', 'behind', 'pretending', 'enough', 'revolt', 'torment', 'vas', 'book', 'picture', 'fool', 'doubt', 'mean', 'object', 'sphere', 'best', 'collection', 'miniature', 'say', 'low', 'ottoman', 'bringing', 'palm', 'great', 'answer', 'letting', 'mind', 'love', 'much', 'question', 'passion', 'ladder', 'rung', 'experiment', 'given', 'food', 'taste', 'curiosity', 'escape', 'whim', 'place', 'lying', 'evening', 'first', 'hair', 'nape', 'lawn', 'collar', 'little', 'pretend', 'run', 'catch', 'calm', 'creeping', 'stroking', 'walk', 'step', 'crawl', 'carpet', 'honesty', 'situation', 'give', 'miss', 'want', 'interest', 'someone', 'lead', 'even', 'world', 'climbing', 'read', 'regret', 'blunder', 'party', 'guest', 'lot', 'drunk', 'drink', 'tall', 'shoulder', 'strap', 'dance', 'sung ...

# %%
print(verbs2)
# Out:
# ['study', 'facing', 'page', 'drawing', 'dusk', 'summer', 'man', 'dressed', 'frock', 'coat', 'top', 'hat', 'carrying', 'cane', 'crept', 'bordering', 'corral', 'farm', 'moved', 'twig', 'snapped', 'fell', 'green', 'wounded', 'grass', 'hand', 'tore', 'plant', 'hurt', 'rested', 'time', 'caring', 'knotted', 'yellow', 'blowing', 'falling', 'covering', 'leaf', 'like', 'face', 'damp', 'struggle', 'standing', 'white', 'birch', 'shimmered', 'heard', 'creaking', 'gate', 'splashing', 'rain', 'ached', 'earth', 'faint', 'murmur', 'moving', 'turn', 'throw', 'arm', 'frog', 'began', 'moaning', 'skunk', 'cabbage', 'thrust', 'bosom', 'seemed', 'wondered', 'sin', 'suffer', 'went', 'feeling', 'reached', 'plank', 'fence', 'sensing', 'finger', 'lay', 'resting', 'head', 'ground', 'tired', 'wanted', 'sleep', 'searched', 'straightened', 'turned', 'eye', 'star', 'thought', 'live', 'shake', 'dog', 'barking', 'dim', 'light', 'kept', 'winking', 'tree', 'swung', 'square', 'came', 'assuring', 'smell', 'stable', 'opened', 'mouth', 'drew', 'begun', 'tremor', 'ran', 'body', 'trembled', 'shudder', 'repeated', 'tremble', 'answering', 'throwing', 'curling', 'withholding', 'striking', 'log', 'dull', 'hollow', 'sound', 'pressed', 'weeping', 'felt', 'hoof', 'beat', 'knew', 'horse', 'gone', 'side', 'greet', 'strike', 'back', 'understood', 'hail', 'bar', 'pressing', 'peering', 'waiting', 'coming', 'turf', 'rounding', 'curve', 'closed', 'menacing', 'deepened', 'heat', 'deepens', 'skin', 'flesh', 'long', 'rising', 'needle', 'taking', 'stitch', 'saw', 'belly', 'pitching', 'flashing', 'straining', 'rose', 'foot', 'fled', 'blood', 'trickled', 'fine', 'passed', 'lifted', 'pounding', 'cease', 'sitting', 'position', 'jogged', 'smothering', 'done', 'put', 'cap', 'twining', 'matted', 'trailing', 'pine', 'torn', 'journey', 'hill', 'twisted', 'pale', 'killing', 'dragging', 'dust', 'wax', 'pipe', 'leaned', 'neck', 'staring', 'black', 'running', 'tongue', 'snapping', 'sighing', 'move', 'crackling', 'last', 'connected', 'noise', 'dropped', 'thin', 'powder', 'pod', 'took', 'tossing', 'liked', 'see', 'fall', 'sat', 'thunder', 'quickening', 'house', 'quivering', 'spear', 'walked', 'pulling', 'talking', 'pink', 'pointed', 'chin', 'mother', 'known', 'lap', 'held', 'kitten', 'trifle', 'fruit', 'desire', 'blew', 'thinking', 'floating', 'veil', 'called', 'intriguing', 'made', 'pain', 'quiver', 'caught', 'whiff', 'near', 'get', 'said', 'stroked', 'looking', 'walking', 'gentle', 'thrusting', 'answered', 'better', 'showing', 'smelling', 'saddle', 'shrivelled', 'nose', 'touching', 'show', 'clothes', 'feel', 'laughing', 'heel', 'make', 'people', 'amusing', 'returned', 'trying', 'know', 'pondering', 'getting', 'used', 'realizing', 'married', 'game', 'win', 'breeding', 'grown', 'gutter', 'fancied', 'reason', 'tell', 'troubled', 'played', 'debased', 'costume', 'groom', 'desired', 'go', 'mirror', 'challenge', 'look', 'shame', 'looked', 'hated', 'got', 'end', 'enter', 'rise', 'general', 'shaking', 'smiling', 'well', 'soldier', 'sensed', 'voice', 'sort', 'commit', 'troubling', 'thwarted', 'robbed', 'prove', 'lower', 'order', 'making', 'laughed', 'stuck', 'receded', 'degenerate', 'creep', 'peer', 'daring', 'weep', 'smear', 'harness', 'grease', 'pretending', 'revolt', 'torment', 'book', 'picture', 'fool', 'doubt', 'mean', 'object', 'best', 'say', 'low', 'bringing', 'palm', 'answer', 'letting', 'mind', 'love', 'question', 'placing', 'ladder', 'rung', 'experiment', 'given', 'taste', 'escape', 'satisfy', 'place', 'lying', 'cramped', 'slow', 'evening', 'met', 'collar', 'pretend', 'run', 'catch', 'intended', 'calm', 'creeping', 'stroking', 'walk', 'step', 'crawl', 'carpet', 'give', 'tried', 'miss', 'want', 'interest', 'ask', 'relented', 'discover', 'wished', 'meant', 'hoping', 'lead', 'even', 'grow', 'learn', 'climbing', 'changing', 'read', 'regret', 'quivered', 'defy', 'defied', 'blunder', 'party', 'lot', 'drunk', 'touched', 'drink', 'remembered', 'thrown', 'gowned', 'loose', 'shoulder', 'strap', 'dance', 'su ...

# %%
noun_dic2 = {}
dt = []
for noun in nouns2:
    d = []
    for synset in wn.synsets(noun):
        if "noun" in synset.lexname():
            if synset.lexname()[5:] not in d:
                d.append(synset.lexname()[5:])
                dt.append(synset.lexname()[5:])
                
    noun_dic2[noun] = d

# %%
for i in noun_dic2:
    print(i,":", noun_dic2[i])
# Out:
# study : ['act', 'cognition', 'communication', 'artifact', 'person']
# frontispiece : ['artifact']
# facing : ['artifact', 'act']
# page : ['communication', 'person']
# portrait : ['communication', 'artifact']
# drawing : ['communication', 'artifact', 'act']
# dusk : ['time']
# summer : ['time']
# year : ['time', 'group']
# man : ['person', 'animal', 'location', 'artifact']
# frock : ['artifact']
# coat : ['artifact', 'animal']
# top : ['location', 'time', 'state', 'attribute', 'artifact']
# hat : ['artifact', 'act']
# cane : ['artifact', 'plant']
# underbrush : ['group']
# corral : ['artifact']
# buckler : ['artifact']
# farm : ['artifact']
# small : ['body', 'attribute']
# twig : ['plant']
# fell : ['substance', 'artifact', 'act']
# knee : ['body', 'animal', 'artifact']
# green : ['attribute', 'location', 'person', 'object', 'food', 'artifact']
# wounded : ['group']
# shrubbery : ['location', 'group']
# grass : ['plant', 'person', 'food', 'artifact']
# hand : ['body', 'person', 'communication', 'cognition', 'location', 'group', 'artifact', 'quantity', 'animal', 'act']
# tore : ['artifact']
# plant : ['artifact', 'Tops', 'person', 'cognition']
# wrist : ['body']
# hurt : ['state', 'feeling', 'event', 'act']
# time : ['event', 'time', 'Tops', 'attribute']
# caring : ['feeling']
# yellow : ['attribute']
# blowing : ['process']
# moustache : ['body']
# dew : ['substance']
# covering : ['object', 'artifact', 'act']
# twilight : ['time', 'phenomenon', 'state']
# leaf : ['plant', 'communication', 'artifact']
# like : ['cognition']
# myriad : ['quantity']
# face : ['body', 'attribute', 'artifact', 'person', 'location', 'communication']
# damp : ['state']
# perspiration : ['body', 'process']
# struggle : ['act']
# existence : ['state', 'object']
# half : ['quantity', 'time']
# mile : ['quantity', 'event']
# standing : ['state', 'communication', 'act']
# darkness : ['state', 'location', 'cognition', 'attribute']
# night : ['time', 'state', 'person']
# grove : ['group', 'artifact']
# white : ['person', 'attribute', 'object', 'food', 'artifact']
# birch : ['plant', 'artifact']
# teeth : ['body', 'artifact', 'animal', 'act']
# skull : ['body']
# creaking : ['event']
# gate : ['artifact', 'possession']
# splashing : ['act']
# rain : ['phenomenon', 'substance', 'attribute']
# depth : ['attribute', 'location', 'state', 'cognition']
# dark : ['state', 'location', 'time', 'cognition']
# cistern : ['body', 'artifact']
# heart : ['cognition', 'body', 'attribute', 'location', 'shape', 'food', 'feeling', 'artifact']
# nearness : ['attribute']
# earth : ['object', 'substance', 'location', 'cognition', 'artifact']
# faint : ['event']
# murmur : ['event', 'communication', 'state']
# sleeper : ['person', 'artifact', 'animal', 'act']
# turn : ['shape', 'act', 'event', 'time', 'communication']
# throw : ['act', 'state', 'event', 'artifact']
# arm : ['body', 'artifact', 'group']
# beloved : ['person']
# frog : ['animal', 'person', 'artifact']
# skunk : ['person', 'event', 'artifact', 'animal']
# cabbage : ['food', 'possession', 'plant']
# john : ['artifact', 'person', 'communication']
# thrust : ['phenomenon', 'act', 'communication']
# deep : ['time', 'object']
# bosom : ['state', 'body', 'artifact', 'act', 'cognition']
# heavy : ['person', 'cognition']
# prison : ['artifact', 'state']
# sin : ['attribute', 'act', 'relation', 'person', 'communication']
# one : ['quantity', 'cognition']
# may : ['time', 'plant']
# punishment : ['act']
# feeling : ['Tops', 'cognition', 'state']
# way : ['attribute', 'act', 'location', 'state', 'artifact', 'quantity', 'cognition', 'possession']
# high : ['attribute', 'state', 'location', 'group', 'artifact']
# plank : ['substance', 'communication']
# fence : ['artifact', 'person']
# sensing : ['cognition', 'act']
# finger : ['body', 'quantity', 'artifact']
# lay : ['communication']
# head : ['body', 'animal', 'cognition', 'person', 'group', 'phenomenon', 'location', 'communication', 'state', 'quantity', 'plant', 'object', 'event', 'artifact', 'act']
# ground : ['object', 'motive', 'substance', 'relation', 'location', 'cognition', 'artifact']
# sleep : ['state', 'time']
# eye : ['body', 'cognition', 'location', 'artifact']
# star : ['object', 'person', 'shape', 'communication', 'cognition']
# thought : ['cognition']
# quick : ['body']
# shake : ['substance', 'food', 'communication', 'act']
# immensity : ['attribute']
# dog : ['animal', 'person', 'food', 'artifact']
# light : ['phenomenon', 'artifact', 'cognition', 'attribute', 'location', 'state', 'person', 'motive', 'communication']
# window : ['artifact', 'object', 'time']
# winking : ['act']
# tree : ['plant', 'shape', 'person']
# square : ['shape', 'quantity', 'location', 'person', 'artifact']
# odor : ['attribute', 'cognition']
# daisy : ['plant']
# smell : ['cognition', 'attribute', 'state', 'act']
# stable : ['artifact']
# mouth : ['body', 'object', 'person', 'communication', 'artifact']
# drew : ['person']
# tumult : ['state', 'feeling', 'act']
# tremor : ['act', 'event', 'state']
# length : ['attribute', 'artifact']
# body : ['body', 'group', 'object', 'attribute', 'communication', 'artifact']
# shudder : ['feeling', 'act']
# tremble : ['act']
# curling : ['act']
# withholding : ['act', 'possession']
# necessary : ['object']
# striking : ['event', 'act']
# log : ['substance', 'communication', 'artifact']
# hollow : ['shape', 'object']
# sound : ['attribute', 'cognition', 'phenomenon', 'event', 'communication', 'object']
# red : ['attribute', 'object', 'person', 'possession']
# weeping : ['act']
# felt : ['artifact']
# hundred : ['quantity']
# hoof : ['animal']
# beat : ['location', 'event', 'communication', 'phenomenon', 'person', 'attribute', 'act']
# horse : ['animal', 'artifact', 'group']
# wild : ['state', 'location']
# side : ['location', 'group', 'body', 'artifact', 'cognition', 'food', 'communication', 'object', 'event']
# animal : ['Tops']
# friend : ['person']
# strike : ['act', 'event']
# back : ['body', 'artifact', 'location', 'person', 'act']
# hail : ['phenomenon', 'object', 'communication']
# life : ['state', 'cognition', 'time', 'person', 'attribute', 'Tops', 'phenomenon', 'communication', 'motive']
# death : ['event', 'phenomenon', 'state', 'time', 'person', 'act']
# bar : ['artifact', 'communication', 'act', 'quantity', 'object', 'group', 'attribute']
# pressing : ['act', 'artifact']
# waiting : ['act']
# coming : ['act', 'attribute']
# turf : ['object', 'location']
# rounding : ['act']
# curve : ['shape', 'communication', 'act', 'attribute', 'artifact']
# willow : ['plant', 'artifact']
# road : ['artifact', 'act']
# heat : ['phenomenon', 'attribute', 'cognition', 'state', 'event', 'artifact']
# skin : ['body', 'artifact', 'animal', 'state', 'food']
# flesh : ['body', 'plant']
# leg : ['body', 'artifact', 'shape', 'food', 'act']
# rising : ['event', 'act']
# needle : ['plant', 'artifact']
# taking : ['act']
# impossible : ['cognition']
# stitch : ['artifact', 'state']
# saw : ['communication', 'artifact']
# belly : ['body', 'shape', 'location', 'animal']
# pitching : ['act']
# flashing : ['event', 'artifact']
# straining : ['act']
# rose : ['plant', 'food', 'attribute']
# foot : ['body', 'quantity', 'location', 'animal', 'artifact', 'act', 'person', 'group', 'communication']
# blood : ['body', 'attribute', 'person', 'group']
# forehead : ['body']
# fine : ['possession']
# moment : ['time', 'attribute', 'phenomenon', 'cognition']
# mane : ['animal', 'body']
# roan : ['substance', 'animal']
# mare : ['animal', 'object']
# pounding : ['event', 'act']
# cease : ['time']
# sitting : ['act', 'group', 'communication']
# position : ['location', 'cognition', 'attribute', 'state', 'act', 'communication']
# child : ['person']
# youth : ['person', 'group', 'time', 'state', 'attribute']
# put : ['act']
# cap : ['artifact', 'plant', 'object', 'communication']
# large : ['attribute']
# thing : ['state', 'act', 'cognition', 'artifact', 'event', 'communication', 'attribute', 'feeling', 'Tops']
# thick : ['location']
# nature : ['attribute', 'person', 'object', 'cognition']
# trailing : ['act']
# pine : ['plant']
# blade : ['plant', 'person', 'object', 'artifact', 'food', 'body']
# journey : ['act']
# hill : ['object', 'artifact', 'person']
# vine : ['plant']
# pale : ['artifact']
# oak : ['plant']
# killing : ['event', 'act', 'possession']
# dust : ['substance']
# wax : ['substance']
# patrick : ['person']
# pipe : ['artifact', 'shape']
# neck : ['body', 'object', 'food', 'artifact']
# black : ['attribute', 'state', 'person', 'artifact']
# running : ['act', 'state']
# tongue : ['body', 'communication', 'shape', 'object', 'food', 'artifact']
# lip : ['body', 'plant', 'communication', 'artifact', 'animal']
# move : ['act']
# crackling : ['substance', 'event']
# last : ['time', 'relation', 'act', 'quantity', 'event', 'artifact']
# autumn : ['time']
# dead : ['group', 'time']
# infinite : ['Tops']
# patient : ['person', 'communication']
# noise : ['event', 'cognition', 'communication', 'attribute']
# acorn : ['plant']
# powder : ['substance', 'artifact']
# frail : ['quantity', 'artifact']
# pod : ['plant', 'group', 'artifact']
# see : ['location']
# fall : ['time', 'act', 'event', 'object', 'attribute']
# sat : ['time']
# thunder : ['event', 'artifact']
# far : ['group']
# quickening : ['process', 'state', 'act']
# scene : ['location', 'event', 'cognition', 'communication', 'state', 'artifact']
# house : ['artifact', 'group', 'act', 'location']
# quivering : ['state', 'act']
# spear : ['artifact']
# pulling : ['act']
# talking : ['communication']
# cunning : ['cognition', 'attribute']
# pink : ['attribute', 'plant', 'person']
# chin : ['body', 'communication']
# daughter : ['person']
# mother : ['person', 'substance', 'cognition']
# admirer : ['person']
# woman : ['person', 'group']
# lap : ['body', 'state', 'artifact', 'act']
# persian : ['person', 'communication']
# kitten : ['animal']
# trifle : ['food', 'cognition', 'artifact']
# fruit : ['plant', 'artifact', 'event']
# bounty : ['possession', 'attribute', 'artifact']
# avarice : ['act', 'attribute']
# desire : ['feeling', 'attribute', 'state']
# thinking : ['cognition']
# floating : ['act']
# veil : ['artifact', 'plant', 'body']
# nothing : ['quantity']
# boy : ['person']
# nostril : ['body']
# pain : ['state', 'feeling', 'cognition', 'person']
# generation : ['group', 'time', 'event', 'act']
# might : ['attribute']
# quiver : ['feeling', 'state', 'artifact', 'act']
# whiff : ['phenomenon', 'animal', 'act']
# get : ['act']
# looking : ['act']
# bitterness : ['feeling', 'attribute', 'cognition']
# walking : ['act']
# thrusting : ['act']
# better : ['attribute', 'person']
# showing : ['communication', 'act']
# sharp : ['communication', 'artifact']
# comber : ['person', 'event', 'artifact']
# smelling : ['act']
# saddle : ['artifact', 'object', 'food', 'animal']
# nose : ['body', 'artifact', 'quantity', 'communication', 'cognition']
# touching : ['event', 'act']
# yes : ['communication']
# show : ['act', 'communication']
# clothes : ['artifact']
# feel : ['cognition', 'state', 'attribute', 'act']
# nice : ['location']
# heel : ['artifact', 'body', 'person', 'food']
# make : ['cognition', 'act']
# people : ['group']
# lackey : ['person']
# know : ['cognition']
# getting : ['act']
# remonstrance : ['communication']
# married : ['person']
# game : ['act', 'animal', 'time', 'quantity', 'food', 'cognition', 'artifact']
# win : ['event', 'possession']
# ill : ['state']
# breeding : ['attribute', 'act']
# gutter : ['artifact', 'state', 'person']
# reason : ['motive', 'communication', 'cognition', 'state']
# kind : ['cognition']
# person : ['Tops', 'body', 'communication']
# tell : ['person']
# truth : ['cognition', 'state', 'communication', 'attribute', 'person']
# costume : ['artifact']
# groom : ['person']
# timid : ['group']
# go : ['time', 'artifact', 'act']
# mirror : ['artifact', 'cognition']
# challenge : ['state', 'communication']
# look : ['attribute', 'act', 'state']
# absurd : ['state']
# shame : ['feeling', 'state', 'event']
# gentleman : ['person']
# city : ['location', 'group']
# street : ['artifact', 'state', 'group']
# common : ['location']
# end : ['location', 'time', 'event', 'cognition', 'state', 'person', 'act', 'communication', 'artifact']
# rise : ['event', 'act', 'object', 'attribute']
# general : ['person', 'cognition']
# lieutenant : ['person']
# physique : ['attribute', 'body']
# shaking : ['act', 'state']
# smiling : ['communication']
# well : ['artifact', 'communication']
# soldier : ['person', 'animal']
# voice : ['attribute', 'communication', 'event', 'act', 'person', 'relation']
# sort : ['cognition', 'attribute', 'person', 'process']
# irony : ['communication', 'attribute']
# patience : ['attribute', 'act']
# crime : ['act']
# natural : ['person', 'communication', 'act']
# instinct : ['cognition']
# men : ['group', 'person', 'animal', 'location', 'artifact']
# final : ['event', 'communication']
# lower : ['artifact']
# order : ['communication', 'attribute', 'state', 'group', 'act']
# making : ['act', 'attribute', 'artifact']
# idiot : ['person']
# ear : ['body', 'cognition', 'plant']
# degenerate : ['person']
# creep : ['person', 'event', 'artifact', 'act']
# peer : ['person']
# daring : ['communication', 'attribute']
# smear : ['communication', 'body', 'attribute', 'act']
# glove : ['artifact']
# harness : ['artifact']
# grease : ['substance', 'state']
# behind : ['body']
# pretending : ['act']
# enough : ['quantity']
# revolt : ['act']
# torment : ['state', 'feeling', 'event', 'act']
# vas : ['body', 'location', 'group']
# book : ['communication', 'artifact', 'possession', 'group']
# picture : ['artifact', 'cognition', 'state', 'communication']
# fool : ['person']
# doubt : ['cognition', 'attribute']
# mean : ['cognition']
# object : ['Tops', 'cognition', 'communication']
# sphere : ['state', 'artifact', 'location', 'cognition', 'shape']
# best : ['act', 'person']
# collection : ['group', 'communication', 'act']
# miniature : ['artifact']
# say : ['state']
# low : ['state', 'person', 'attribute', 'artifact']
# ottoman : ['person', 'group', 'artifact']
# bringing : ['act']
# palm : ['body', 'quantity', 'plant', 'communication']
# great : ['person']
# answer : ['communication', 'act']
# letting : ['possession']
# mind : ['cognition', 'person']
# love : ['feeling', 'cognition', 'person', 'quantity', 'act']
# much : ['quantity']
# question : ['communication', 'attribute']
# passion : ['feeling', 'attribute', 'state', 'motive', 'cognition']
# ladder : ['artifact', 'state', 'event']
# rung : ['artifact']
# experiment : ['act', 'cognition']
# given : ['cognition']
# food : ['Tops', 'food', 'cognition']
# taste : ['cognition', 'feeling', 'event', 'food', 'act']
# curiosity : ['cognition', 'artifact']
# escape : ['act', 'plant', 'event', 'artifact']
# whim : ['feeling', 'cognition']
# place : ['location', 'cognition', 'act', 'state', 'communication']
# lying : ['act']
# evening : ['time']
# first : ['relation', 'quantity', 'time', 'act', 'communication', 'artifact']
# hair : ['body', 'quantity', 'plant', 'artifact', 'animal']
# nape : ['body']
# lawn : ['location']
# collar : ['artifact', 'attribute', 'act']
# little : ['quantity']
# pretend : ['act']
# run : ['act', 'event', 'group', 'time', 'state', 'quantity', 'object', 'attribute']
# catch : ['attribute', 'quantity', 'person', 'object', 'communication', 'artifact', 'act']
# calm : ['attribute', 'phenomenon']
# creeping : ['act']
# stroking : ['act']
# walk : ['act', 'attribute', 'artifact']
# step : ['act', 'quantity', 'artifact', 'state', 'event', 'communication']
# crawl : ['act']
# carpet : ['artifact', 'object']
# honesty : ['attribute', 'plant']
# situation : ['state', 'location', 'act']
# give : ['attribute']
# miss : ['person', 'event', 'communication']
# want : ['state', 'object', 'feeling']
# interest : ['cognition', 'attribute', 'possession', 'group', 'act']
# someone : ['Tops']
# lead : ['attribute', 'substance', 'cognition', 'act', 'shape', 'communication', 'quantity', 'person', 'location', 'artifact']
# even : ['time']
# world : ['object', 'group', 'cognition', 'animal']
# climbing : ['event']
# read : ['communication']
# regret : ['feeling']
# blunder : ['act']
# party : ['group', 'event', 'person']
# guest : ['person', 'artifact']
# lot : ['quantity', 'location', 'group', 'state', 'artifact', 'person']
# drunk : ['person']
# drink : ['food', 'act', 'object']
# tall : ['attribute']
# shoulder : ['body', 'food', 'artifact']
# strap : ['artifact']
# dance : ['communication', 'group', 'act', 'event']
# sung : ['group']
# bit : ['quantity', 'object', 'time', 'event', 'artifact', 'food', 'communication']
# song : ['communication', 'event', 'act', 'possession', 'group']
# fact : ['cognition', 'communication', 'state']
# behaviour : ['state', 'attribute', 'act']
# purr : ['event']
# satin : ['artifact']
# gown : ['artifact', 'group']
# two : ['quantity', 'artifact']
# going : ['act', 'event']
# spitting : ['act']
# garden : ['artifact', 'group']
# found : ['possession']
# crawling : ['act']
# dampness : ['state']
# come : ['body']
# stallion : ['animal']
# special : ['communication', 'food']
# pet : ['animal', 'person', 'feeling', 'act']
# rough : ['location']
# knowing : ['cognition']
# tearing : ['process']
# ballroom : ['artifact']
# full : ['time']
# real : ['quantity', 'possession']
# still : ['artifact', 'attribute']
# le : ['state']
# leading : ['artifact', 'act']
# pasture : ['location', 'food']
# flare : ['shape', 'process', 'communication', 'state', 'phenomenon', 'artifact', 'act']
# three : ['quantity', 'artifact']
# four : ['quantity', 'artifact']
# testing : ['act']
# weather : ['phenomenon']
# mount : ['animal', 'act', 'object', 'artifact']
# ride : ['act', 'artifact']
# day : ['time', 'state', 'person']
# rush : ['act', 'event', 'plant', 'person', 'feeling']
# joy : ['feeling', 'cognition']
# exhilaration : ['feeling']
# stand : ['artifact', 'location', 'group', 'event', 'cognition', 'act']
# cry : ['communication', 'event']
# ten : ['quantity', 'artifact']
# twelve : ['quantity']
# curb : ['artifact', 'act']
# think : ['cognition']
# shirt : ['artifact']
# front : ['location', 'cognition', 'artifact', 'person', 'state', 'phenomenon', 'group']
# excitement : ['feeling', 'state', 'act']
# wheeling : ['location', 'act']
# wet : ['state']
# quandary : ['state', 'cognition']
# horror : ['feeling', 'artifact']
# damned : ['group']
# open : ['location', 'event', 'cognition']
# calling : ['act']
# speaking : ['communication']
# throat : ['body', 'artifact', 'animal']
# forge : ['artifact']
# mark : ['cognition', 'communication', 'attribute', 'quantity', 'person', 'act']
# pleasure : ['feeling', 'cognition', 'act']
# admission : ['act', 'communication', 'possession', 'attribute']
# rebellion : ['act']
# second : ['time', 'act', 'relation', 'quantity', 'person', 'communication', 'artifact']
# switching : ['act']
# tail : ['animal', 'time', 'shape', 'body', 'person', 'artifact']
# patch : ['attribute', 'location', 'artifact', 'time', 'communication']
# brother : ['person']
# adventuress : ['person']
# lady : ['person']
# leisure : ['time', 'act']
# afternoon : ['time', 'communication']
# boudoir : ['artifact']
# narrow : ['object']
# room : ['artifact', 'quantity', 'state', 'group']
# lacquer : ['substance', 'artifact']
# screen : ['artifact', 'group']
# shade : ['state', 'attribute', 'artifact', 'communication', 'quantity', 'cognition']
# blue : ['attribute', 'artifact', 'group', 'object', 'substance', 'animal']
# extreme : ['attribute', 'location']
# curtain : ['artifact', 'object']
# couch : ['artifact']
# left : ['location', 'group', 'body', 'artifact', 'act']
# peasant : ['person']
# type : ['cognition', 'person', 'group', 'communication', 'artifact']
# range : ['attribute', 'location', 'object', 'artifact', 'group', 'cognition']
# age : ['attribute', 'time']
# nineteen : ['quantity']
# straight : ['person', 'group', 'artifact']
# hanging : ['artifact', 'act']
# lash : ['body', 'artifact', 'act']
# russet : ['artifact']
# shoe : ['artifact']
# six : ['quantity', 'artifact']
# wear : ['state', 'artifact', 'act']
# purple : ['attribute', 'state']
# aster : ['plant', 'body']
# tie : ['artifact', 'state', 'event', 'communication']
# nasal : ['communication', 'body']
# crack : ['object', 'artifact', 'shape', 'event', 'state', 'communication', 'attribute', 'act']
# spite : ['feeling', 'attribute']
# smile : ['communication']
# melancholy : ['feeling', 'state', 'body']
# grossness : ['attribute']
# stupidity : ['cognition', 'act']
# observation : ['act', 'communication', 'cognition']
# keeping : ['act']
# impression : ['cognition', 'attribute', 'shape', 'communication', 'artifact', 'act']
# try : ['act']
# whisper : ['communication', 'event']
# forth : ['object']
# wall : ['artifact', 'object', 'body', 'state']
# part : ['relation', 'artifact', 'object', 'cognition', 'location', 'act', 'possession', 'body', 'communication']
# forty : ['quantity']
# fashion : ['attribute', 'act', 'cognition', 'artifact']
# air : ['substance', 'location', 'attribute', 'phenomenon', 'communication', 'act']
# adulation : ['communication']
# trick : ['act', 'time', 'person']
# narrowing : ['attribute', 'process', 'act']
# forward : ['person', 'act']
# commotion : ['state', 'act', 'event']
# none : ['time', 'act']
# call : ['communication', 'cognition', 'act']
# seat : ['location', 'body', 'artifact', 'attribute']
# crossing : ['act', 'object', 'location', 'artifact']
# carson : ['person']
# james : ['person', 'object', 'communication']
# henry : ['quantity', 'person']
# ha : ['shape']
# good : ['attribute', 'artifact']
# memory : ['cognition', 'artifact']
# social : ['group']
# visitor : ['person']
# monday : ['time']
# tuesday : ['time']
# country : ['group', 'location']
# father : ['person']
# cloth : ['artifact']
# suit : ['artifact', 'act', 'person', 'communication']
# rat : ['animal', 'person', 'artifact']
# remembering : ['cognition']
# barber : ['person']
# chemist : ['person']
# bad : ['attribute']
# funny : ['communication']
# ankle : ['body']
# prostitute : ['person']
# dancing : ['act']
# girl : ['person']
# clean : ['act']
# word : ['communication', 'quantity', 'person']
# vocabulary : ['communication', 'cognition']
# whole : ['cognition', 'Tops']
# fancy : ['cognition', 'feeling']
# ability : ['attribute', 'cognition']
# burning : ['act', 'state', 'process']
# use : ['act', 'attribute', 'process']
# bicycle : ['artifact']
# laughter : ['communication', 'act']
# sun : ['object', 'phenomenon', 'person', 'time']
# right : ['attribute', 'location', 'artifact', 'group', 'body', 'act', 'possession']
# letter : ['communication', 'person']
# cross : ['artifact', 'attribute', 'state', 'animal', 'act']
# fellow : ['person', 'quantity']
# reaction : ['process', 'cognition', 'act', 'phenomenon']
# malice : ['feeling', 'attribute']
# bark : ['plant', 'event', 'artifact']
# mine : ['artifact']
# find : ['cognition', 'act']
# tear : ['body', 'object', 'act']
# dirt : ['substance', 'state', 'communication']
# motion : ['communication', 'event', 'act', 'state', 'phenomenon']
# cow : ['animal', 'person']
# fed : ['person', 'group']
# wish : ['feeling', 'communication', 'cognition']
# tale : ['communication']
# dawn : ['time', 'event']
# bed : ['artifact', 'object', 'location']
# meet : ['event']
# work : ['act', 'artifact', 'cognition', 'phenomenon']
# sight : ['cognition', 'communication', 'act', 'quantity']
# speech : ['communication', 'cognition']
# add : ['state']
# sunday : ['time', 'person']
# watch : ['artifact', 'time', 'act', 'person']
# church : ['group', 'artifact', 'act']
# amen : ['person']
# lift : ['act', 'phenomenon', 'event', 'artifact']
# simple : ['plant', 'person']
# need : ['state', 'object', 'Tops']
# sheep : ['animal', 'person']
# longer : ['person']
# home : ['location', 'artifact', 'state', 'group']
# today : ['time']
# trust : ['possession', 'cognition', 'attribute', 'group', 'state']
# hawk : ['animal', 'person', 'artifact']
# flying : ['act']
# badger : ['person', 'animal']
# treat : ['food', 'event']
# fieldmouse : ['animal']
# ox : ['animal']
# rope : ['artifact']
# package : ['group', 'artifact', 'communication']
# box : ['artifact', 'quantity', 'state', 'shape', 'plant', 'act']
# desk : ['artifact']
# take : ['possession', 'act']
# ribbon : ['object', 'communication', 'artifact']
# breathing : ['act']
# difficulty : ['act', 'cognition', 'state', 'attribute']
# blouse : ['artifact']
# morley : ['person']
# sang : ['plant']
# honey : ['food', 'person']
# jar : ['artifact', 'quantity', 'event']
# stage : ['time', 'state', 'artifact', 'communication', 'act', 'location']
# draw : ['object', 'person', 'event', 'artifact', 'act']
# style : ['attribute', 'communication', 'cognition', 'plant', 'artifact', 'animal']
# disease : ['state']
# underlip : ['body']
# creature : ['Tops', 'person']
# touch : ['event', 'cognition', 'communication', 'attribute', 'act', 'quantity', 'state']
# humility : ['attribute', 'feeling']
# saying : ['communication']
# let : ['group', 'act']
# beauty : ['attribute', 'person', 'cognition']
# line : ['group', 'communication', 'shape', 'phenomenon', 'location', 'cognition', 'artifact', 'act', 'quantity', 'possession']
# laborer : ['person']
# digging : ['act']
# beginning : ['event', 'time', 'cognition', 'location', 'act']
# grunt : ['event', 'person', 'animal']
# roar : ['event', 'communication']
# original : ['artifact', 'cognition']
# pig : ['animal', 'person', 'artifact']
# adenoid : ['body']
# rupture : ['state', 'event', 'act']
# probability : ['attribute']
# ulcer : ['state']
# stomach : ['body', 'feeling']
# god : ['person', 'artifact']
# keep : ['possession', 'artifact']
# meal : ['food', 'time']
# emperor : ['person', 'food', 'animal']
# oh : ['location']
# result : ['phenomenon', 'communication', 'event']
# mole : ['quantity', 'person', 'food', 'attribute', 'artifact', 'animal']
# farmer : ['person']
# russian : ['person', 'communication']
# idea : ['cognition', 'communication']
# madam : ['person']
# column : ['group', 'artifact', 'shape', 'communication', 'body']
# five : ['quantity', 'group', 'artifact']
# sens : ['artifact', 'quantity']
# pot : ['artifact', 'quantity', 'possession', 'body']
# religion : ['cognition', 'group']
# needy : ['group']
# candle : ['artifact', 'quantity']
# blow : ['act', 'event', 'phenomenon', 'artifact']
# somewhere : ['location']
# breath : ['act', 'substance', 'time', 'communication', 'phenomenon']
# tower : ['artifact', 'shape']
# stupid : ['person']
# hate : ['feeling']
# intonation : ['communication', 'act']
# die : ['artifact']
# bother : ['event', 'cognition']
# madonna : ['person']
# pick : ['cognition', 'quantity', 'group', 'artifact', 'act']
# photograph : ['artifact']
# playing : ['act']
# crown : ['communication', 'body', 'artifact', 'possession', 'plant', 'location']
# thorn : ['cognition', 'plant', 'communication']
# amateur : ['person']
# theatrical : ['communication']
# virtue : ['attribute']
# vice : ['attribute', 'act']
# baby : ['person', 'animal', 'act']
# true : ['attribute']
# breast : ['body', 'food', 'animal']
# stroke : ['act', 'event', 'state', 'quantity', 'person', 'communication']
# career : ['act']
# tone : ['communication', 'attribute', 'state', 'cognition']
# pay : ['possession']
# attention : ['cognition', 'act', 'attribute']
# curse : ['communication', 'state', 'event']
# close : ['time', 'communication', 'act']
# nietzsche : ['person']
# schopenhauer : ['person']
# least : ['cognition']
# help : ['act', 'person', 'attribute']
# gross : ['quantity', 'possession']
# trouble : ['cognition', 'event', 'act', 'feeling', 'state']
# cut : ['possession', 'communication', 'artifact', 'state', 'food', 'cognition', 'act']
# pause : ['time', 'act']
# sense : ['cognition', 'communication']
# begin : ['person']
# laugh : ['communication']
# france : ['location', 'person']
# de : ['location']
# hour : ['time', 'attribute']
# dare : ['communication']
# evil : ['act', 'attribute']
# shaving : ['act', 'object']
# carpenter : ['person']
# shop : ['artifact', 'act']
# kill : ['act']
# slipper : ['artifact', 'person']
# court : ['group', 'artifact', 'person', 'act']
# cleaning : ['act']
# frame : ['artifact', 'body', 'time', 'communication', 'cognition', 'act']
# turning : ['act', 'object', 'event', 'artifact']
# affair : ['cognition', 'state', 'event']
# photo : ['artifact']
# burn : ['state', 'attribute', 'act']
# leaving : ['act']
# u : ['substance', 'communication']
# raise : ['attribute', 'object', 'act']
# kiss : ['act', 'food']
# bore : ['person', 'event', 'attribute', 'artifact']
# drop : ['shape', 'quantity', 'attribute', 'object', 'location', 'event', 'artifact', 'act']
# illustration : ['communication', 'cognition', 'artifact']
# field : ['location', 'cognition', 'phenomenon', 'act', 'state', 'object', 'group', 'artifact']
# spring : ['time', 'artifact', 'object', 'location', 'attribute', 'act']
# grey : ['person', 'group', 'attribute', 'artifact', 'animal']
# rye : ['plant', 'food']
# stature : ['state', 'attribute']
# oblong : ['shape']
# dry : ['person']
# ending : ['communication', 'act', 'time', 'event']
# slight : ['act']
# bulb : ['plant', 'artifact', 'shape', 'body']
# rhythm : ['communication', 'attribute', 'time', 'act']
# farming : ['act']
# tender : ['possession', 'person', 'communication', 'artifact']
# acre : ['quantity', 'location']
# month : ['time']
# neighbour : ['person', 'object']
# doorway : ['artifact']
# stretching : ['act']
# shed : ['artifact']
# brown : ['attribute', 'person', 'artifact']
# mutter : ['event', 'communication']
# stroll : ['act']
# cattle : ['animal']
# circle : ['shape', 'group', 'act', 'artifact']
# fly : ['animal', 'artifact', 'act']
# drone : ['animal', 'communication', 'person', 'artifact']
# taffeta : ['artifact']
# deal : ['act', 'communication', 'quantity', 'substance', 'group', 'event']
# trainer : ['person', 'artifact']
# discus : ['event', 'artifact']
# thinness : ['attribute']
# shape : ['attribute', 'Tops', 'body', 'cognition', 'state', 'group']
# flank : ['group', 'shape', 'food', 'animal']
# hock : ['food', 'animal']
# racer : ['person', 'artifact', 'animal']
# rump : ['animal', 'food', 'body']
# england : ['location']
# play : ['communication', 'act', 'state', 'time', 'event', 'attribute']
# hay : ['food']
# grain : ['object', 'food', 'substance', 'quantity', 'plant', 'attribute']
# bin : ['artifact', 'quantity', 'communication']
# flounce : ['artifact', 'act']
# leaping : ['act']
# screaming : ['communication', 'event']
# setting : ['location', 'state', 'artifact']
# ruffle : ['artifact', 'act']
# skill : ['cognition']
# bite : ['state', 'food', 'event', 'communication', 'attribute', 'act']
# pride : ['feeling', 'attribute', 'group', 'act']
# rodent : ['animal']
# menace : ['state', 'communication']
# winter : ['time']
# key : ['artifact', 'cognition', 'attribute', 'communication', 'quantity', 'plant', 'person', 'object', 'location']
# disrepute : ['state']
# townsfolk : ['group']
# landholder : ['person']
# content : ['group', 'communication', 'relation', 'quantity', 'cognition', 'state', 'artifact']
# leave : ['time', 'communication', 'act']
# holding : ['act', 'possession']
# skirt : ['artifact', 'plant', 'person']
# roof : ['artifact', 'object', 'communication']
# disapproval : ['feeling', 'communication', 'cognition', 'act']
# dress : ['artifact']
# driveway : ['artifact']
# stamp : ['shape', 'group', 'communication', 'possession', 'artifact']
# drive : ['act', 'artifact', 'attribute', 'state']
# town : ['location', 'group', 'person']
# market : ['act', 'group', 'artifact']
# gourd : ['artifact', 'plant']
# squash : ['plant', 'food', 'act']
# apple : ['food', 'plant']
# tomato : ['food', 'plant']
# odour : ['cognition', 'attribute']
# sunlight : ['phenomenon']
# occasion : ['event', 'motive', 'time', 'state']
# leaning : ['feeling', 'cognition', 'attribute', 'act']
# maid : ['person']
# quarter : ['quantity', 'location', 'time', 'relation', 'possession', 'person', 'artifact', 'act']
# pat : ['event', 'act']
# round : ['artifact', 'time', 'location', 'act', 'object', 'food', 'communication']
# bust : ['event', 'body', 'artifact', 'act']
# singing : ['act', 'communication']
# chewing : ['act']
# salad : ['food']
# interval : ['time', 'cognition', 'attribute', 'communication']
# kneel : ['act']
# gaudy : ['group']
# christ : ['person']
# beam : ['communication', 'artifact', 'phenomenon', 'attribute']
# barn : ['artifact', 'quantity']
# board : ['group', 'substance', 'artifact', 'food']
# murmuring : ['event', 'communication']
# udder : ['animal']
# fury : ['feeling', 'state', 'attribute', 'person']
# milk : ['food', 'body', 'object']
# shining : ['act']
# knuckle : ['body']
# sister : ['person']
# growing : ['process']
# corn : ['plant', 'food', 'state', 'attribute']
# vegetable : ['food', 'plant']
# purpose : ['cognition', 'attribute']
# grinning : ['communication']
# valet : ['person']
# household : ['group']
# saving : ['act']
# visit : ['act', 'group']
# aunt : ['person']
# mixture : ['substance', 'food', 'group', 'event', 'act']
# jew : ['person']
# nail : ['body', 'artifact', 'quantity']
# revolution : ['event', 'act']
# short : ['artifact', 'act']
# brow : ['body', 'location']
# attempt : ['act']
# alert : ['state', 'communication']
# effort : ['act']
# pace : ['time', 'quantity', 'attribute', 'act']
# master : ['person', 'artifact']
# russia : ['location']
# shot : ['act', 'artifact', 'state', 'person', 'communication', 'quantity', 'cognition']
# dinner : ['food', 'group']
# pail : ['artifact', 'quantity']
# student : ['person']
# chamber : ['artifact', 'body', 'group']
# talk : ['communication', 'act']
# excuse : ['communication', 'cognition']
# phrase : ['communication', 'act']
# raising : ['event', 'attribute', 'act']
# cold : ['state', 'attribute', 'cognition']
# persistence : ['attribute', 'act']
# fireplace : ['artifact']
# tapping : ['event']
# silk : ['artifact', 'substance']
# ruin : ['state', 'artifact', 'process', 'event', 'act']
# stop : ['event', 'act', 'state', 'location', 'communication', 'artifact']
# remark : ['communication', 'cognition']
# catching : ['act']
# sheet : ['object', 'communication', 'artifact', 'shape']
# paper : ['substance', 'communication', 'group', 'artifact']
# push : ['act', 'phenomenon', 'attribute', 'artifact']
# chair : ['artifact', 'act', 'person']
# tea : ['food', 'plant', 'group']
# illness : ['state']
# limb : ['body', 'plant', 'location', 'artifact']
# dung : ['substance']
# plan : ['cognition', 'artifact']
# haying : ['act']
# season : ['time']
# crop : ['plant', 'group', 'artifact', 'animal']
# wood : ['substance', 'group', 'person', 'artifact']
# paregoric : ['artifact']
# whispering : ['event', 'communication']
# ease : ['attribute', 'state', 'act']
# velvet : ['artifact']
# suicide : ['act', 'person']
# impulse : ['motive', 'feeling', 'event', 'act', 'attribute']
# malady : ['state']
# meeting : ['group', 'event', 'act', 'location']
# friendly : ['group']
# term : ['communication', 'time', 'cognition', 'artifact']
# dignity : ['attribute', 'state']
# reserve : ['attribute', 'possession', 'person', 'quantity', 'location', 'group']
# dear : ['person']
# telling : ['communication']
# story : ['communication', 'artifact']
# week : ['time']
# london : ['location', 'person']
# adventure : ['act']
# hotel : ['artifact']
# keeper : ['person']
# nobility : ['group', 'attribute', 'state']
# quality : ['attribute', 'cognition', 'state']
# gay : ['person']
# nurse : ['person']
# rubbing : ['phenomenon', 'artifact', 'act']
# alcohol : ['food', 'substance']
# soup : ['food', 'substance', 'state']
# bedside : ['location']
# coughing : ['state']
# dining : ['act']
# kitchen : ['artifact']
# orchard : ['artifact']
# pump : ['artifact', 'body']
# slope : ['object', 'attribute']
# edge : ['location', 'shape', 'artifact', 'attribute']
# meadow : ['location']
# table : ['group', 'artifact', 'object', 'food']
# health : ['state']
# strength : ['attribute', 'state']
# ham : ['food', 'person']
# fowl : ['animal', 'food']
# bond : ['phenomenon', 'possession', 'relation', 'artifact', 'substance', 'person', 'attribute']
# company : ['group', 'state', 'person']
# crumb : ['quantity', 'person', 'food']
# account : ['communication', 'state', 'motive', 'attribute', 'possession']
# matter : ['cognition', 'Tops', 'attribute', 'communication']
# sod : ['object', 'substance', 'person']
# thud : ['event']
# quiet : ['state', 'attribute']
# brilliancy : ['attribute']
# medicine : ['cognition', 'artifact', 'act']
# bottle : ['artifact', 'quantity']
# flower : ['plant', 'time']
# overwork : ['act']
# expression : ['attribute', 'communication', 'process', 'act']
# peace : ['state', 'feeling', 'communication']
# cast : ['group', 'artifact', 'shape', 'attribute', 'act']
# shadow : ['state', 'location', 'cognition', 'feeling', 'communication', 'attribute', 'person']
# brushing : ['act']
# imaginary : ['quantity']
# speck : ['attribute', 'substance', 'quantity']
# bodice : ['artifact']
# sending : ['act']
# doctor : ['person', 'act']
# burden : ['cognition', 'artifact', 'communication']
# worry : ['cognition', 'feeling']
# relish : ['feeling', 'food', 'cognition']
# picturing : ['cognition', 'act']
# gain : ['quantity', 'attribute', 'possession']
# comfort : ['state', 'feeling', 'act', 'artifact']
# opening : ['object', 'event', 'act', 'state', 'communication', 'cognition', 'body', 'artifact']
# dying : ['time']
# cover : ['artifact', 'act', 'object', 'possession']
# pulsing : ['event']
# spot : ['location', 'communication', 'attribute', 'artifact', 'act', 'state', 'quantity']
# driving : ['act']
# desperation : ['state', 'attribute']
# cheek : ['body', 'communication', 'attribute']
# break : ['event', 'object', 'act', 'time', 'state']
# approaching : ['event', 'attribute', 'act']
# hall : ['artifact', 'person']
# problem : ['state', 'communication', 'cognition']
# hen : ['animal', 'food']
# performance : ['communication', 'act', 'process']
# spirit : ['person', 'state', 'attribute', 'communication']
# shedding : ['process', 'phenomenon']
# folding : ['process', 'act']
# undertaker : ['person']
# coffin : ['artifact']
# flat : ['object', 'artifact', 'communication']
# service : ['act', 'group', 'person', 'attribute', 'artifact']
# passing : ['act', 'event']
# secret : ['communication', 'cognition']
# stoppage : ['state', 'artifact', 'act']
# giving : ['act', 'communication']
# minute : ['time', 'quantity', 'communication', 'attribute']
# excellence : ['attribute', 'cognition']
# arrangement : ['cognition', 'group', 'attribute', 'communication', 'act']
# silence : ['state', 'attribute']
# tread : ['act', 'artifact']
# movement : ['act', 'event', 'group', 'communication', 'phenomenon', 'process', 'cognition', 'artifact']
# rustling : ['act', 'event']
# owl : ['animal']
# pebble : ['object']
# hydrangea : ['plant']
# bush : ['plant', 'location', 'group', 'person', 'body']
# perfume : ['cognition', 'artifact']
# sill : ['artifact', 'object']
# command : ['communication', 'group', 'attribute', 'state', 'cognition']
# must : ['object', 'food', 'attribute']
# middle : ['location', 'cognition', 'body', 'time']
# start : ['event', 'time', 'act', 'location', 'communication', 'attribute']
# shiver : ['act', 'feeling']
# set : ['group', 'act', 'artifact', 'cognition', 'time', 'process', 'person', 'event']
# sigh : ['communication', 'event']
# old : ['time']
# gaiety : ['feeling']
# watching : ['act']
# mountain : ['object', 'quantity']
# cottage : ['artifact']
# overlook : ['location']
# centre : ['location', 'food', 'cognition', 'body', 'artifact']
# door : ['artifact', 'attribute']
# bedroom : ['artifact']
# glimpse : ['act', 'cognition', 'communication']
# pole : ['artifact', 'person', 'cognition', 'quantity', 'location']
# lie : ['communication', 'person', 'location']
# threshold : ['time', 'cognition', 'artifact', 'shape']
# paw : ['animal', 'body']
# crystal : ['substance', 'artifact', 'object']
# glass : ['substance', 'artifact', 'quantity']
# scent : ['cognition', 'attribute']
# bowl : ['artifact', 'shape', 'quantity', 'act']
# perfect : ['relation']
# design : ['act', 'cognition', 'artifact']
# furniture : ['artifact']
# view : ['cognition', 'act', 'location', 'communication', 'artifact', 'attribute']
# audience : ['group', 'state', 'communication']
# mantel : ['artifact']
# medium : ['communication', 'location', 'substance', 'state', 'person', 'act']
# height : ['attribute', 'state']
# faithful : ['group']
# singular : ['communication']
# sadness : ['feeling', 'state', 'attribute']
# vault : ['artifact', 'act']
# windowsill : ['artifact']
# property : ['possession', 'attribute', 'location', 'cognition', 'artifact']
# upright : ['artifact']
# son : ['person']
# physician : ['person']
# commute : ['act']
# religious : ['person']
# fervour : ['state', 'feeling']
# wife : ['person']
# possible : ['cognition', 'person']
# trim : ['state', 'artifact', 'relation', 'act']
# particular : ['cognition', 'relation', 'communication']
# personal : ['communication']
# masculine : ['communication']
# hatband : ['artifact']
# fear : ['feeling']
# misuse : ['act']
# mode : ['attribute', 'state', 'relation', 'communication', 'cognition']
# entrance : ['artifact', 'event', 'act']
# remains : ['object', 'body']
# hope : ['feeling', 'cognition', 'person', 'attribute']
# startle : ['act']
# helena : ['location']
# surprise : ['feeling', 'event', 'act']
# respect : ['cognition', 'state', 'act', 'feeling', 'attribute']
# insult : ['communication', 'act']
# hide : ['substance', 'animal']
# admiration : ['feeling', 'act']
# kicking : ['act']
# riding : ['act']
# whip : ['artifact', 'person', 'food', 'attribute', 'act']
# spectacle : ['communication', 'artifact', 'act']
# ascending : ['act']
# mix : ['food', 'event', 'act']
# trade : ['act', 'group', 'phenomenon']
# incapability : ['cognition', 'attribute']
# storm : ['phenomenon', 'state', 'act']
# cloud : ['phenomenon', 'object', 'state', 'group']
# rolling : ['event', 'act']
# offer : ['communication', 'act']
# state : ['location', 'Tops', 'group', 'state']
# fire : ['event', 'act', 'process', 'artifact', 'substance', 'feeling', 'communication']
# living : ['cognition', 'group', 'state', 'possession']
# sake : ['attribute', 'food', 'cognition']
# glad : ['plant']
# fast : ['act']
# anger : ['feeling', 'state', 'act']
# frankness : ['attribute']
# tough : ['person']
# queer : ['person']
# corruption : ['attribute', 'state', 'process', 'act']
# limit : ['attribute', 'time', 'location', 'quantity']
# cat : ['animal', 'person', 'artifact', 'act']
# magnet : ['artifact', 'cognition']
# positive : ['communication', 'artifact']
# conviction : ['cognition', 'act']
# enemy : ['group', 'person']
# warning : ['communication']
# seizing : ['artifact', 'act']
# resistance : ['act', 'phenomenon', 'state', 'group', 'attribute', 'artifact']
# human : ['animal']
# contact : ['act', 'state', 'event', 'person', 'communication', 'artifact']
# dig : ['location', 'communication', 'attribute', 'act']
# treasure : ['possession', 'artifact', 'group']
# rage : ['feeling', 'state', 'cognition']
# past : ['time', 'communication']
# carrion : ['animal']
# lost : ['group']
# science : ['cognition']
# scientist : ['person']
# posse : ['group']
# phenomenon : ['Tops', 'event']
# failure : ['act', 'event', 'state', 'person']
# change : ['event', 'relation', 'act', 'phenomenon', 'possession', 'artifact', 'attribute']
# coal : ['substance', 'object']
# entire : ['animal']
# manner : ['attribute', 'cognition']
# ardour : ['feeling']
# decay : ['process', 'phenomenon', 'state']
# whinny : ['event']
# pauper : ['person']
# handle : ['artifact']
# cling : ['food']
# vase : ['artifact']
# approach : ['act', 'artifact', 'location', 'event', 'communication', 'attribute']
# walker : ['person', 'artifact']
# dream : ['cognition', 'feeling', 'state']
# plain : ['object', 'artifact']
# lover : ['person']
# name : ['communication', 'state', 'group', 'person', 'act']
# cradle : ['artifact', 'location', 'time']
# kissing : ['act']
# level : ['attribute', 'state', 'artifact', 'cognition']
# recall : ['communication', 'cognition', 'act']
# recollection : ['cognition']
# lock : ['artifact', 'body', 'act']
# thief : ['person']
# terrier : ['animal']
# carry : ['act']
# aniseed : ['food']
# return : ['communication', 'act', 'event', 'possession', 'artifact']
# exit : ['artifact', 'event', 'act']
# spanking : ['act']
# noon : ['time']
# windlass : ['artifact']
# water : ['substance', 'object', 'artifact', 'food']
# cool : ['attribute']
# abyss : ['object']
# bucket : ['artifact', 'quantity']
# familiar : ['person']
# distance : ['attribute', 'location', 'feeling', 'time']
# driver : ['person', 'communication', 'artifact']
# scandinavian : ['person', 'communication']
# folktale : ['communication']
# partridge : ['food', 'animal']
# rein : ['artifact', 'attribute']
# whistle : ['event', 'communication', 'artifact']
# swinging : ['act']
# base : ['artifact', 'object', 'location', 'communication', 'cognition', 'substance', 'shape', 'relation', 'quantity', 'group']
# drifting : ['act']
# tune : ['communication', 'attribute', 'act']
# tang : ['attribute', 'group', 'cognition', 'animal']
# leather : ['substance']
# reaching : ['act']
# whirl : ['event', 'shape', 'act']
# bass : ['attribute', 'communication', 'person', 'food', 'artifact', 'animal']
# mr : ['communication']
# husband : ['person']
# pear : ['food', 'plant']
# deliberation : ['communication', 'cognition', 'attribute']
# comic : ['person']
# boldness : ['attribute']
# ermine : ['substance', 'animal']
# muff : ['artifact', 'act']
# direction : ['location', 'relation', 'cognition', 'communication', 'act']
# local : ['artifact']
# office : ['artifact', 'group', 'act', 'state']
# mail : ['communication', 'artifact', 'group']
# nephew : ['person']
# job : ['act', 'artifact', 'state', 'person', 'communication']
# froth : ['object']
# brightness : ['attribute', 'cognition']
# bending : ['event', 'attribute', 'act']
# waist : ['body', 'artifact']
# reflection : ['cognition', 'phenomenon', 'communication', 'attribute', 'artifact', 'relation']
# lung : ['body']
# echo : ['attribute', 'person', 'communication', 'act']
# fourteen : ['quantity']
# rail : ['artifact', 'animal']
# christmas : ['time']
# locust : ['animal', 'plant']
# smoke : ['phenomenon', 'process', 'communication', 'attribute', 'artifact', 'act']
# jaw : ['body', 'artifact']
# bound : ['shape', 'location', 'attribute', 'act']
# cart : ['artifact']
# jacket : ['artifact', 'food']
# hip : ['body', 'shape', 'plant']
# ascent : ['object', 'event', 'act']
# upstairs : ['artifact']
# sash : ['artifact']
# figure : ['communication', 'body', 'quantity', 'artifact', 'person', 'shape', 'possession', 'attribute', 'cognition', 'act']
# beard : ['body', 'plant', 'person', 'animal']
# wedge : ['shape', 'food', 'communication', 'artifact']
# gait : ['time', 'act']
# keen : ['communication']
# newness : ['attribute']
# rapid : ['object']
# stride : ['act', 'quantity']
# note : ['communication', 'attribute', 'possession', 'state']
# happiness : ['state', 'feeling']
# damn : ['attribute']
# course : ['act', 'group', 'location', 'object', 'food', 'artifact']
# method : ['cognition', 'act']
# koch : ['person']
# nonsense : ['communication', 'artifact']
# trip : ['act', 'state', 'event', 'artifact']
# pushing : ['act']
# december : ['time']
# fifteen : ['quantity']
# sweet : ['person', 'food', 'cognition', 'attribute']
# heaven : ['location', 'cognition']
# colour : ['substance', 'group', 'cognition', 'attribute']
# stopping : ['artifact', 'act']
# mood : ['feeling', 'state', 'relation']
# asking : ['communication']
# bend : ['shape', 'event', 'artifact', 'location']
# forgiveness : ['feeling', 'act']
# misery : ['state', 'feeling']
# pity : ['feeling', 'event', 'attribute']
# ordinary : ['person', 'state', 'artifact']
# experience : ['cognition', 'event']
# nerve : ['body', 'attribute']
# cell : ['artifact', 'Tops', 'group']
# drinking : ['act']
# sleeping : ['cognition', 'act']
# primitive : ['person', 'communication']
# swimming : ['act']
# danger : ['state', 'act', 'location']
# cent : ['quantity', 'possession']
# humanity : ['attribute', 'animal']
# sick : ['group']
# fever : ['state', 'feeling']
# lust : ['feeling', 'act']
# lied : ['communication']
# bear : ['animal', 'person']
# perception : ['cognition', 'act']
# bottom : ['location', 'body', 'time', 'object', 'artifact']
# alien : ['person']
# choir : ['group', 'artifact']
# external : ['cognition']
# demand : ['communication', 'process', 'cognition', 'act', 'state']
# faith : ['cognition', 'group', 'act']
# notion : ['cognition', 'artifact']
# fitting : ['event', 'artifact', 'act']
# release : ['artifact', 'act', 'process', 'communication', 'event']
# handkerchief : ['artifact']
# finish : ['attribute', 'time', 'state', 'location', 'event', 'cognition', 'act']
# wrong : ['attribute', 'act']
# everlasting : ['plant']
# flavour : ['state', 'cognition']
# intimacy : ['attribute', 'state', 'feeling']
# christian : ['person']
# closing : ['act', 'communication']
# divide : ['state', 'location']
# system : ['artifact', 'group', 'substance', 'cognition', 'body', 'attribute']
# working : ['artifact']
# basis : ['relation', 'cognition']
# war : ['act', 'state']
# upside : ['location']
# grimace : ['communication']
# twitch : ['state']
# streaming : ['phenomenon']
# family : ['group', 'person']
# graf : ['person']
# conclusion : ['cognition', 'time', 'event', 'communication', 'act']
# fight : ['act', 'attribute', 'communication']
# stair : ['artifact']
# led : ['artifact']
# filling : ['substance', 'process', 'food', 'artifact', 'act']
# joyousness : ['feeling']
# shelf : ['artifact', 'object']
# chain : ['group', 'object', 'artifact', 'quantity', 'person']
# listening : ['act']
# outside : ['location']
# wind : ['phenomenon', 'act', 'communication', 'artifact']
# childhood : ['time', 'state']
# glory : ['state', 'attribute']
# mercy : ['act', 'attribute', 'feeling', 'state']
# plaster : ['substance', 'artifact']
# lath : ['artifact']
# chest : ['body', 'artifact']
# corner : ['location', 'artifact', 'shape', 'state', 'object']
# lid : ['body', 'artifact']
# spanish : ['communication', 'person']
# mistake : ['act', 'cognition', 'communication']
# irrelevance : ['relation']
# tobacco : ['artifact', 'plant']
# ...
# reclining : ['act']
# tandem : ['attribute', 'artifact']
# firearm : ['artifact']
# group : ['Tops', 'substance', 'cognition']
# modern : ['person', 'communication']
# pistol : ['artifact']
# teen : ['person']
# china : ['location', 'artifact']
# deer : ['animal']
# divan : ['artifact', 'group', 'communication']
# polishing : ['act']
# hurrying : ['act']
# amelia : ['state']
# business : ['group', 'act', 'cognition']
# collect : ['communication']
# shoot : ['plant', 'act']
# gun : ['artifact', 'person', 'act']
# darning : ['act']
# cotton : ['substance', 'artifact', 'plant']
# education : ['act', 'cognition', 'attribute', 'group']
# garter : ['artifact']
# pinch : ['state', 'quantity', 'event', 'act']
# nest : ['object', 'artifact', 'location', 'group']
# elbow : ['body', 'artifact', 'animal']
# tickling : ['act']
# wonder : ['feeling', 'event', 'cognition']
# happening : ['event']
# imagination : ['cognition']
# ignorance : ['cognition']
# knowledge : ['Tops']
# infernal : ['person']
# weapon : ['artifact', 'communication']
# polish : ['attribute', 'state', 'substance', 'communication']
# chop : ['phenomenon', 'food', 'body', 'act']
# blunderbuss : ['artifact']
# parisienne : ['person']
# bathing : ['act']
# pin : ['artifact', 'event', 'communication', 'body']
# hole : ['object', 'artifact', 'shape', 'state', 'body']
# border : ['location', 'shape', 'artifact']
# virgin : ['person', 'location']
# eccentric : ['person']
# underground : ['group', 'artifact']
# suspicion : ['cognition', 'state', 'attribute']
# painting : ['artifact', 'act']
# parasol : ['artifact']
# military : ['group']
# opium : ['artifact']
# hasheesh : ['artifact']
# dresden : ['location']
# doll : ['artifact', 'person']
# chiffon : ['artifact']
# bone : ['body', 'substance', 'attribute']
# action : ['act', 'state', 'process', 'communication', 'attribute', 'artifact']
# bullet : ['artifact', 'act']
# practice : ['act', 'cognition']
# lumber : ['substance', 'artifact']
# dealer : ['person', 'group']
# incline : ['object', 'artifact']
# using : ['act']
# remove : ['attribute']
# wait : ['time', 'act']
# hopelessness : ['feeling']
# biography : ['communication']
# saint : ['person']
# continuity : ['state', 'communication', 'attribute']
# logic : ['cognition']
# probable : ['person']
# sequence : ['group', 'attribute', 'artifact', 'act', 'event']
# dam : ['artifact', 'quantity', 'animal']
# puddle : ['substance', 'object', 'location']
# instance : ['event', 'cognition']
# pop : ['person', 'food', 'event', 'communication']
# arsenal : ['artifact']
# album : ['communication', 'artifact']
# clear : ['state', 'location']
# courtesan : ['person']
# grocer : ['person']
# violin : ['artifact']
# slur : ['communication', 'attribute']
# wearing : ['process', 'act']
# foreground : ['cognition', 'artifact']
# hum : ['state', 'group', 'event']
# italian : ['person', 'communication']
# temperament : ['attribute', 'act']
# poniard : ['artifact']
# pacing : ['time', 'act']
# disaster : ['state', 'event', 'act']
# wink : ['time', 'communication', 'act']
# cork : ['substance', 'location', 'artifact']
# seamstress : ['person']
# monkey : ['animal', 'person']
# mailman : ['person']
# income : ['possession']
# eating : ['act']
# exercising : ['act']
# instep : ['body', 'artifact']
# exercise : ['act', 'event']
# wire : ['artifact', 'location', 'communication']
# tunnel : ['artifact', 'object']
# chimney : ['artifact']
# clutch : ['act', 'state', 'group', 'artifact']
# emphasis : ['state', 'attribute', 'communication']
# pawn : ['possession', 'person', 'artifact', 'act']
# reading : ['cognition', 'communication', 'location', 'act']
# lydia : ['location']
# mistress : ['person']
# corset : ['artifact']
# due : ['attribute', 'possession']
# coral : ['attribute', 'substance', 'food', 'animal']
# necklace : ['artifact']
# ring : ['attribute', 'shape', 'artifact', 'object', 'group', 'event']
# jewelry : ['artifact']
# tragedy : ['event', 'communication']
# tray : ['artifact']
# guardian : ['person']
# cemetery : ['location']
# garnet : ['substance']
# bracelet : ['artifact']
# vessel : ['body', 'artifact']
# tackle : ['person', 'artifact', 'act']
# ivory : ['substance', 'attribute']
# crucifix : ['artifact', 'act']
# englishman : ['person']
# accent : ['communication', 'state']
# cleft : ['shape', 'object']
# separate : ['communication', 'artifact']
# tuft : ['group', 'animal']
# eyetooth : ['body']
# tweed : ['artifact']
# toe : ['body', 'artifact']
# jerky : ['food']
# europe : ['object', 'group']
# watering : ['process', 'act']
# tightening : ['act']
# embracing : ['act']
# gold : ['possession', 'attribute', 'substance']
# strait : ['object', 'state']
# inevitable : ['event']
# arranging : ['act']
# capacity : ['attribute', 'state', 'quantity', 'act', 'phenomenon', 'cognition']
# significance : ['attribute', 'cognition', 'communication']
# affect : ['feeling']
# swagger : ['person', 'act']
# conquest : ['act']
# tease : ['person', 'act']
# loss : ['possession', 'process', 'act', 'attribute', 'event']
# somebody : ['Tops']
# angora : ['location', 'animal']
# amethyst : ['substance']
# opal : ['substance']
# stare : ['act']
# twitching : ['state']
# fixing : ['act', 'artifact']
# caretaker : ['person']
# furnace : ['artifact']
# liqueur : ['food']
# cousin : ['person']
# blond : ['person', 'attribute']
# boring : ['act']
# provincial : ['person']
# chafe : ['state', 'feeling']
# police : ['group']
# ornament : ['artifact']
# heaviness : ['attribute', 'feeling']
# stocking : ['artifact', 'act']
# pressure : ['phenomenon', 'attribute', 'act', 'state', 'cognition']
# relative : ['person', 'animal']
# steal : ['possession', 'act']
# fright : ['feeling']
# hare : ['animal', 'food']
# bough : ['plant']
# slumber : ['state']
# string : ['artifact', 'group', 'communication', 'substance', 'object']
# drowse : ['act']
# coverlet : ['artifact']
# nigger : ['person']
# blinking : ['act']
# toilet : ['artifact', 'state', 'act']
# eager : ['event']
# merriment : ['feeling', 'act']
# negro : ['person']
# southerner : ['person']
# infant : ['person']
# flaw : ['state']
# broth : ['food']
# kin : ['person', 'group']
# heating : ['process', 'artifact']
# saucepan : ['artifact']
# haunch : ['body', 'animal']
# backing : ['act', 'artifact', 'possession']
# inside : ['location']
# fill : ['quantity', 'substance']
# ball : ['artifact', 'shape', 'group', 'body', 'person', 'event', 'act']
# rattling : ['event']
# fringe : ['shape', 'location', 'phenomenon', 'group', 'body', 'artifact']
# gush : ['event', 'communication']
# gasp : ['act']
# card : ['artifact', 'communication', 'substance', 'person']
# harm : ['state', 'event', 'act']
# leapfrog : ['act']
# plantain : ['plant', 'food']
# yard : ['quantity', 'artifact', 'location']
# greenwich : ['location']
# thistle : ['plant']
# morrow : ['time']
# current : ['phenomenon', 'event', 'group']
# yankee : ['person']
# cuff : ['artifact']
# nakedness : ['state', 'attribute']
# yearly : ['communication']
# festivity : ['act']
# owner : ['person']
# strictness : ['attribute']
# accuracy : ['attribute']
# precaution : ['act', 'attribute', 'cognition']
# thus : ['substance']
# expectation : ['cognition', 'state', 'feeling']
# pollen : ['plant']
# drudge : ['person']
# produce : ['food']
# labour : ['group', 'state', 'act']
# loveliness : ['attribute']
# lent : ['time']
# plastic : ['substance', 'possession']
# embodiment : ['person', 'cognition', 'act']
# melting : ['process']
# century : ['time', 'quantity']
# countenance : ['attribute', 'communication', 'body']
# wrinkle : ['shape', 'cognition']
# wisdom : ['cognition', 'attribute', 'communication']
# iris : ['plant', 'body', 'artifact']
# favour : ['feeling', 'cognition', 'attribute', 'artifact', 'act']
# valuable : ['possession']
# rich : ['group']
# scarlet : ['attribute']
# gum : ['food', 'body', 'substance', 'plant']
# whiteness : ['attribute', 'state']
# moisture : ['state']
# access : ['attribute', 'artifact', 'communication', 'act']
# lovely : ['person']
# kneeling : ['act']
# attendant : ['person', 'event']
# serve : ['act']
# onyx : ['substance']
# cushion : ['artifact']
# magazine : ['communication', 'artifact', 'group']
# salon : ['artifact']
# whisker : ['quantity', 'animal']
# embrace : ['act', 'state']
# footman : ['person']
# ambition : ['feeling', 'attribute']
# emissary : ['person']
# poet : ['person']
# musician : ['person']
# bonbon : ['food']
# sentiment : ['feeling', 'cognition']
# professor : ['person']
# crowd : ['group']
# absentmindedness : ['cognition']
# deed : ['communication', 'Tops']
# unattractiveness : ['attribute']
# cruelty : ['act', 'feeling', 'attribute']
# twenty : ['quantity', 'possession']
# severity : ['attribute']
# retort : ['communication', 'artifact']
# hatred : ['feeling']
# oppression : ['act', 'state', 'feeling']
# plenty : ['attribute', 'quantity']
# free : ['group']
# custom : ['act', 'cognition', 'possession']
# compensation : ['possession', 'process', 'act']
# treachery : ['attribute', 'act']
# remedy : ['act', 'artifact']
# italy : ['location']
# spain : ['location']
# devotion : ['feeling', 'act']
# ready : ['state']
# assurance : ['cognition', 'communication', 'possession']
# constant : ['cognition', 'quantity']
# multitude : ['quantity', 'group']
# fur : ['substance', 'animal', 'artifact']
# clothing : ['artifact']
# lapse : ['act', 'time']
# aspirant : ['person']
# steady : ['person']
# gaze : ['act']
# rudeness : ['attribute', 'state']
# being : ['state', 'Tops']
# crookedness : ['shape', 'attribute']
# venture : ['act', 'possession']
# astonishment : ['feeling']
# arguing : ['communication']
# nowhere : ['state']
# entertainment : ['act']
# adoration : ['feeling', 'act']
# decisiveness : ['attribute']
# hint : ['communication', 'quantity']
# piece : ['artifact', 'object', 'communication', 'event', 'food', 'attribute', 'time', 'possession']
# wedding : ['event', 'act', 'group']
# june : ['time']
# reception : ['communication', 'group', 'act']
# throng : ['group']
# hilarity : ['feeling']
# trend : ['location', 'cognition']
# degree : ['attribute', 'state', 'communication', 'quantity', 'cognition']
# wellbeing : ['state']
# flowing : ['event']
# dresser : ['artifact', 'person']
# dressmaker : ['person']
# dressing : ['food', 'event', 'artifact', 'act']
# battlefield : ['location']
# armament : ['artifact', 'act']
# society : ['group', 'state']
# complex : ['cognition', 'substance', 'feeling', 'artifact']
# appearance : ['attribute', 'event', 'act', 'cognition']
# simplicity : ['attribute']
# chill : ['attribute', 'feeling', 'state']
# voicing : ['act']
# tax : ['possession']
# fatigue : ['state', 'feeling', 'act']
# affection : ['feeling']
# praise : ['communication']
# club : ['group', 'artifact']
# exclaiming : ['communication']
# stock : ['possession', 'artifact', 'group', 'food', 'state', 'plant', 'animal']
# spiral : ['shape', 'process', 'artifact', 'act']
# bier : ['artifact']
# elderly : ['group']
# vest : ['artifact']
# bee : ['animal', 'group']
# plum : ['plant', 'food', 'act']
# coo : ['event']
# chilly : ['food']
# hawthorn : ['plant']
# hound : ['animal', 'person']
# armenian : ['person', 'communication']
# lingering : ['act']
# goodbye : ['communication']
# adieu : ['communication']
# restraint : ['act', 'attribute', 'state', 'cognition', 'artifact']
# piquancy : ['attribute']
# departure : ['act', 'event']
# pang : ['feeling', 'state']
# midst : ['location']
# housewife : ['person']
# quilt : ['artifact']
# soil : ['state', 'substance', 'object', 'location']
# plough : ['object', 'artifact']
# goose : ['animal', 'person', 'food']
# satisfaction : ['feeling', 'state', 'possession', 'act']
# duck : ['animal', 'quantity', 'food', 'artifact']
# press : ['state', 'communication', 'artifact', 'group', 'act']
# brittle : ['food']
# incidental : ['possession', 'communication']
# tailoring : ['act']
# establishment : ['act', 'group', 'artifact', 'process', 'cognition']
# september : ['time']
# mosquito : ['animal']
# swamp : ['object', 'state']
# swearing : ['communication']
# mesh : ['quantity', 'event', 'cognition', 'artifact', 'act']
# stranger : ['person']
# sweeping : ['act']
# cot : ['artifact']
# example : ['cognition', 'communication', 'event', 'act']
# scruff : ['body']
# task : ['act']
# cardboard : ['substance']
# chap : ['person', 'shape', 'object', 'artifact']
# butcher : ['person']
# remnant : ['relation', 'artifact']
# serge : ['artifact']
# frosting : ['food']
# kidney : ['body']
# irregular : ['person', 'artifact']
# poultry : ['animal', 'food']
# stitching : ['act']
# gas : ['state', 'substance', 'artifact']
# stove : ['artifact']
# foul : ['act']
# burner : ['artifact']
# paling : ['artifact']
# neighbourhood : ['location', 'group']
# marriage : ['state', 'group', 'act']
# tradesman : ['person']
# smallness : ['attribute']
# hero : ['person', 'cognition', 'food']
# scream : ['communication', 'event']
# liar : ['person']
# effect : ['phenomenon', 'attribute', 'cognition', 'communication', 'state']
# spoiling : ['process', 'act']
# gypsy : ['person', 'communication']
# land : ['possession', 'object', 'location', 'state', 'group', 'person', 'act']
# lad : ['person']
# rival : ['person']
# jean : ['artifact']
# blacksmith : ['person']
# enamel : ['body', 'substance', 'artifact']
# save : ['act']
# feeding : ['act']
# thrush : ['state', 'person', 'animal']
# throbbing : ['event']
# pan : ['artifact', 'person', 'animal']
# pool : ['artifact', 'object', 'group', 'possession', 'location', 'act']
# collecting : ['act']
# insertion : ['communication', 'act']
# passerby : ['person']
# roadway : ['artifact']
# slab : ['artifact']
# tripe : ['food', 'communication']
# pit : ['object', 'shape', 'plant', 'cognition', 'artifact']
# locking : ['act']
# meat : ['food', 'plant', 'cognition']
# pattern : ['cognition', 'act', 'artifact', 'location', 'communication']
# grime : ['state']
# breaking : ['act']
# hang : ['cognition', 'attribute', 'act']
# ploughing : ['act']
# hitting : ['act']
# jerking : ['act']
# cupful : ['quantity']
# cost : ['possession', 'attribute']
# rabbit : ['animal', 'substance', 'food']
# comb : ['artifact', 'animal', 'act']
# tryst : ['group', 'act']
# pulse : ['event', 'time', 'food']
# tomb : ['artifact']
# armpit : ['body']
# number : ['attribute', 'quantity', 'communication', 'group', 'artifact']
# snow : ['phenomenon', 'substance', 'person', 'artifact']
# frost : ['substance', 'phenomenon', 'process', 'person']
# la : ['substance', 'location', 'communication']
# gallop : ['act']
# lane : ['artifact']
# copse : ['group']
# plume : ['shape', 'artifact', 'animal']
# forelock : ['body', 'animal']
# plane : ['artifact', 'shape', 'state']
# frontal : ['artifact']
# spine : ['body', 'shape', 'plant', 'artifact', 'animal']
# pelvis : ['body']
# grip : ['act', 'artifact', 'phenomenon', 'person', 'attribute']
# actress : ['person']
# fife : ['artifact']
# fiddle : ['artifact']
# drum : ['artifact', 'event', 'shape', 'animal']
# king : ['person', 'state', 'artifact']
# intrigue : ['cognition', 'state']
# opera : ['communication', 'artifact']
# queen : ['animal', 'person', 'artifact']
# vaudeville : ['communication']
# foothill : ['object']
# store : ['artifact', 'possession']
# manservant : ['person']
# seven : ['quantity', 'artifact']
# birthmark : ['attribute']
# twisting : ['act']
# goat : ['animal', 'person', 'location']
# smart : ['state']
# brandt : ['person']
# bailey : ['person', 'artifact']
# wilson : ['person', 'object']
# couple : ['group', 'quantity', 'object']
# melon : ['food', 'plant']
# vanity : ['feeling', 'attribute', 'artifact']
# gossip : ['communication', 'person']
# mystery : ['cognition', 'communication']
# element : ['cognition', 'artifact', 'substance', 'location', 'state', 'shape']
# control : ['attribute', 'relation', 'act', 'cognition', 'state', 'artifact', 'person', 'communication']
# chic : ['attribute']
# exaggeration : ['communication', 'act']
# talc : ['substance']
# peignoir : ['artifact']
# engraving : ['artifact', 'act']
# official : ['person']
# double : ['act', 'person', 'cognition']
# rustic : ['person']
# contrast : ['relation', 'act', 'cognition', 'attribute']
# eleven : ['quantity', 'group']
# school : ['group', 'artifact', 'cognition', 'time']
# mud : ['substance', 'communication']
# distress : ['feeling', 'state', 'act']
# amazement : ['feeling']
# schoolmaster : ['person', 'animal']
# untying : ['act']
# bank : ['object', 'group', 'possession', 'artifact', 'act']
# illusion : ['cognition', 'act']
# innocence : ['attribute', 'state']
# suffering : ['state', 'feeling']
# footboard : ['artifact']
# confusion : ['state', 'cognition', 'feeling', 'act']
# indolence : ['attribute']
# clapping : ['communication']
# mortal : ['Tops']
# catbird : ['animal']
# forfeit : ['possession', 'act']
# vow : ['communication']
# static : ['event', 'communication']
# chorister : ['person']
# vapour : ['substance', 'process']
# gardener : ['person']

# %%
verb_dic2 = {}
for verb in verbs2:
    d = []
    for synset in wn.synsets(verb):
        if "verb" in synset.lexname():
            if synset.lexname()[5:] not in d:
                d.append(synset.lexname()[5:])
    verb_dic2[verb] = d

for i in verb_dic2:
    print(i,":", verb_dic2[i])
# Out:
# study : ['cognition', 'perception']
# facing : ['communication', 'competition', 'stative', 'motion', 'perception', 'contact']
# page : ['communication', 'social']
# drawing : ['contact', 'possession', 'cognition', 'motion', 'creation', 'communication', 'emotion', 'consumption', 'competition', 'change', 'stative', 'social', 'body']
# dusk : ['change']
# summer : ['stative']
# man : ['social', 'competition']
# dressed : ['body', 'contact', 'change', 'motion', 'creation']
# frock : ['body']
# coat : ['contact', 'body']
# top : ['stative', 'motion', 'possession', 'contact', 'change']
# hat : ['body', 'possession']
# carrying : ['contact', 'stative', 'motion', 'communication', 'social', 'change', 'competition', 'cognition', 'possession', 'creation', 'consumption', 'body']
# cane : ['contact']
# crept : ['motion']
# bordering : ['contact', 'stative', 'possession']
# corral : ['contact']
# farm : ['social', 'possession', 'creation']
# moved : ['motion', 'social', 'body', 'change', 'emotion', 'creation', 'possession', 'competition', 'communication']
# twig : ['change', 'cognition']
# snapped : ['communication', 'contact', 'change', 'motion', 'perception', 'emotion']
# fell : ['contact', 'motion', 'change', 'stative', 'weather', 'social', 'possession']
# green : ['change']
# wounded : ['body', 'emotion']
# grass : ['competition', 'contact', 'consumption', 'communication']
# hand : ['possession', 'motion']
# tore : ['contact', 'motion', 'body']
# plant : ['contact', 'creation', 'possession', 'cognition']
# hurt : ['perception', 'body', 'emotion', 'change']
# rested : ['contact', 'communication', 'stative', 'body', 'change', 'social']
# time : ['change', 'cognition']
# caring : ['emotion', 'social']
# knotted : ['creation', 'contact']
# yellow : ['change']
# blowing : ['body', 'weather', 'motion', 'perception', 'change', 'social', 'possession', 'contact', 'communication']
# falling : ['motion', 'change', 'stative', 'weather', 'social', 'possession', 'contact']
# covering : ['contact', 'stative', 'communication', 'motion', 'competition', 'social', 'perception', 'possession', 'body']
# leaf : ['perception', 'motion', 'body']
# like : ['emotion', 'cognition']
# face : ['communication', 'competition', 'stative', 'motion', 'perception', 'contact']
# damp : ['perception', 'change']
# struggle : ['social', 'contact', 'motion', 'competition']
# standing : ['contact', 'stative', 'cognition', 'competition']
# white : ['change']
# birch : ['contact']
# shimmered : ['weather', 'stative']
# heard : ['perception', 'cognition', 'social']
# creaking : ['perception']
# gate : ['possession', 'contact', 'change']
# splashing : ['contact', 'motion', 'perception']
# rain : ['weather']
# ached : ['perception', 'emotion']
# earth : ['perception', 'contact']
# faint : ['body']
# murmur : ['communication']
# moving : ['motion', 'social', 'body', 'change', 'emotion', 'creation', 'possession', 'competition', 'communication']
# turn : ['motion', 'change', 'stative', 'contact', 'creation', 'body', 'social', 'possession', 'competition', 'communication']
# throw : ['contact', 'motion', 'communication', 'creation', 'emotion', 'cognition']
# arm : ['competition', 'possession']
# frog : ['contact']
# began : ['change', 'stative', 'communication', 'social']
# moaning : ['communication']
# skunk : ['competition']
# cabbage : ['possession']
# thrust : ['motion', 'communication', 'contact', 'stative']
# bosom : ['perception', 'contact']
# seemed : ['perception', 'stative']
# wondered : ['cognition', 'communication']
# sin : ['social']
# suffer : ['perception', 'body', 'emotion', 'cognition', 'change', 'stative']
# went : ['motion', 'social', 'change', 'stative', 'perception', 'contact', 'consumption', 'competition', 'cognition']
# feeling : ['emotion', 'cognition', 'perception', 'body', 'stative', 'contact', 'possession']
# reached : ['motion', 'contact', 'communication', 'social', 'stative', 'possession', 'competition']
# plank : ['contact', 'consumption']
# fence : ['contact', 'possession', 'competition', 'communication']
# sensing : ['perception', 'cognition']
# finger : ['contact', 'communication']
# lay : ['contact', 'creation', 'possession', 'stative', 'communication', 'motion']
# resting : ['contact', 'communication', 'stative', 'body', 'change', 'social']
# head : ['motion', 'social', 'stative', 'contact']
# ground : ['contact', 'communication', 'motion', 'cognition', 'social', 'change', 'creation']
# tired : ['body', 'possession', 'emotion']
# wanted : ['emotion', 'consumption', 'contact', 'cognition', 'stative']
# sleep : ['body', 'stative']
# searched : ['contact', 'perception', 'cognition']
# straightened : ['motion', 'contact', 'change']
# turned : ['motion', 'change', 'stative', 'contact', 'creation', 'body', 'social', 'possession', 'competition', 'communication']
# eye : ['perception']
# star : ['stative', 'creation', 'change']
# thought : ['cognition', 'creation', 'change']
# live : ['stative', 'cognition']
# shake : ['motion', 'body', 'change', 'emotion', 'communication']
# dog : ['motion']
# barking : ['communication', 'contact', 'change']
# dim : ['perception', 'change']
# light : ['change', 'consumption', 'motion', 'weather', 'possession']
# kept : ['stative', 'possession', 'social', 'cognition', 'communication', 'consumption', 'contact', 'change']
# winking : ['body', 'perception']
# tree : ['motion', 'contact', 'competition', 'change']
# swung : ['motion', 'social', 'contact', 'stative', 'competition', 'change', 'creation']
# square : ['change', 'cognition', 'stative', 'motion', 'possession', 'competition']
# came : ['motion', 'change', 'stative', 'cognition', 'perception']
# assuring : ['communication', 'cognition', 'emotion']
# smell : ['perception', 'cognition']
# stable : ['social']
# opened : ['contact', 'social', 'change', 'stative', 'competition', 'possession', 'perception']
# mouth : ['communication', 'contact']
# drew : ['contact', 'possession', 'cognition', 'motion', 'creation', 'communication', 'emotion', 'consumption', 'competition', 'change', 'stative', 'social', 'body']
# begun : ['change', 'stative', 'communication', 'social']
# tremor : ['motion']
# ran : ['motion', 'stative', 'social', 'contact', 'competition', 'creation', 'change', 'possession']
# body : ['stative']
# trembled : ['motion']
# shudder : ['body', 'motion']
# repeated : ['communication', 'creation', 'change', 'social']
# tremble : ['motion']
# answering : ['communication', 'cognition', 'stative', 'consumption']
# throwing : ['contact', 'motion', 'communication', 'creation', 'emotion', 'cognition']
# curling : ['change', 'motion', 'contact', 'competition']
# withholding : ['possession']
# striking : ['contact', 'emotion', 'competition', 'communication', 'social', 'stative', 'change', 'possession', 'creation', 'perception', 'motion', 'cognition']
# log : ['communication', 'contact']
# dull : ['contact', 'change', 'perception']
# hollow : ['contact']
# sound : ['perception', 'communication', 'change']
# pressed : ['contact', 'communication', 'stative', 'motion', 'creation', 'social', 'competition']
# weeping : ['body']
# felt : ['contact', 'change', 'emotion', 'cognition', 'perception', 'body', 'stative', 'possession']
# hoof : ['motion', 'creation']
# beat : ['competition', 'contact', 'motion', 'creation', 'perception', 'stative', 'social', 'cognition', 'body']
# knew : ['cognition', 'contact']
# horse : ['consumption']
# gone : ['motion', 'social', 'change', 'stative', 'perception', 'contact', 'consumption', 'competition', 'cognition']
# side : ['competition']
# greet : ['communication', 'cognition', 'perception']
# strike : ['contact', 'emotion', 'competition', 'communication', 'social', 'stative', 'change', 'possession', 'creation', 'perception', 'motion', 'cognition']
# back : ['social', 'motion', 'possession', 'stative', 'competition', 'change']
# understood : ['cognition']
# hail : ['communication', 'stative', 'weather']
# bar : ['communication', 'contact', 'social']
# pressing : ['contact', 'communication', 'stative', 'motion', 'creation', 'social', 'competition']
# peering : ['perception']
# waiting : ['stative', 'cognition', 'social']
# coming : ['motion', 'change', 'stative', 'cognition', 'perception']
# turf : ['contact']
# rounding : ['motion', 'change', 'communication', 'body']
# curve : ['motion', 'stative', 'change']
# closed : ['contact', 'social', 'stative', 'communication', 'perception', 'motion', 'change']
# menacing : ['stative', 'communication', 'body']
# deepened : ['change']
# heat : ['change', 'possession', 'emotion']
# deepens : ['change']
# skin : ['motion', 'contact']
# flesh : ['possession']
# long : ['emotion']
# rising : ['motion', 'change', 'stative', 'body', 'emotion', 'competition', 'social']
# needle : ['communication', 'contact']
# taking : ['social', 'possession', 'motion', 'contact', 'change', 'cognition', 'stative', 'perception', 'communication', 'consumption', 'competition', 'body']
# stitch : ['contact']
# saw : ['contact', 'perception', 'cognition', 'creation', 'motion', 'communication', 'social', 'competition']
# belly : ['change']
# pitching : ['contact', 'motion', 'change', 'possession', 'competition']
# flashing : ['perception', 'change', 'communication', 'motion', 'contact']
# straining : ['competition', 'emotion', 'consumption', 'contact', 'body', 'change']
# rose : ['motion', 'change', 'stative', 'body', 'emotion', 'competition', 'social']
# foot : ['possession', 'motion', 'cognition']
# fled : ['motion']
# blood : ['contact']
# trickled : ['motion']
# fine : ['social']
# passed : ['motion', 'social', 'possession', 'stative', 'change', 'contact', 'communication', 'body']
# lifted : ['motion', 'contact', 'communication', 'possession', 'change', 'stative', 'body']
# pounding : ['contact', 'motion', 'change']
# cease : ['stative']
# sitting : ['contact', 'stative', 'motion', 'perception', 'social', 'competition']
# position : ['motion', 'contact']
# jogged : ['stative', 'motion', 'contact', 'communication']
# smothering : ['contact', 'stative']
# done : ['social', 'creation', 'stative', 'body', 'motion']
# put : ['contact', 'communication', 'consumption', 'possession', 'cognition', 'perception', 'creation']
# cap : ['stative', 'change']
# twining : ['contact', 'stative', 'change', 'body']
# matted : ['contact', 'change']
# trailing : ['motion', 'contact']
# pine : ['emotion']
# torn : ['contact', 'motion', 'body']
# journey : ['motion']
# hill : ['creation']
# twisted : ['motion', 'contact', 'change', 'stative', 'communication', 'body']
# pale : ['body']
# killing : ['contact', 'social', 'change', 'stative', 'perception', 'emotion', 'consumption']
# dragging : ['contact', 'stative', 'motion', 'consumption', 'communication', 'change']
# dust : ['contact']
# wax : ['contact', 'change']
# pipe : ['communication', 'motion', 'creation']
# leaned : ['motion', 'contact', 'stative', 'cognition']
# neck : ['contact']
# staring : ['perception', 'body', 'stative', 'creation', 'change']
# black : ['change']
# running : ['motion', 'stative', 'social', 'contact', 'competition', 'creation', 'change', 'possession']
# tongue : ['creation', 'contact']
# snapping : ['communication', 'contact', 'change', 'motion', 'perception', 'emotion']
# sighing : ['body', 'communication']
# move : ['motion', 'social', 'body', 'change', 'emotion', 'creation', 'possession', 'competition', 'communication']
# crackling : ['perception', 'communication', 'change']
# last : ['stative']
# connected : ['contact', 'cognition', 'stative', 'communication', 'social']
# noise : ['perception']
# dropped : ['motion', 'change', 'social', 'communication', 'contact', 'competition', 'possession', 'stative', 'consumption', 'cognition', 'body']
# thin : ['change', 'body']
# powder : ['change', 'body']
# pod : ['change', 'body']
# took : ['social', 'possession', 'motion', 'contact', 'change', 'cognition', 'stative', 'perception', 'communication', 'consumption', 'competition', 'body']
# tossing : ['contact', 'motion', 'possession']
# liked : ['emotion', 'cognition']
# see : ['perception', 'cognition', 'creation', 'motion', 'communication', 'social', 'contact', 'competition']
# fall : ['motion', 'change', 'stative', 'weather', 'social', 'possession', 'contact']
# sat : ['contact', 'stative', 'motion', 'perception', 'social', 'competition']
# thunder : ['motion', 'communication', 'weather']
# quickening : ['change', 'perception', 'body']
# house : ['stative', 'social']
# quivering : ['motion']
# spear : ['contact', 'stative']
# walked : ['motion', 'competition', 'social']
# pulling : ['contact', 'motion', 'social', 'body', 'competition', 'change']
# talking : ['communication']
# pink : ['perception', 'contact']
# pointed : ['communication', 'stative', 'competition', 'motion', 'contact', 'change']
# chin : ['motion']
# mother : ['social', 'body']
# known : ['cognition', 'contact']
# lap : ['stative', 'contact', 'perception', 'consumption', 'change']
# held : ['stative', 'contact', 'creation', 'possession', 'cognition', 'emotion', 'social', 'competition', 'communication', 'motion', 'consumption', 'body']
# kitten : ['body']
# trifle : ['stative', 'social', 'cognition']
# fruit : ['creation']
# desire : ['emotion']
# blew : ['body', 'weather', 'motion', 'perception', 'change', 'social', 'possession', 'contact', 'communication']
# thinking : ['cognition', 'creation', 'change']
# floating : ['motion', 'social', 'contact', 'cognition', 'change']
# veil : ['contact', 'change']
# called : ['communication', 'social', 'stative', 'possession', 'motion', 'cognition', 'body']
# intriguing : ['stative', 'cognition']
# made : ['social', 'change', 'creation', 'communication', 'cognition', 'possession', 'stative', 'motion', 'body', 'perception', 'contact']
# pain : ['body', 'emotion']
# quiver : ['motion']
# caught : ['cognition', 'perception', 'contact', 'motion', 'possession', 'competition', 'change', 'social', 'body', 'weather', 'emotion', 'creation']
# whiff : ['perception', 'motion', 'contact', 'consumption', 'communication']
# near : ['motion']
# get : ['possession', 'change', 'motion', 'contact', 'perception', 'competition', 'communication', 'body', 'cognition', 'emotion', 'creation']
# said : ['communication', 'stative']
# stroked : ['contact', 'competition', 'communication']
# looking : ['perception', 'body', 'stative', 'social', 'communication', 'cognition']
# walking : ['motion', 'competition', 'social']
# gentle : ['emotion', 'social', 'contact']
# thrusting : ['motion', 'communication', 'contact', 'stative']
# answered : ['communication', 'cognition', 'stative', 'consumption']
# better : ['competition', 'change']
# showing : ['perception', 'cognition', 'communication', 'creation', 'motion', 'competition']
# smelling : ['perception', 'cognition']
# saddle : ['contact', 'communication']
# shrivelled : ['change']
# nose : ['perception', 'motion', 'contact', 'competition']
# touching : ['contact', 'perception', 'emotion', 'stative', 'change', 'social', 'communication', 'cognition', 'consumption']
# show : ['perception', 'cognition', 'communication', 'creation', 'motion', 'competition']
# clothes : ['body', 'social', 'contact']
# feel : ['emotion', 'cognition', 'perception', 'body', 'stative', 'contact', 'possession']
# laughing : ['body']
# heel : ['motion', 'creation', 'contact', 'change']
# make : ['social', 'change', 'creation', 'communication', 'cognition', 'possession', 'stative', 'motion', 'body', 'perception', 'contact']
# people : ['change', 'stative']
# amusing : ['social', 'communication']
# returned : ['motion', 'possession', 'change', 'communication', 'contact', 'social', 'creation']
# trying : ['social', 'consumption', 'emotion', 'change', 'body']
# know : ['cognition', 'contact']
# pondering : ['cognition']
# getting : ['possession', 'change', 'motion', 'contact', 'perception', 'competition', 'communication', 'body', 'cognition', 'emotion', 'creation']
# used : ['consumption', 'social']
# realizing : ['cognition', 'creation', 'possession']
# married : ['social']
# game : ['competition']
# win : ['competition', 'possession', 'social']
# breeding : ['creation', 'contact', 'body']
# grown : ['change', 'stative', 'creation', 'body']
# gutter : ['weather', 'motion', 'contact', 'consumption']
# fancied : ['creation', 'emotion']
# reason : ['cognition', 'communication']
# tell : ['communication', 'cognition']
# troubled : ['emotion', 'social', 'body']
# played : ['competition', 'social', 'creation', 'body', 'motion', 'contact', 'consumption', 'cognition', 'stative']
# debased : ['social', 'change']
# costume : ['body', 'possession']
# groom : ['social', 'body']
# desired : ['emotion']
# go : ['motion', 'social', 'change', 'stative', 'perception', 'contact', 'consumption', 'competition', 'cognition']
# mirror : ['weather', 'communication']
# challenge : ['communication']
# look : ['perception', 'body', 'stative', 'social', 'communication', 'cognition']
# shame : ['social', 'emotion', 'competition']
# looked : ['perception', 'body', 'stative', 'social', 'communication', 'cognition']
# hated : ['emotion', 'body', 'possession']
# got : ['possession', 'change', 'motion', 'contact', 'perception', 'competition', 'communication', 'body', 'cognition', 'emotion', 'creation']
# end : ['stative', 'change', 'creation']
# enter : ['motion', 'competition', 'social', 'stative', 'communication', 'creation', 'contact', 'change']
# rise : ['motion', 'change', 'stative', 'body', 'emotion', 'competition', 'social']
# general : ['communication']
# shaking : ['motion', 'body', 'change', 'emotion', 'communication']
# smiling : ['body', 'communication']
# well : ['motion']
# soldier : ['competition']
# sensed : ['perception', 'cognition']
# voice : ['communication']
# sort : ['social', 'cognition']
# commit : ['social', 'communication', 'possession']
# troubling : ['emotion', 'social', 'body']
# thwarted : ['social']
# robbed : ['possession']
# prove : ['stative', 'cognition', 'communication', 'social', 'motion', 'creation']
# lower : ['motion', 'change', 'contact', 'body']
# order : ['communication', 'social', 'change', 'cognition']
# making : ['social', 'change', 'creation', 'communication', 'cognition', 'possession', 'stative', 'motion', 'body', 'perception', 'contact']
# laughed : ['body']
# stuck : ['contact', 'motion', 'stative', 'creation', 'communication', 'cognition']
# receded : ['motion', 'competition', 'change']
# degenerate : ['body']
# creep : ['motion']
# peer : ['perception']
# daring : ['social', 'communication']
# weep : ['body']
# smear : ['contact', 'communication']
# harness : ['contact', 'consumption', 'social', 'change']
# grease : ['contact']
# pretending : ['communication', 'creation', 'possession']
# revolt : ['social', 'perception', 'emotion']
# torment : ['emotion', 'body']
# book : ['cognition', 'social']
# picture : ['creation']
# fool : ['social', 'consumption', 'communication']
# doubt : ['cognition']
# mean : ['communication', 'stative', 'cognition']
# object : ['communication', 'stative']
# best : ['competition']
# say : ['communication', 'stative']
# low : ['communication']
# bringing : ['motion', 'contact', 'creation', 'change', 'possession', 'emotion', 'communication']
# palm : ['contact']
# answer : ['communication', 'cognition', 'stative', 'consumption']
# letting : ['social', 'communication', 'change', 'possession']
# mind : ['communication', 'cognition', 'social']
# love : ['emotion', 'contact']
# question : ['communication']
# placing : ['contact', 'social', 'cognition', 'possession', 'communication', 'competition', 'creation', 'stative']
# ladder : ['change']
# rung : ['perception', 'communication', 'contact']
# experiment : ['social']
# given : ['possession', 'communication', 'creation', 'cognition', 'social', 'motion', 'consumption', 'contact', 'change', 'body']
# taste : ['perception', 'consumption', 'cognition']
# escape : ['motion', 'communication', 'stative', 'social', 'change']
# satisfy : ['stative', 'emotion', 'consumption']
# place : ['contact', 'social', 'cognition', 'possession', 'communication', 'competition', 'creation', 'stative']
# lying : ['stative', 'contact', 'communication', 'motion']
# cramped : ['contact', 'change', 'body']
# slow : ['change']
# evening : ['contact', 'change']
# met : ['motion', 'social', 'stative', 'consumption', 'competition', 'perception', 'contact']
# collar : ['contact']
# pretend : ['communication', 'creation', 'possession']
# run : ['motion', 'stative', 'social', 'contact', 'competition', 'creation', 'change', 'possession']
# catch : ['cognition', 'perception', 'contact', 'motion', 'possession', 'competition', 'change', 'social', 'body', 'weather', 'emotion', 'creation']
# intended : ['cognition', 'communication']
# calm : ['emotion', 'change', 'body']
# creeping : ['motion']
# stroking : ['contact', 'competition', 'communication']
# walk : ['motion', 'competition', 'social']
# step : ['motion', 'social', 'possession', 'contact', 'change']
# crawl : ['motion', 'stative']
# carpet : ['stative', 'contact']
# give : ['possession', 'communication', 'creation', 'cognition', 'social', 'motion', 'consumption', 'contact', 'change', 'body']
# tried : ['social', 'consumption', 'emotion', 'change', 'body']
# miss : ['perception', 'emotion', 'stative', 'cognition', 'motion', 'contact', 'communication']
# want : ['emotion', 'consumption', 'contact', 'cognition', 'stative']
# interest : ['emotion', 'stative']
# ask : ['communication', 'stative']
# relented : ['stative']
# discover : ['perception', 'cognition', 'creation', 'possession', 'communication']
# wished : ['emotion', 'communication']
# meant : ['communication', 'stative', 'cognition']
# hoping : ['emotion', 'cognition', 'motion']
# lead : ['motion', 'stative', 'communication', 'social', 'creation']
# even : ['contact', 'change']
# grow : ['change', 'stative', 'creation', 'body']
# learn : ['cognition', 'communication']
# climbing : ['motion', 'change']
# changing : ['change', 'possession', 'motion']
# read : ['cognition', 'stative', 'communication', 'creation']
# regret : ['emotion', 'communication']
# quivered : ['motion']
# defy : ['stative', 'communication']
# defied : ['stative', 'communication']
# blunder : ['social', 'motion', 'communication']
# party : ['social']
# lot : ['social', 'possession']
# drunk : ['consumption', 'cognition']
# touched : ['contact', 'perception', 'emotion', 'stative', 'change', 'social', 'communication', 'cognition', 'consumption']
# drink : ['consumption', 'cognition']
# remembered : ['cognition', 'possession', 'communication']
# thrown : ['contact', 'motion', 'communication', 'creation', 'emotion', 'cognition']
# gowned : ['body']
# loose : ['social', 'contact', 'change']
# shoulder : ['contact']
# strap : ['contact', 'change', 'body']
# dance : ['motion', 'creation']
# sung : ['creation', 'communication']
# bit : ['contact', 'perception']
# brought : ['motion', 'contact', 'creation', 'change', 'possession', 'emotion', 'communication']
# purr : ['perception', 'communication']
# gown : ['body']
# going : ['motion', 'social', 'change', 'stative', 'perception', 'contact', 'consumption', 'competition', 'cognition']
# twirled : ['motion']
# spitting : ['body', 'communication', 'weather', 'contact']
# garden : ['creation']
# happened : ['change', 'social', 'possession']
# found : ['social', 'creation', 'cognition', 'possession', 'perception', 'communication', 'change', 'motion']
# crawling : ['motion', 'stative']
# come : ['motion', 'change', 'stative', 'cognition', 'perception']
# stared : ['perception', 'body', 'stative', 'creation', 'change']
# pet : ['contact']
# rough : ['creation']
# knowing : ['cognition', 'contact']
# tearing : ['contact', 'motion', 'body']
# galloping : ['motion']
# full : ['contact', 'change']
# paused : ['stative', 'communication']
# still : ['emotion', 'change']
# leading : ['motion', 'stative', 'communication', 'social', 'creation']
# pasture : ['contact']
# flare : ['weather', 'change']
# testing : ['social', 'communication', 'stative', 'competition', 'cognition']
# weather : ['stative', 'motion', 'change']
# mount : ['contact', 'change', 'creation', 'motion']
# ride : ['motion', 'stative', 'communication', 'contact']
# taken : ['social', 'possession', 'motion', 'contact', 'change', 'cognition', 'stative', 'perception', 'communication', 'consumption', 'competition', 'body']
# rush : ['motion', 'competition', 'change', 'creation']
# joy : ['emotion']
# stand : ['contact', 'stative', 'cognition', 'competition']
# cry : ['communication', 'body', 'consumption']
# curb : ['social', 'change', 'contact']
# seem : ['perception', 'stative']
# wondering : ['cognition', 'communication']
# think : ['cognition', 'creation', 'change']
# shirt : ['body']
# front : ['stative', 'competition']
# arising : ['stative', 'motion', 'change', 'social', 'body']
# wheeling : ['motion']
# flaring : ['weather', 'change']
# wet : ['change', 'body']
# whinnied : ['communication']
# damned : ['communication']
# open : ['contact', 'social', 'change', 'stative', 'competition', 'possession', 'perception']
# calling : ['communication', 'social', 'stative', 'possession', 'motion', 'cognition', 'body']
# speaking : ['communication', 'perception']
# promising : ['communication', 'stative']
# descended : ['motion', 'stative', 'social', 'change']
# forge : ['creation', 'motion']
# mark : ['contact', 'communication', 'cognition', 'change', 'social', 'perception']
# forgot : ['cognition']
# spoken : ['communication', 'perception']
# upraised : ['body']
# missed : ['perception', 'emotion', 'stative', 'cognition', 'motion', 'contact', 'communication']
# second : ['social']
# nibbling : ['contact', 'consumption']
# switching : ['change', 'possession', 'contact']
# tail : ['motion', 'contact']
# avoiding : ['communication', 'social', 'consumption']
# patch : ['contact', 'possession', 'change']
# adventuress : ['social']
# narrow : ['change', 'cognition']
# room : ['stative']
# lacquer : ['creation']
# screen : ['social', 'cognition', 'perception', 'contact', 'competition']
# shade : ['weather', 'creation', 'contact', 'change']
# blue : ['change']
# decorated : ['creation', 'stative', 'social', 'contact']
# curtain : ['possession']
# discovered : ['perception', 'cognition', 'creation', 'possession', 'communication']
# couch : ['communication']
# left : ['motion', 'cognition', 'stative', 'change', 'social', 'possession']
# type : ['communication', 'cognition']
# range : ['stative', 'motion', 'contact', 'consumption', 'cognition']
# age : ['change']
# insists : ['communication', 'cognition']
# sticking : ['contact', 'motion', 'stative', 'creation', 'communication', 'cognition']
# hanging : ['contact', 'social', 'motion', 'stative', 'perception', 'creation', 'change']
# lash : ['contact', 'motion']
# clothed : ['body', 'social', 'contact']
# shoe : ['body']
# wear : ['body', 'stative', 'change', 'contact']
# purple : ['change']
# tie : ['contact', 'competition', 'change', 'social', 'creation']
# crack : ['change', 'perception', 'contact', 'social', 'emotion', 'communication']
# spite : ['emotion']
# smile : ['body', 'communication']
# compassionate : ['emotion']
# keeping : ['stative', 'possession', 'social', 'cognition', 'communication', 'consumption', 'contact', 'change']
# try : ['social', 'consumption', 'emotion', 'change', 'body']
# whisper : ['communication']
# buzzing : ['perception', 'motion', 'stative', 'communication']
# wall : ['competition']
# hear : ['perception', 'cognition', 'social']
# part : ['motion', 'social', 'contact']
# enters : ['motion', 'competition', 'social', 'stative', 'communication', 'creation', 'contact', 'change']
# fashion : ['creation']
# interesting : ['emotion', 'stative']
# air : ['perception', 'communication', 'change']
# exerting : ['consumption', 'possession', 'social']
# trick : ['social']
# narrowing : ['change', 'cognition']
# forward : ['motion']
# manages : ['social', 'contact']
# call : ['communication', 'social', 'stative', 'possession', 'motion', 'cognition', 'body']
# seat : ['contact', 'stative', 'social', 'possession']
# crossing : ['motion', 'social', 'stative', 'creation', 'contact']
# james : ['motion', 'contact', 'communication']
# seen : ['perception', 'cognition', 'creation', 'motion', 'communication', 'social', 'contact', 'competition']
# presume : ['cognition', 'social', 'communication', 'body']
# father : ['body']
# pausing : ['stative', 'communication']
# suit : ['stative']
# carried : ['contact', 'stative', 'motion', 'communication', 'social', 'change', 'competition', 'cognition', 'possession', 'creation', 'consumption', 'body']
# rat : ['social', 'contact', 'communication']
# remembering : ['cognition', 'possession', 'communication']
# barber : ['body']
# noticed : ['perception', 'communication']
# prostitute : ['social']
# believe : ['cognition']
# dancing : ['motion', 'creation']
# clean : ['contact', 'change', 'body', 'stative']
# word : ['communication']
# fancy : ['creation', 'emotion']
# burning : ['change', 'weather', 'perception', 'emotion', 'social', 'possession', 'body', 'creation', 'consumption']
# use : ['consumption', 'social']
# bicycle : ['motion']
# sun : ['body', 'perception']
# right : ['social', 'motion', 'change']
# crossed : ['motion', 'social', 'stative', 'creation', 'contact']
# letter : ['possession', 'creation']
# sit : ['contact', 'stative', 'motion', 'perception', 'social', 'competition']
# cross : ['motion', 'social', 'stative', 'creation', 'contact']
# bark : ['communication', 'contact', 'change']
# mine : ['consumption', 'competition']
# find : ['possession', 'perception', 'communication', 'cognition', 'creation', 'change', 'motion']
# tear : ['contact', 'motion', 'body']
# motion : ['communication']
# illustrate : ['communication', 'creation']
# cow : ['emotion']
# milked : ['change', 'consumption']
# fed : ['consumption', 'change', 'social', 'motion']
# shod : ['body']
# wish : ['emotion', 'communication']
# continue : ['stative', 'communication', 'motion', 'social', 'change']
# dawn : ['cognition', 'stative', 'change']
# bed : ['possession', 'contact', 'body']
# meet : ['motion', 'social', 'stative', 'consumption', 'competition', 'perception', 'contact']
# asked : ['communication', 'stative']
# work : ['social', 'contact', 'creation', 'body', 'motion', 'stative', 'perception', 'emotion', 'consumption', 'cognition', 'change']
# sight : ['perception']
# add : ['change', 'communication', 'possession', 'cognition', 'stative']
# watch : ['perception', 'social', 'communication']
# church : ['motion']
# lift : ['motion', 'contact', 'communication', 'possession', 'change', 'stative', 'body']
# need : ['stative', 'consumption']
# home : ['social', 'motion']
# asks : ['communication', 'stative']
# trust : ['cognition', 'social', 'emotion', 'possession']
# hawk : ['possession', 'competition', 'body']
# flying : ['motion', 'contact', 'change', 'perception']
# badger : ['emotion', 'communication']
# bring : ['motion', 'contact', 'creation', 'change', 'possession', 'emotion', 'communication']
# treat : ['social', 'change', 'body', 'communication', 'possession', 'consumption', 'cognition']
# destroyed : ['creation', 'contact', 'competition']
# rope : ['contact']
# package : ['contact']
# risen : ['motion', 'change', 'stative', 'body', 'emotion', 'competition', 'social']
# box : ['contact']
# take : ['social', 'possession', 'motion', 'contact', 'change', 'cognition', 'stative', 'perception', 'communication', 'consumption', 'competition', 'body']
# tied : ['contact', 'competition', 'change', 'social', 'creation']
# sits : ['contact', 'stative', 'motion', 'perception', 'social', 'competition']
# breathing : ['body', 'stative', 'possession', 'communication', 'change']
# thank : ['communication']
# remember : ['cognition', 'possession', 'communication']
# danced : ['motion', 'creation']
# sang : ['creation', 'communication']
# honey : ['perception']
# jar : ['stative', 'motion', 'emotion', 'contact']
# stage : ['creation']
# draw : ['contact', 'possession', 'cognition', 'motion', 'creation', 'communication', 'emotion', 'consumption', 'competition', 'change', 'stative', 'social', 'body']
# style : ['communication', 'creation']
# kissed : ['contact']
# touch : ['contact', 'perception', 'emotion', 'stative', 'change', 'social', 'communication', 'cognition', 'consumption']
# saying : ['communication', 'stative']
# suppose : ['communication', 'cognition']
# let : ['social', 'communication', 'change', 'possession']
# inherited : ['possession']
# line : ['stative', 'contact', 'change']
# digging : ['contact', 'social', 'perception', 'motion', 'cognition']
# beginning : ['change', 'stative', 'communication', 'social']
# grunt : ['communication']
# roar : ['communication', 'motion', 'body']
# pig : ['stative', 'consumption', 'body']
# bleached : ['change']
# rupture : ['contact']
# stomach : ['consumption', 'cognition']
# keep : ['stative', 'possession', 'social', 'cognition', 'communication', 'consumption', 'contact', 'change']
# satisfied : ['stative', 'emotion', 'consumption']
# result : ['stative', 'change']
# listen : ['perception', 'social']
# becomes : ['change', 'stative']
# discovers : ['perception', 'cognition', 'creation', 'possession', 'communication']
# buries : ['perception', 'social', 'contact', 'cognition']
# loved : ['emotion', 'contact']
# pot : ['contact']
# understand : ['cognition']
# admit : ['communication', 'social', 'possession', 'stative']
# candle : ['perception']
# blow : ['body', 'weather', 'motion', 'perception', 'change', 'social', 'possession', 'contact', 'communication']
# tower : ['stative']
# builded : ['creation', 'change', 'social', 'cognition']
# hate : ['emotion']
# shut : ['contact', 'social']
# die : ['change', 'perception', 'emotion', 'contact', 'competition']
# bother : ['social', 'emotion', 'motion']
# posed : ['stative', 'perception', 'communication', 'social', 'contact', 'cognition']
# pick : ['cognition', 'contact', 'communication', 'creation', 'change', 'possession', 'consumption']
# photograph : ['communication', 'stative']
# playing : ['competition', 'social', 'creation', 'body', 'motion', 'contact', 'consumption', 'cognition', 'stative']
# crown : ['social', 'change', 'stative', 'contact']
# presumed : ['cognition', 'social', 'communication', 'body']
# devoted : ['communication', 'cognition', 'possession']
# baby : ['social']
# true : ['change']
# breast : ['stative', 'motion', 'competition']
# stroke : ['contact', 'competition', 'communication']
# career : ['motion']
# tone : ['communication', 'change', 'body']
# pay : ['possession', 'communication', 'cognition', 'stative', 'social']
# curse : ['communication']
# close : ['contact', 'social', 'stative', 'communication', 'perception', 'motion', 'change']
# help : ['social', 'body', 'stative', 'consumption', 'change']
# gross : ['possession']
# trouble : ['emotion', 'social', 'body']
# cut : ['contact', 'change', 'motion', 'social', 'creation', 'communication', 'stative', 'perception', 'body']
# pause : ['stative', 'communication']
# sense : ['perception', 'cognition']
# begin : ['change', 'stative', 'communication', 'social']
# laugh : ['body']
# barked : ['communication', 'contact', 'change']
# needed : ['stative', 'consumption']
# prepared : ['change', 'creation', 'social', 'cognition', 'perception']
# dare : ['social', 'communication']
# cried : ['communication', 'body', 'consumption']
# mistaken : ['cognition']
# cleared : ['change', 'weather', 'communication', 'social', 'possession', 'perception', 'motion', 'cognition']
# shaving : ['body', 'contact', 'possession']
# carpenter : ['social']
# shop : ['possession', 'social', 'communication']
# kill : ['contact', 'social', 'change', 'stative', 'perception', 'emotion', 'consumption']
# court : ['social']
# cleaning : ['contact', 'change', 'body', 'stative']
# frame : ['contact', 'stative', 'social', 'communication', 'cognition', 'creation']
# turning : ['motion', 'change', 'stative', 'contact', 'creation', 'body', 'social', 'possession', 'competition', 'communication']
# bless : ['communication', 'possession']
# burn : ['change', 'weather', 'perception', 'emotion', 'social', 'possession', 'body', 'creation', 'consumption']
# swear : ['communication', 'cognition']
# leaving : ['motion', 'cognition', 'stative', 'change', 'social', 'possession']
# shown : ['perception', 'cognition', 'communication', 'creation', 'motion', 'competition']
# reminded : ['cognition', 'communication']
# forget : ['cognition']
# become : ['change', 'stative']
# raise : ['change', 'motion', 'communication', 'possession', 'creation', 'social', 'emotion', 'competition', 'cognition', 'body']
# kiss : ['contact']
# bore : ['emotion', 'contact', 'stative', 'body', 'cognition', 'creation', 'possession', 'social']
# drop : ['motion', 'change', 'social', 'communication', 'contact', 'competition', 'possession', 'stative', 'consumption', 'cognition', 'body']
# field : ['competition', 'communication', 'cognition']
# grew : ['change', 'stative', 'creation', 'body']
# spring : ['motion', 'stative', 'body', 'communication']
# surrounding : ['contact', 'competition']
# grey : ['change']
# sowed : ['contact', 'communication']
# dry : ['change']
# ending : ['stative', 'change', 'creation']
# slight : ['cognition']
# prided : ['emotion']
# farming : ['social', 'possession', 'creation']
# surveyed : ['cognition', 'perception']
# tender : ['possession', 'change']
# neighbour : ['stative']
# stretching : ['stative', 'body', 'motion', 'change', 'contact']
# shed : ['contact', 'body']
# brown : ['change']
# ploughed : ['motion', 'creation']
# mutter : ['communication']
# stroll : ['motion']
# dizzy : ['change']
# circle : ['motion', 'contact']
# coloured : ['social', 'creation', 'communication', 'change']
# fly : ['motion', 'contact', 'change', 'perception']
# swayed : ['motion', 'social']
# emitting : ['body', 'weather', 'communication']
# drone : ['perception', 'communication']
# rubbed : ['contact', 'perception']
# deal : ['communication', 'cognition', 'social', 'possession']
# shape : ['cognition', 'creation', 'change']
# flank : ['stative']
# hock : ['possession', 'body']
# crowned : ['social', 'change', 'stative', 'contact']
# play : ['competition', 'social', 'creation', 'body', 'motion', 'contact', 'consumption', 'cognition', 'stative']
# hay : ['change']
# grain : ['contact', 'change']
# bin : ['contact']
# flounce : ['motion']
# leaping : ['motion', 'change']
# screaming : ['communication', 'perception']
# stamping : ['motion', 'contact', 'perception', 'cognition', 'change', 'creation']
# setting : ['contact', 'cognition', 'communication', 'change', 'creation', 'motion', 'competition', 'body']
# ruffle : ['motion', 'emotion', 'contact']
# bite : ['contact', 'perception']
# disguised : ['perception']
# pride : ['emotion']
# inform : ['communication', 'change']
# menace : ['stative', 'communication', 'body']
# winter : ['stative']
# shrugging : ['body']
# key : ['cognition', 'possession', 'contact', 'change']
# fallen : ['motion', 'change', 'stative', 'weather', 'social', 'possession', 'contact']
# hinted : ['communication']
# neighbouring : ['stative']
# content : ['consumption', 'emotion']
# leave : ['motion', 'cognition', 'stative', 'change', 'social', 'possession']
# holding : ['stative', 'contact', 'creation', 'possession', 'cognition', 'emotion', 'social', 'competition', 'communication', 'motion', 'consumption', 'body']
# skirt : ['communication', 'motion', 'stative', 'contact']
# roof : ['contact']
# dress : ['body', 'contact', 'change', 'motion', 'creation']
# brings : ['motion', 'contact', 'creation', 'change', 'possession', 'emotion', 'communication']
# stamp : ['motion', 'contact', 'perception', 'cognition', 'change', 'creation']
# showed : ['perception', 'cognition', 'communication', 'creation', 'motion', 'competition']
# drive : ['motion', 'contact', 'social', 'creation', 'communication', 'stative', 'consumption', 'competition']
# market : ['possession', 'change']
# squash : ['contact']
# exhaling : ['body']
# decaying : ['change']
# occasion : ['creation']
# accompanied : ['stative', 'motion', 'creation']
# leaning : ['motion', 'contact', 'stative', 'cognition']
# pointing : ['communication', 'stative', 'competition', 'motion', 'contact', 'change']
# quarter : ['stative', 'social', 'contact', 'cognition']
# pat : ['contact']
# round : ['motion', 'change', 'communication', 'body']
# bust : ['contact', 'social', 'change']
# flourished : ['change', 'possession', 'contact']
# singing : ['creation', 'communication', 'change']
# chewing : ['consumption']
# prayed : ['communication']
# kneel : ['contact']
# hung : ['contact', 'social', 'motion', 'stative', 'perception', 'creation', 'change']
# beam : ['body', 'weather', 'communication', 'perception', 'emotion']
# board : ['motion', 'stative', 'consumption']
# praying : ['communication']
# murmuring : ['communication']
# milking : ['change', 'consumption']
# milk : ['change', 'consumption']
# shining : ['weather', 'perception', 'stative', 'emotion', 'contact', 'motion']
# knuckle : ['contact']
# spend : ['stative', 'possession']
# growing : ['change', 'stative', 'creation', 'body']
# corn : ['consumption', 'change']
# purpose : ['cognition']
# grinning : ['body']
# watered : ['change', 'possession', 'body']
# valet : ['social']
# saving : ['social', 'possession', 'change', 'communication']
# visit : ['social', 'motion', 'communication', 'stative', 'change']
# nail : ['contact', 'social', 'possession', 'competition']
# talked : ['communication']
# fitted : ['stative', 'change', 'possession']
# pomaded : ['body']
# pulled : ['contact', 'motion', 'social', 'body', 'competition', 'change']
# short : ['social', 'creation']
# tormented : ['emotion', 'body']
# distributed : ['possession', 'contact', 'social', 'motion', 'communication', 'stative']
# attempt : ['social', 'creation']
# alert : ['communication']
# pace : ['motion', 'change', 'cognition']
# master : ['cognition', 'competition', 'social']
# shot : ['competition', 'social', 'communication', 'motion', 'contact', 'weather', 'perception', 'consumption', 'cognition', 'change', 'body']
# threw : ['contact', 'motion', 'communication', 'creation', 'emotion', 'cognition']
# arrested : ['contact', 'competition', 'motion']
# sounded : ['perception', 'communication', 'change']
# gazed : ['perception']
# told : ['communication', 'cognition']
# adding : ['change', 'communication', 'possession', 'cognition', 'stative']
# became : ['change', 'stative']
# bald : ['change']
# chamber : ['stative']
# talk : ['communication']
# excuse : ['communication']
# write : ['creation', 'communication']
# scrawling : ['creation']
# phrase : ['communication']
# lifting : ['motion', 'contact', 'communication', 'possession', 'change', 'stative', 'body']
# raising : ['change', 'motion', 'communication', 'possession', 'creation', 'social', 'emotion', 'competition', 'cognition', 'body']
# approve : ['communication', 'cognition']
# tapping : ['contact', 'possession', 'consumption', 'perception', 'motion', 'communication']
# stretched : ['stative', 'body', 'motion', 'change', 'contact']
# ruin : ['contact', 'social', 'possession', 'change']
# stop : ['motion', 'stative', 'social', 'change', 'competition', 'contact']
# remark : ['communication']
# grunting : ['communication']
# catching : ['cognition', 'perception', 'contact', 'motion', 'possession', 'competition', 'change', 'social', 'body', 'weather', 'emotion', 'creation']
# sheet : ['weather', 'contact']
# paper : ['contact']
# finished : ['change', 'stative', 'contact', 'consumption']
# push : ['motion', 'communication', 'social', 'possession', 'contact']
# chair : ['social', 'communication']
# attacked : ['competition', 'communication', 'change', 'body']
# forced : ['social', 'creation', 'motion', 'communication', 'contact']
# complained : ['communication']
# persisted : ['stative', 'change']
# amuse : ['social', 'communication']
# swaying : ['motion', 'social']
# watched : ['perception', 'social', 'communication']
# sniffing : ['perception', 'body']
# dung : ['change', 'body']
# plan : ['cognition', 'creation']
# haying : ['change']
# season : ['perception', 'change']
# crop : ['contact', 'creation']
# gave : ['possession', 'communication', 'creation', 'cognition', 'social', 'motion', 'consumption', 'contact', 'change', 'body']
# wandered : ['motion', 'social', 'communication']
# withered : ['change']
# whispering : ['communication']
# ease : ['motion', 'body', 'change', 'emotion']
# sunk : ['motion', 'change', 'contact']
# surprised : ['cognition', 'social', 'competition']
# meeting : ['motion', 'social', 'stative', 'consumption', 'competition', 'perception', 'contact']
# term : ['communication']
# lived : ['stative', 'cognition']
# maintain : ['stative', 'possession', 'consumption', 'communication', 'cognition']
# reserve : ['possession', 'cognition', 'communication', 'social']
# telling : ['communication', 'cognition']
# spent : ['stative', 'possession']
# adventure : ['social']
# served : ['stative', 'competition', 'social', 'consumption', 'contact']
# nurse : ['body', 'emotion', 'social', 'consumption']
# rubbing : ['contact', 'perception']
# soup : ['body']
# stood : ['contact', 'stative', 'cognition', 'competition']
# coughing : ['body']
# dining : ['consumption', 'perception', 'cognition']
# bare : ['contact', 'communication', 'change']
# pleased : ['emotion']
# pump : ['contact', 'competition', 'motion', 'possession', 'communication']
# slope : ['motion']
# edge : ['motion', 'possession', 'contact']
# table : ['stative', 'creation']
# browsed : ['possession', 'contact', 'consumption']
# gaining : ['possession', 'motion', 'competition', 'change', 'body']
# ham : ['creation']
# smoked : ['consumption', 'weather']
# fowl : ['competition']
# bond : ['contact', 'social', 'possession']
# accepted : ['cognition', 'possession', 'communication', 'stative']
# company : ['stative']
# crumb : ['contact', 'change']
# forgetting : ['cognition']
# suffered : ['perception', 'body', 'emotion', 'cognition', 'change', 'stative']
# account : ['stative', 'possession', 'communication']
# matter : ['stative']
# ripened : ['change']
# sod : ['contact']
# thud : ['perception', 'contact']
# detached : ['contact', 'motion']
# quiet : ['perception', 'emotion']
# receive : ['possession', 'change', 'perception', 'contact', 'cognition', 'communication', 'stative', 'social', 'consumption']
# caressed : ['contact']
# medicine : ['body']
# bottle : ['possession', 'contact']
# tended : ['stative', 'social']
# flower : ['change']
# except : ['communication', 'cognition']
# overwork : ['creation', 'social']
# changed : ['change', 'possession', 'motion']
# flickering : ['motion', 'weather', 'perception']
# cast : ['creation', 'possession', 'contact', 'social', 'motion', 'competition', 'communication', 'body']
# shadow : ['motion', 'weather', 'stative']
# excited : ['emotion', 'change', 'perception']
# brushing : ['contact', 'motion', 'change']
# speck : ['contact']
# sending : ['motion', 'contact', 'communication', 'competition', 'possession']
# observe : ['perception', 'communication', 'social', 'cognition']
# comforted : ['emotion', 'body']
# improved : ['change']
# doctor : ['change', 'body']
# arrived : ['motion', 'social']
# shifted : ['change', 'motion', 'communication']
# burden : ['contact', 'communication']
# worry : ['emotion', 'stative', 'contact']
# bought : ['possession', 'stative', 'cognition']
# relish : ['emotion']
# lessen : ['change']
# picturing : ['creation']
# laid : ['contact', 'creation', 'possession']
# gain : ['possession', 'motion', 'competition', 'change', 'body']
# comfort : ['emotion', 'body']
# opening : ['contact', 'social', 'change', 'stative', 'competition', 'possession', 'perception']
# dying : ['change', 'perception', 'emotion', 'contact', 'competition']
# cover : ['contact', 'stative', 'communication', 'motion', 'competition', 'social', 'perception', 'possession', 'body']
# exposed : ['perception', 'communication', 'contact', 'cognition']
# pulsing : ['motion', 'creation']
# spot : ['perception', 'contact', 'change']
# fondled : ['contact']
# driving : ['motion', 'contact', 'social', 'creation', 'communication', 'stative', 'consumption', 'competition']
# knelt : ['contact']
# cheek : ['communication']
# break : ['change', 'contact', 'social', 'motion', 'emotion', 'stative', 'competition', 'communication', 'possession', 'cognition', 'body']
# approaching : ['motion', 'stative', 'social', 'communication']
# locked : ['contact', 'change', 'emotion', 'motion', 'creation']
# wander : ['motion', 'social', 'communication']
# speak : ['communication', 'perception']
# hasten : ['change', 'motion', 'social', 'creation']
# died : ['change', 'perception', 'emotion', 'contact', 'competition']
# follow : ['motion', 'stative', 'social', 'change', 'possession', 'creation', 'cognition', 'perception']
# planned : ['cognition', 'creation']
# cackled : ['communication', 'body']
# resounded : ['perception']
# spirit : ['change']
# shedding : ['contact', 'body']
# folding : ['contact', 'change', 'social']
# washed : ['contact', 'body', 'motion', 'stative', 'change']
# coffin : ['contact']
# arranged : ['contact', 'communication', 'creation', 'body', 'cognition']
# overlooking : ['perception', 'stative', 'cognition']
# paced : ['motion', 'change', 'cognition']
# undone : ['contact', 'creation', 'social']
# service : ['social', 'change', 'contact']
# distressed : ['social', 'emotion']
# passing : ['motion', 'social', 'possession', 'stative', 'change', 'contact', 'communication', 'body']
# considering : ['cognition', 'perception', 'communication']
# dropping : ['motion', 'change', 'social', 'communication', 'contact', 'competition', 'possession', 'stative', 'consumption', 'cognition', 'body']
# ...
# sing : ['creation', 'communication']
# clear : ['change', 'weather', 'communication', 'social', 'possession', 'perception', 'motion', 'cognition']
# complain : ['communication']
# slur : ['creation', 'communication', 'change']
# wearing : ['body', 'stative', 'change', 'contact']
# plumed : ['possession', 'emotion', 'creation', 'contact', 'change', 'body']
# foreground : ['change']
# hum : ['communication', 'stative', 'perception']
# continues : ['stative', 'communication', 'motion', 'social', 'change']
# loaded : ['contact', 'possession', 'change']
# shined : ['weather', 'perception', 'stative', 'emotion', 'contact', 'motion']
# poniard : ['contact']
# pacing : ['motion', 'change', 'cognition']
# remonstrated : ['communication']
# wink : ['body', 'perception']
# bitten : ['contact', 'perception']
# cork : ['contact', 'change']
# flew : ['motion', 'contact', 'change', 'perception']
# monkey : ['contact']
# infested : ['motion', 'stative']
# offered : ['possession', 'social', 'cognition', 'perception', 'stative', 'communication']
# eating : ['consumption', 'emotion', 'change']
# exercising : ['consumption', 'social', 'body', 'cognition']
# reduces : ['change', 'social', 'possession', 'emotion', 'contact', 'body']
# exercise : ['consumption', 'social', 'body', 'cognition']
# regains : ['possession']
# wire : ['possession', 'communication', 'contact', 'change']
# tunnel : ['motion', 'contact']
# hidden : ['perception', 'contact', 'change']
# sharpened : ['contact', 'change', 'perception']
# clutch : ['contact', 'cognition']
# bares : ['contact', 'communication', 'change', 'social']
# stifled : ['contact', 'change']
# appears : ['perception', 'change', 'creation', 'social']
# uncorked : ['contact']
# vacated : ['social', 'motion', 'communication']
# pawn : ['possession']
# reading : ['cognition', 'stative', 'communication', 'creation']
# divided : ['social', 'cognition', 'stative', 'contact', 'motion']
# corset : ['body']
# focused : ['cognition', 'perception', 'change']
# distended : ['change']
# magnifying : ['change', 'communication']
# ring : ['perception', 'communication', 'contact']
# dealt : ['communication', 'cognition', 'social', 'possession']
# inlaid : ['creation']
# tackle : ['social', 'contact', 'competition']
# marked : ['contact', 'communication', 'cognition', 'change', 'social', 'perception']
# accent : ['communication']
# cleft : ['contact']
# separate : ['stative', 'contact', 'cognition', 'social', 'motion', 'change']
# toe : ['motion', 'contact']
# watering : ['change', 'possession', 'body']
# lowered : ['motion', 'change', 'contact', 'body']
# tightening : ['change']
# darting : ['motion']
# occupied : ['social', 'stative', 'competition', 'possession', 'cognition']
# embracing : ['stative', 'contact', 'cognition']
# examining : ['cognition', 'perception', 'communication', 'social']
# preoccupied : ['emotion', 'possession']
# clinging : ['contact', 'emotion']
# arranging : ['contact', 'communication', 'creation', 'body', 'cognition']
# affect : ['change', 'body', 'stative', 'communication', 'emotion']
# frightens : ['emotion']
# swagger : ['motion', 'communication', 'body']
# disturbing : ['emotion', 'contact', 'change']
# tease : ['emotion', 'communication', 'contact', 'body']
# stare : ['perception', 'body']
# twitching : ['body', 'motion', 'contact']
# fixing : ['change', 'contact', 'communication', 'creation', 'competition', 'body', 'social']
# sipping : ['consumption']
# boring : ['emotion', 'contact']
# chafe : ['perception', 'emotion', 'contact', 'change']
# police : ['social']
# ornament : ['creation', 'stative']
# ribbed : ['creation', 'communication']
# stocking : ['possession', 'body']
# rejected : ['cognition', 'possession', 'communication', 'stative', 'social']
# rejecting : ['cognition', 'possession', 'communication', 'stative', 'social']
# bruised : ['contact', 'emotion', 'change']
# pressure : ['social']
# shivered : ['motion', 'body']
# ceasing : ['stative']
# direct : ['communication', 'competition', 'creation', 'social', 'motion', 'cognition']
# oppressed : ['social']
# weighed : ['stative', 'communication']
# hid : ['perception', 'contact', 'change']
# steal : ['possession', 'motion', 'competition']
# fright : ['emotion']
# hare : ['motion']
# slumber : ['body']
# string : ['contact', 'change', 'motion']
# drowse : ['body']
# minded : ['communication', 'cognition', 'social']
# breathed : ['body', 'stative', 'possession', 'communication', 'change']
# crouched : ['motion', 'contact']
# blinking : ['body', 'perception']
# awed : ['emotion']
# nursed : ['body', 'emotion', 'social', 'consumption']
# flaw : ['change']
# throbbed : ['perception', 'motion']
# failed : ['social', 'emotion', 'change', 'possession']
# heating : ['change', 'possession', 'emotion']
# backing : ['social', 'motion', 'possession', 'stative', 'competition', 'change']
# moistened : ['change', 'contact']
# fill : ['change', 'stative', 'social', 'consumption']
# ball : ['contact']
# rattling : ['perception', 'motion']
# fringe : ['creation', 'contact']
# gush : ['motion', 'communication', 'contact']
# sprang : ['motion', 'stative', 'body', 'communication']
# gasp : ['body']
# card : ['contact', 'cognition']
# harm : ['body']
# leapfrog : ['motion', 'change']
# planted : ['contact', 'creation', 'possession', 'cognition']
# stamped : ['motion', 'contact', 'perception', 'cognition', 'change', 'creation']
# pricked : ['contact', 'perception', 'motion', 'emotion']
# erect : ['creation', 'motion']
# outlined : ['communication', 'creation']
# cuff : ['contact']
# lobed : ['contact']
# utter : ['communication', 'motion']
# proclaims : ['communication']
# speculated : ['cognition', 'communication', 'possession']
# drudge : ['social']
# solve : ['cognition', 'communication']
# produce : ['creation', 'perception', 'body']
# laboured : ['social', 'body']
# labour : ['social', 'body']
# blazed : ['weather', 'competition', 'motion', 'communication']
# savoured : ['perception', 'emotion']
# lent : ['possession', 'stative']
# carved : ['contact']
# melting : ['change']
# countenance : ['communication']
# wrinkle : ['contact', 'change']
# experienced : ['perception', 'cognition', 'emotion', 'change']
# acquired : ['possession', 'change', 'body', 'stative', 'cognition']
# veiled : ['contact', 'change']
# confer : ['communication', 'possession']
# favour : ['social', 'cognition']
# restrained : ['social', 'change', 'contact', 'emotion']
# uncovered : ['perception', 'contact']
# gum : ['contact', 'consumption', 'change', 'body']
# whiteness : ['change']
# dyed : ['change']
# access : ['possession', 'motion']
# worshipped : ['emotion', 'stative']
# kneeling : ['contact']
# serve : ['stative', 'competition', 'social', 'consumption', 'contact']
# pray : ['communication']
# cushion : ['contact']
# whisker : ['possession']
# curled : ['change', 'motion', 'contact', 'competition']
# embrace : ['stative', 'contact', 'cognition']
# refined : ['change']
# ambition : ['emotion']
# proffered : ['possession']
# experimenting : ['social']
# grouped : ['cognition', 'competition']
# courted : ['social']
# crowd : ['motion', 'stative']
# entertained : ['social', 'cognition', 'emotion']
# succumb : ['communication', 'stative']
# remembers : ['cognition', 'possession', 'communication']
# retort : ['communication']
# reproached : ['communication']
# free : ['social', 'possession', 'contact', 'communication', 'creation', 'change']
# expanded : ['motion', 'change', 'communication']
# serenading : ['creation']
# remedy : ['change', 'body']
# hovered : ['stative', 'motion']
# marry : ['social']
# lavish : ['possession']
# ready : ['creation', 'change']
# accept : ['cognition', 'possession', 'communication', 'stative']
# squinting : ['body', 'perception']
# piercing : ['contact', 'emotion', 'perception']
# clothing : ['body', 'social', 'contact']
# proclaimed : ['communication']
# shaped : ['cognition', 'creation', 'change']
# lapse : ['motion', 'change', 'body', 'possession']
# steady : ['change', 'contact']
# centred : ['motion', 'cognition']
# gaze : ['perception']
# rob : ['possession']
# being : ['stative', 'social', 'possession']
# providing : ['possession', 'consumption', 'communication', 'social', 'stative', 'change']
# venture : ['social', 'communication']
# neglecting : ['cognition', 'social']
# persisting : ['stative', 'change']
# arguing : ['communication']
# decide : ['cognition']
# hint : ['communication']
# piece : ['contact', 'creation', 'consumption', 'change']
# wedding : ['social']
# flooded : ['contact', 'change', 'possession']
# throng : ['motion']
# hushed : ['change', 'perception']
# trend : ['motion']
# resemble : ['stative']
# flowing : ['motion', 'stative', 'contact', 'change', 'body']
# supple : ['change']
# bloomed : ['change']
# appreciate : ['emotion', 'cognition', 'possession', 'change']
# dressing : ['body', 'contact', 'change', 'motion', 'creation']
# resembled : ['stative']
# chill : ['emotion', 'change']
# hoped : ['emotion', 'cognition', 'motion']
# expecting : ['cognition', 'communication', 'body']
# voicing : ['communication']
# dawned : ['cognition', 'stative', 'change']
# lose : ['possession', 'competition', 'emotion', 'contact', 'perception', 'change']
# summoned : ['communication', 'contact', 'change']
# assured : ['communication', 'cognition', 'emotion']
# entertaining : ['social', 'cognition', 'emotion']
# tax : ['possession', 'consumption', 'communication']
# fatigue : ['body']
# renewed : ['creation', 'change']
# lavished : ['possession']
# praise : ['communication']
# endearing : ['emotion']
# losing : ['possession', 'competition', 'emotion', 'contact', 'perception', 'change']
# appreciated : ['emotion', 'cognition', 'possession', 'change']
# club : ['social', 'contact']
# exclaiming : ['communication']
# ordered : ['communication', 'social', 'change', 'cognition']
# stock : ['possession', 'body']
# indulged : ['social', 'consumption']
# spiral : ['motion', 'stative']
# strode : ['motion']
# vest : ['social', 'possession', 'body']
# hearkened : ['perception']
# coo : ['communication']
# throve : ['change', 'possession']
# hound : ['motion']
# lingering : ['stative', 'motion']
# quilt : ['creation']
# soil : ['contact']
# toiled : ['social']
# plough : ['motion', 'creation']
# goose : ['contact']
# duck : ['motion', 'communication']
# gaping : ['perception', 'stative', 'contact']
# press : ['contact', 'communication', 'stative', 'motion', 'creation', 'social', 'competition']
# amazed : ['cognition']
# tailoring : ['change', 'creation']
# sew : ['contact', 'creation']
# dipped : ['contact', 'consumption', 'change', 'possession', 'perception', 'motion', 'creation']
# spilling : ['contact', 'motion', 'communication', 'change']
# speckling : ['contact']
# ragged : ['emotion', 'creation', 'communication', 'change']
# swamp : ['weather', 'contact']
# swearing : ['communication', 'cognition']
# tangled : ['stative', 'contact']
# mesh : ['contact', 'change', 'social']
# hissed : ['communication', 'motion']
# sweeping : ['motion', 'contact', 'stative', 'competition']
# curtained : ['possession']
# sprinkled : ['contact', 'weather', 'change']
# sneered : ['body']
# shaken : ['motion', 'body', 'change', 'emotion', 'communication']
# task : ['social', 'consumption']
# peered : ['perception']
# specked : ['contact']
# chap : ['change']
# butcher : ['contact']
# vying : ['competition']
# frosting : ['contact', 'change']
# stitching : ['contact']
# gas : ['competition', 'communication']
# stove : ['possession', 'change']
# foul : ['competition', 'change', 'contact']
# paling : ['body', 'social']
# flattered : ['communication']
# calculated : ['cognition', 'possession', 'communication']
# threatened : ['stative', 'communication']
# prosper : ['possession']
# attracted : ['contact', 'emotion']
# acted : ['social', 'body', 'creation', 'competition', 'stative']
# displeased : ['emotion']
# shrugged : ['body']
# dented : ['contact']
# pondered : ['cognition']
# scream : ['communication', 'perception']
# effect : ['creation', 'social']
# spoiling : ['social', 'change', 'emotion', 'contact']
# returning : ['motion', 'possession', 'change', 'communication', 'contact', 'social', 'creation']
# land : ['motion', 'change', 'possession']
# fought : ['competition', 'social']
# rival : ['stative', 'competition']
# framed : ['contact', 'stative', 'social', 'communication', 'cognition', 'creation']
# enamel : ['creation']
# illuminating : ['change', 'cognition', 'creation']
# killed : ['contact', 'social', 'change', 'stative', 'perception', 'emotion', 'consumption']
# save : ['social', 'possession', 'change', 'communication']
# feeding : ['consumption', 'change', 'social', 'motion']
# choked : ['body', 'contact', 'social', 'change']
# widened : ['change']
# separated : ['stative', 'contact', 'cognition', 'social', 'motion', 'change']
# throbbing : ['perception', 'motion']
# pan : ['motion', 'contact', 'communication']
# pool : ['possession', 'competition']
# collecting : ['possession', 'contact']
# lured : ['communication']
# shrouded : ['contact', 'stative']
# flanked : ['stative']
# pit : ['competition', 'contact', 'change']
# tugged : ['contact', 'social', 'competition']
# darted : ['motion']
# emerged : ['change', 'motion', 'stative']
# observed : ['perception', 'communication', 'social', 'cognition']
# locking : ['contact', 'change', 'emotion', 'motion', 'creation']
# stumbled : ['motion', 'possession', 'cognition']
# pattern : ['creation', 'stative']
# strutting : ['motion']
# clenched : ['contact']
# grime : ['contact']
# breaking : ['change', 'contact', 'social', 'motion', 'emotion', 'stative', 'competition', 'communication', 'possession', 'cognition', 'body']
# jagged : ['contact']
# hang : ['contact', 'social', 'motion', 'stative', 'perception', 'creation', 'change']
# ploughing : ['motion', 'creation']
# uttered : ['communication', 'motion']
# hitting : ['contact', 'motion', 'competition', 'possession', 'perception', 'social', 'consumption', 'communication']
# jerking : ['contact', 'motion', 'body']
# cost : ['stative']
# stooped : ['motion', 'social', 'contact']
# rabbit : ['competition']
# comb : ['contact', 'body']
# pulse : ['motion', 'creation']
# number : ['stative', 'communication', 'change']
# disillusioned : ['emotion']
# snow : ['weather', 'communication']
# frost : ['contact', 'change']
# gallop : ['motion']
# plume : ['possession', 'emotion', 'creation', 'contact', 'change', 'body']
# rounded : ['motion', 'change', 'communication', 'body']
# plane : ['contact', 'motion']
# melted : ['change']
# grip : ['contact', 'emotion']
# lacking : ['stative']
# fiddle : ['social', 'possession', 'creation', 'contact', 'change']
# drum : ['perception', 'creation', 'cognition']
# suggesting : ['communication']
# intrigue : ['stative', 'cognition']
# copied : ['creation']
# queen : ['social', 'motion']
# snuggled : ['contact']
# store : ['possession']
# stunning : ['change', 'contact', 'perception']
# twisting : ['motion', 'contact', 'change', 'stative', 'communication', 'body']
# smart : ['perception']
# couple : ['contact', 'social']
# berrying : ['contact']
# gossip : ['communication']
# control : ['social', 'contact', 'emotion', 'cognition']
# breakfasted : ['consumption']
# dusted : ['contact']
# talc : ['body']
# imprisoned : ['social']
# engraving : ['contact', 'emotion', 'creation']
# double : ['change', 'contact', 'motion', 'possession', 'creation']
# faced : ['communication', 'competition', 'stative', 'motion', 'perception', 'contact']
# received : ['possession', 'change', 'perception', 'contact', 'cognition', 'communication', 'stative', 'social', 'consumption']
# contrast : ['cognition', 'stative']
# quilted : ['creation']
# raining : ['weather']
# chose : ['cognition']
# school : ['social', 'motion']
# softened : ['perception', 'change', 'stative', 'contact', 'communication']
# splashed : ['contact', 'motion', 'perception']
# mud : ['contact']
# rolled : ['motion', 'stative', 'contact', 'perception', 'change', 'body', 'possession', 'communication']
# hesitated : ['stative']
# distress : ['social', 'emotion']
# regarded : ['cognition', 'perception', 'stative']
# untying : ['contact']
# bank : ['motion', 'contact', 'possession', 'cognition']
# confessed : ['communication']
# faltered : ['stative', 'motion', 'communication']
# suffused : ['change']
# suffering : ['perception', 'body', 'emotion', 'cognition', 'change', 'stative']
# embarrasses : ['emotion', 'social']
# clapping : ['contact', 'motion', 'communication', 'body']
# reestablish : ['social']
# forfeit : ['possession']
# vow : ['communication']
# lamented : ['emotion', 'communication']
# reclaim : ['possession', 'change']
# iced : ['contact', 'change']

# %%
noun_cate_dic2 = {}

for i in noun_dic2:
    for j in noun_dic2[i]:
        if j not in noun_cate_dic2:
            noun_cate_dic2[j] = 1
        else:
            noun_cate_dic2[j] +=1

print(noun_cate_dic2)
# Out:
# {'act': 694, 'cognition': 344, 'communication': 457, 'artifact': 733, 'person': 469, 'time': 135, 'group': 226, 'animal': 151, 'location': 189, 'state': 345, 'attribute': 405, 'plant': 102, 'body': 158, 'substance': 117, 'object': 159, 'food': 139, 'quantity': 142, 'Tops': 33, 'feeling': 139, 'event': 225, 'process': 57, 'phenomenon': 71, 'possession': 91, 'shape': 72, 'relation': 40, 'motive': 9}

# %%
verb_cate_dic2 = {}

for i in verb_dic2:
    for j in verb_dic2[i]:
        if j not in verb_cate_dic2:
            verb_cate_dic2[j] = 1
        else:
            verb_cate_dic2[j] +=1

print(verb_cate_dic2)
# Out:
# {'cognition': 472, 'perception': 348, 'communication': 703, 'competition': 265, 'stative': 547, 'motion': 644, 'contact': 829, 'social': 592, 'possession': 397, 'creation': 333, 'emotion': 291, 'consumption': 189, 'change': 707, 'body': 389, 'weather': 57}

# %%
plt.figure()
plt.bar(noun_cate_dic2.keys(),noun_cate_dic2.values())
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure()
plt.bar(verb_cate_dic2.keys(),verb_cate_dic2.values())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # PART 2

# %%
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk import ne_chunk

# %%
tagged_T2 = nltk.word_tokenize(T2)
tagged_T2 = nltk.pos_tag(tagged_T2)
tagged_T2

# %%
results = ne_chunk(tagged_T2)
print(results)

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
cs = cp.parse(tagged_T2)
print(cs)

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)

# %%
for word, pos, ner in iob_tagged:
    print(word, pos, ner)

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
T2 = nlp(T2)
print([(X, X.ent_iob_, X.ent_type_) for X in T2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-5be5561824de> in <module>
# ----> 1 T2 = nlp(T2)
#       2 pprint([(X, X.ent_iob_, X.ent_type_) for X in T2])
#
# ~\Anaconda3\lib\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#     428                 Errors.E088.format(length=len(text), max_length=self.max_length)
#     429             )
# --> 430         doc = self.make_doc(text)
#     431         if component_cfg is None:
#     432             component_cfg = {}
#
# ~\Anaconda3\lib\site-packages\spacy\language.py in make_doc(self, text)
#     452
#     453     def make_doc(self, text):
# --> 454         return self.tokenizer(text)
#     455
#     456     def _format_docs_and_golds(self, docs, golds):
#
# TypeError: Argument 'string' has incorrect type (expected str, got spacy.tokens.doc.Doc)

# %%
labels = [x.label_ for x in T2.ents]

# %%
Counter(labels)
# Out:
# Counter({'DATE': 284,
#          'GPE': 237,
#          'ORDINAL': 163,
#          'PERSON': 764,
#          'QUANTITY': 38,
#          'TIME': 135,
#          'WORK_OF_ART': 51,
#          'NORP': 154,
#          'ORG': 257,
#          'CARDINAL': 405,
#          'FAC': 44,
#          'PRODUCT': 15,
#          'LANGUAGE': 19,
#          'LOC': 16,
#          'MONEY': 9,
#          'EVENT': 1})
